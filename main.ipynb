# %% [markdown]
# RBF

# %%
from filtrar_datos import filtrar_datos_en_rango
from procesar_tableros import procesar_tableros
import pandas as pd
from mpl_toolkits.mplot3d import Axes3D
import os
import numpy as np
import scipy
import scipy.io
from procesar_tableros import *
from filtrar_datos import *
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import matplotlib.pyplot as plt
import xlsxwriter
class RBFNetwork:
    def __init__(self, num_centers, sigma, lambda_reg):
        self.num_centers = num_centers
        self.sigma = sigma
        self.lambda_reg = lambda_reg
        self.centers = None
        self.weights = None

    def _calculate_activations(self, X):
        #distances = scipy.spatial.distance.cdist(X, self.centers)
        distances = np.linalg.norm(X[:, None, :] - self.centers[None, :, :], axis=2)
        activations = np.exp(-distances**2 / (2 * self.sigma**2))
        return activations

    def fit(self, X, y):
        indices = np.random.choice(X.shape[0], self.num_centers, replace=False)
        self.centers = X[indices]
        activations = self._calculate_activations(X)
        
        regularization_matrix = self.lambda_reg * np.eye(activations.shape[1])
        self.weights = np.linalg.solve(activations.T @ activations + regularization_matrix, activations.T @ y)


    def predict(self, X):
        activations = self._calculate_activations(X)
        return activations @ self.weights

# %% [markdown]
# Cargar datos

# %%
# Cargar datos
print("Cargando datos...")
file_path_1bit = "./10x10/10x10/1bit/DATASET_v7.mat"
file_path_2bit = "./10x10/10x10/2bit/DATASET_v7.mat"

mat_data1b = scipy.io.loadmat(file_path_1bit)
mat_data2b = scipy.io.loadmat(file_path_2bit)
print("Datos cargados.")

# Obtenemos los dataset
dataset1b = mat_data1b['DATASET']
dataset2b = mat_data2b['DATASET']

# Acceder a las variables dentro del archivo (1bit)
labels_1b = dataset1b['labels']
inputs_1b = dataset1b['input']
bits_1b = dataset1b['bits']
beams_1b = dataset1b['beams']

# Acceder a las variables dentro del archivo (2bit)
labels_2b = dataset2b['labels']
inputs_2b = dataset2b['input']
bits_2b = dataset2b['bits']
beams_2b = dataset2b['beams']
# Out:
# Cargando datos...
# Datos cargados.

# %%
# Acceder a las variables dentro del archivo (1bit)
labels_1b = dataset1b['labels']
inputs_1b = dataset1b['input']
bits_1b = dataset1b['bits']
beams_1b = dataset1b['beams']

# Acceder a las variables dentro del archivo (2bit)
labels_2b = dataset2b['labels']
inputs_2b = dataset2b['input']
bits_2b = dataset2b['bits']
beams_2b = dataset2b['beams']

# %% [markdown]
# Filtrar datos y procesar tableros

# %%
# Filtrar datos de 1 bit
print("Filtrando datos de 1 bit...")
datos1b_filtrados_input, datos1b_filtrados_labels = filtrar_datos_en_rango(inputs_1b, labels_1b)

# Filtrar datos de 2 bits
print("Filtrando datos de 2 bits...")
datos2b_filtrados_input, datos2b_filtrados_labels = filtrar_datos_en_rango(inputs_2b, labels_2b)

print("Datos filtrados listos.")

# Procesar los tableros
print("Procesando tableros...")

# 1 bit
tableros_procesados_1b = procesar_tableros(datos1b_filtrados_labels, 1)

# 2 bit
tableros_procesados_2b = procesar_tableros(datos2b_filtrados_labels, 2)

# Verificar dimensiones antes de transponer
print("Dimensiones antes de reshaping:")
print("tableros_procesados_1b.shape:", tableros_procesados_1b.shape)
print("tableros_procesados_2b.shape:", tableros_procesados_2b.shape)

# Reshape tableros
rs_tableros_procesados_1b = tableros_procesados_1b.reshape(-1, tableros_procesados_1b.shape[1] * tableros_procesados_1b.shape[2])
rs_tableros_procesados_2b = tableros_procesados_2b.reshape(-1, tableros_procesados_2b.shape[1] * tableros_procesados_2b.shape[2])

print("Dimensiones después de reshaping:")
print("rs_tableros_procesados_1b.shape:", rs_tableros_procesados_1b.shape)
print("rs_tableros_procesados_2b.shape:", rs_tableros_procesados_2b.shape)

# Ajustar las dimensiones de datos1b_filtrados_labels
reshaped_labels_1b = datos1b_filtrados_labels.reshape(-1, datos1b_filtrados_labels.shape[0] * datos1b_filtrados_labels.shape[1])
reshaped_labels_2b = datos2b_filtrados_labels.reshape(-1, datos2b_filtrados_labels.shape[0] * datos2b_filtrados_labels.shape[1])

# Comprobar las dimensiones después del reshaping
print("Dimensiones de reshaped_labels_1b:", reshaped_labels_1b.shape)
print("Dimensiones de reshaped_labels_2b:", reshaped_labels_2b.shape)

# Comprobar las dimensiones de datos1b
print("Dimensiones de datos1b_filtrados_labels:", datos1b_filtrados_labels.shape)
print("Dimensiones de datos2b_filtrados_labels:", datos2b_filtrados_labels.shape)

# Comprobar las dimensiones de datos1b
print("Dimensiones de datos1b_filtrados_inputs:", datos1b_filtrados_input.shape)
print("Dimensiones de datos2b_filtrados_inputs:", datos2b_filtrados_input.shape)
# Out:
# Filtrando datos de 1 bit...
# Filtrando datos de 2 bits...
# Datos filtrados listos.
# Procesando tableros...
# Dimensiones antes de reshaping:
# tableros_procesados_1b.shape: (9180, 10, 10)
# tableros_procesados_2b.shape: (9180, 10, 10)
# Dimensiones después de reshaping:
# rs_tableros_procesados_1b.shape: (9180, 100)
# rs_tableros_procesados_2b.shape: (9180, 100)
# Dimensiones de reshaped_labels_1b: (9180, 100)
# Dimensiones de reshaped_labels_2b: (9180, 100)
# Dimensiones de datos1b_filtrados_labels: (10, 10, 9180)
# Dimensiones de datos2b_filtrados_labels: (10, 10, 9180)
# Dimensiones de datos1b_filtrados_inputs: (9180, 2)
# Dimensiones de datos2b_filtrados_inputs: (9180, 2)

# %% [markdown]
# Pruebas

# %%
# Inicializar matrices para almacenar métricas
predicciones_100_RBFs = np.zeros((10, 10, rs_tableros_procesados_1b.shape[0]))
mse_metrics = np.zeros((10, 10))
mae_metrics = np.zeros((10, 10))
r2_metrics = np.zeros((10, 10))

print(f"rs_tableros_procesados_1b:  ", rs_tableros_procesados_1b.shape)
print(f"datos1b_filtrados_input:  ", datos1b_filtrados_input.shape)

# Definir valores de alpha y sigma para las pruebas
lambda_regs = [0.01, 1, 10, 100]
alpha_factors = [0.01, 0.1, 1]

# Inicializar la matriz multidimensional para almacenar las métricas
# Dimensiones: (10 celdas, 10 celdas, len(Alpha), len(Sigma), len(Lambda))
mse_metrics_matrix_all = np.zeros((10, 10, 6, 6, len(lambda_regs)))
mae_metrics_matrix_all = np.zeros((10, 10, 6, 6, len(lambda_regs)))
r2_metrics_matrix_all = np.zeros((10, 10, 6, 6, len(lambda_regs)))

# Definir valores de alpha, sigma y lambda_reg para las pruebas
alphas_up = []
sigmas_up = []
lambda_up = []

# Realizar pruebas variando num_centers y sigma
for i in range(10):
    for j in range(10):
        y_labels = rs_tableros_procesados_1b[:, i * 10 + j].reshape(-1, 1)
        print(f"Y_labels: ", y_labels.shape)
        X_train1, X_test1, y_train1, y_test1 = train_test_split(
            datos1b_filtrados_input, y_labels, test_size=0.4, random_state=42
        )
        print(f"Datos divididos para la celda ({i},{j}).")

        nc1 = len(X_train1) // 10   # LINEAS NUEVAS 27_6
        #nc1 = 2000 # 2000
        print(f"nc1: ", nc1)
        #alphas = np.linspace(nc1 / len(X_train1) / 2, nc1 / len(X_train1) * 2, 10)  #LINEAS NUEVAS 27_6
        alphas = [1, 10, 100, 1000, 3000, len(X_train1)]
        #alphas = np.logspace(np.log10(nc1 / 100), np.log10(nc1 * 10), 10)
        #alphas = [nc1 * factor for factor in alpha_factors]
        print(f"alphas: ", alphas)

        dc = np.linalg.norm(X_train1[:, None] - X_train1[None, :], axis=-1)
        sg = np.median(dc)
        #sg = 7.5 # 15
        print(f"sg: ", sg)
        #sigmas = np.linspace(sg / 4, sg * 4, 10)
        #sigmas = np.logspace(np.log10(sg / 100), np.log10(sg* 100), 10)
        #sigmas = [sg * factor for factor in alpha_factors]
        sigmas = [1, 2, 4, 8, 16, 32]
        print(f"sigmas: ", sigmas)

        # Inicializar matriz para almacenar resultados
        results = np.zeros((len(alphas), len(sigmas), len(lambda_regs)))

        for alpha_index, alpha in enumerate(alphas):
            #num_centers = int(np.ceil(len(X_train1) * alpha))
            num_centers = alpha
            for sigma_index, sigma in enumerate(sigmas):
                for lambda_reg_index, lambda_reg in enumerate(lambda_regs):
                    print(f"Probando con num_centers = {num_centers} y sigma = {sigma}...")
                    rbf_net = RBFNetwork(num_centers=num_centers, sigma=sigma, lambda_reg=lambda_reg)
                    rbf_net.fit(X_train1, y_train1)
                    predictions_test = rbf_net.predict(X_test1)
                    mse_test = mean_squared_error(y_test1, predictions_test)
                    results[alpha_index, sigma_index, lambda_reg_index] = mse_test
                    print(f"MSE en conjunto de prueba con num_centers = {num_centers} y sigma = {sigma} y lambda_reg = {lambda_reg}: {mse_test}")

                    # Almacenar las métricas en la matriz multidimensional
                    mse_metrics_matrix_all[i, j, alpha_index, sigma_index, lambda_reg_index] = mse_test
                    mae_metrics_matrix_all[i, j, alpha_index, sigma_index, lambda_reg_index] = mean_absolute_error(y_test1, predictions_test)
                    r2_metrics_matrix_all[i, j, alpha_index, sigma_index, lambda_reg_index] = r2_score(y_test1, predictions_test)


        # Almacenar los resultados de la mejor configuración en las matrices de métricas
        best_alpha_index, best_sigma_index, best_lambda_reg_index = np.unravel_index(np.argmin(results), results.shape)
        #best_num_centers = int(np.ceil(len(X_train1) * alphas[best_alpha_index]))
        best_num_centers = alphas[best_alpha_index]
        best_sigma = sigmas[best_sigma_index]
        best_lambda_reg = lambda_regs[best_lambda_reg_index]
        print(f"Best alpha: ", best_num_centers)
        print(f"Best sigma: ", best_sigma)
        print(f"Best lamda_reg: ", best_lambda_reg)
        # Añadir
        alphas_up.append(best_num_centers)
        sigmas_up.append(best_sigma)
        lambda_up.append(best_lambda_reg)


        # Entrenar la RBF con los mejores hiperparámetros
        rbf_net = RBFNetwork(num_centers=best_num_centers, sigma=best_sigma, lambda_reg=best_lambda_reg)
        rbf_net.fit(X_train1, y_train1)
        predictions_all = rbf_net.predict(X_test1)

        # Almacenar las predicciones y métricas
        predicciones_100_RBFs[i, j, :len(predictions_all)] = predictions_all.flatten()
        mse_metrics[i, j] = mean_squared_error(y_test1, predictions_all)
        mae_metrics[i, j] = mean_absolute_error(y_test1, predictions_all)
        r2_metrics[i, j] = r2_score(y_test1, predictions_all)
# Out:
# rs_tableros_procesados_1b:   (9180, 100)
# datos1b_filtrados_input:   (9180, 2)
# Y_labels:  (9180, 1)
# Datos divididos para la celda (0,0).
# nc1:  550
# alphas:  [1, 10, 100, 1000, 3000, 5508]
# sg:  56.85068161420758
# sigmas:  [1, 2, 4, 8, 16, 32]
# Probando con num_centers = 1 y sigma = 1...
# MSE en conjunto de prueba con num_centers = 1 y sigma = 1 y lambda_reg = 0.01: 0.01720037799141049
# Probando con num_centers = 1 y sigma = 1...
# MSE en conjunto de prueba con num_centers = 1 y sigma = 1 y lambda_reg = 1: 0.017163930198592338
# Probando con num_centers = 1 y sigma = 1...
# MSE en conjunto de prueba con num_centers = 1 y sigma = 1 y lambda_reg = 10: 0.01715686274509804
# Probando con num_centers = 1 y sigma = 1...
# MSE en conjunto de prueba con num_centers = 1 y sigma = 1 y lambda_reg = 100: 0.017156862745150908
# Probando con num_centers = 1 y sigma = 2...
# MSE en conjunto de prueba con num_centers = 1 y sigma = 2 y lambda_reg = 0.01: 0.0171568627450983
# Probando con num_centers = 1 y sigma = 2...
# MSE en conjunto de prueba con num_centers = 1 y sigma = 2 y lambda_reg = 1: 0.01715686277065169
# Probando con num_centers = 1 y sigma = 2...
# MSE en conjunto de prueba con num_centers = 1 y sigma = 2 y lambda_reg = 10: 0.01715686274509804
# Probando con num_centers = 1 y sigma = 2...
# MSE en conjunto de prueba con num_centers = 1 y sigma = 2 y lambda_reg = 100: 0.01715687088028418
# Probando con num_centers = 1 y sigma = 4...
# MSE en conjunto de prueba con num_centers = 1 y sigma = 4 y lambda_reg = 0.01: 0.01715685764572829
# Probando con num_centers = 1 y sigma = 4...
# MSE en conjunto de prueba con num_centers = 1 y sigma = 4 y lambda_reg = 1: 0.017156858854049287
# Probando con num_centers = 1 y sigma = 4...
# MSE en conjunto de prueba con num_centers = 1 y sigma = 4 y lambda_reg = 10: 0.017156862756578902
# Probando con num_centers = 1 y sigma = 4...
# MSE en conjunto de prueba con num_centers = 1 y sigma = 4 y lambda_reg = 100: 0.017026646666706162
# Probando con num_centers = 1 y sigma = 8...
# MSE en conjunto de prueba con num_centers = 1 y sigma = 8 y lambda_reg = 0.01: 0.017156854013030142
# Probando con num_centers = 1 y sigma = 8...
# MSE en conjunto de prueba con num_centers = 1 y sigma = 8 y lambda_reg = 1: 0.01674421281267515
# Probando con num_centers = 1 y sigma = 8...
# MSE en conjunto de prueba con num_centers = 1 y sigma = 8 y lambda_reg = 10: 0.01715448713583575
# Probando con num_centers = 1 y sigma = 8...
# MSE en conjunto de prueba con num_centers = 1 y sigma = 8 y lambda_reg = 100: 0.01712972395233526
# Probando con num_centers = 1 y sigma = 16...
# MSE en conjunto de prueba con num_centers = 1 y sigma = 16 y lambda_reg = 0.01: 0.01705046033187876
# Probando con num_centers = 1 y sigma = 16...
# MSE en conjunto de prueba con num_centers = 1 y sigma = 16 y lambda_reg = 1: 0.017122495099633213
# Probando con num_centers = 1 y sigma = 16...
# MSE en conjunto de prueba con num_centers = 1 y sigma = 16 y lambda_reg = 10: 0.017093733566773094
# Probando con num_centers = 1 y sigma = 16...
# MSE en conjunto de prueba con num_centers = 1 y sigma = 16 y lambda_reg = 100: 0.017003955469902948
# Probando con num_centers = 1 y sigma = 32...
# MSE en conjunto de prueba con num_centers = 1 y sigma = 32 y lambda_reg = 0.01: 0.017022568283377986
# Probando con num_centers = 1 y sigma = 32...
# MSE en conjunto de prueba con num_centers = 1 y sigma = 32 y lambda_reg = 1: 0.016930125725027348
# Probando con num_centers = 1 y sigma = 32...
# MSE en conjunto de prueba con num_centers = 1 y sigma = 32 y lambda_reg = 10: 0.016860225602216148
# Probando con num_centers = 1 y sigma = 32...
# MSE en conjunto de prueba con num_centers = 1 y sigma = 32 y lambda_reg = 100: 0.01693021485991559
# Probando con num_centers = 10 y sigma = 1...
# MSE en conjunto de prueba con num_centers = 10 y sigma = 1 y lambda_reg = 0.01: 0.0171703149995424
# Probando con num_centers = 10 y sigma = 1...
# MSE en conjunto de prueba con num_centers = 10 y sigma = 1 y lambda_reg = 1: 0.01715686274511153
# Probando con num_centers = 10 y sigma = 1...
# MSE en conjunto de prueba con num_centers = 10 y sigma = 1 y lambda_reg = 10: 0.017156884534534837
# Probando con num_centers = 10 y sigma = 1...
# MSE en conjunto de prueba con num_centers = 10 y sigma = 1 y lambda_reg = 100: 0.017156864192018947
# Probando con num_centers = 10 y sigma = 2...
# MSE en conjunto de prueba con num_centers = 10 y sigma = 2 y lambda_reg = 0.01: 0.016124101594416754
# Probando con num_centers = 10 y sigma = 2...
# MSE en conjunto de prueba con num_centers = 10 y sigma = 2 y lambda_reg = 1: 0.017137570441906575
# Probando con num_centers = 10 y sigma = 2...
# MSE en conjunto de prueba con num_centers = 10 y sigma = 2 y lambda_reg = 10: 0.017084759174038094
# Probando con num_centers = 10 y sigma = 2...
# MSE en conjunto de prueba con num_centers = 10 y sigma = 2 y lambda_reg = 100: 0.017152326846564064
# Probando con num_centers = 10 y sigma = 4...
# MSE en conjunto de prueba con num_centers = 10 y sigma = 4 y lambda_reg = 0.01: 0.01681596035655217
# Probando con num_centers = 10 y sigma = 4...
# MSE en conjunto de prueba con num_centers = 10 y sigma = 4 y lambda_reg = 1: 0.01707608521823294
# Probando con num_centers = 10 y sigma = 4...
# MSE en conjunto de prueba con num_centers = 10 y sigma = 4 y lambda_reg = 10: 0.016618043341868824
# Probando con num_centers = 10 y sigma = 4...
# MSE en conjunto de prueba con num_centers = 10 y sigma = 4 y lambda_reg = 100: 0.017116121473714073
# Probando con num_centers = 10 y sigma = 8...
# MSE en conjunto de prueba con num_centers = 10 y sigma = 8 y lambda_reg = 0.01: 0.01661911608946834
# Probando con num_centers = 10 y sigma = 8...
# MSE en conjunto de prueba con num_centers = 10 y sigma = 8 y lambda_reg = 1: 0.016833312285903713
# Probando con num_centers = 10 y sigma = 8...
# MSE en conjunto de prueba con num_centers = 10 y sigma = 8 y lambda_reg = 10: 0.016882836795770337
# Probando con num_centers = 10 y sigma = 8...
# MSE en conjunto de prueba con num_centers = 10 y sigma = 8 y lambda_reg = 100: 0.017032608996583817
# Probando con num_centers = 10 y sigma = 16...
# MSE en conjunto de prueba con num_centers = 10 y sigma = 16 y lambda_reg = 0.01: 0.01691515698748461
# Probando con num_centers = 10 y sigma = 16...
# MSE en conjunto de prueba con num_centers = 10 y sigma = 16 y lambda_reg = 1: 0.016748658539571082
# Probando con num_centers = 10 y sigma = 16...
# MSE en conjunto de prueba con num_centers = 10 y sigma = 16 y lambda_reg = 10: 0.016514658147949057
# Probando con num_centers = 10 y sigma = 16...
# MSE en conjunto de prueba con num_centers = 10 y sigma = 16 y lambda_reg = 100: 0.016994477987127277
# Probando con num_centers = 10 y sigma = 32...
# MSE en conjunto de prueba con num_centers = 10 y sigma = 32 y lambda_reg = 0.01: 0.01652185259783325
# Probando con num_centers = 10 y sigma = 32...
# MSE en conjunto de prueba con num_centers = 10 y sigma = 32 y lambda_reg = 1: 0.016646393453461947
# Probando con num_centers = 10 y sigma = 32...
# MSE en conjunto de prueba con num_centers = 10 y sigma = 32 y lambda_reg = 10: 0.016681689681191884
# Probando con num_centers = 10 y sigma = 32...
# MSE en conjunto de prueba con num_centers = 10 y sigma = 32 y lambda_reg = 100: 0.016714946614869046
# Probando con num_centers = 100 y sigma = 1...
# MSE en conjunto de prueba con num_centers = 100 y sigma = 1 y lambda_reg = 0.01: 0.01722874296864597
# Probando con num_centers = 100 y sigma = 1...
# MSE en conjunto de prueba con num_centers = 100 y sigma = 1 y lambda_reg = 1: 0.01681004099752444
# Probando con num_centers = 100 y sigma = 1...
# MSE en conjunto de prueba con num_centers = 100 y sigma = 1 y lambda_reg = 10: 0.017072840594072432
# Probando con num_centers = 100 y sigma = 1...
# MSE en conjunto de prueba con num_centers = 100 y sigma = 1 y lambda_reg = 100: 0.017127152109553
# Probando con num_centers = 100 y sigma = 2...
# MSE en conjunto de prueba con num_centers = 100 y sigma = 2 y lambda_reg = 0.01: 0.01701742466048339
# Probando con num_centers = 100 y sigma = 2...
# MSE en conjunto de prueba con num_centers = 100 y sigma = 2 y lambda_reg = 1: 0.01682379935682093
# Probando con num_centers = 100 y sigma = 2...
# MSE en conjunto de prueba con num_centers = 100 y sigma = 2 y lambda_reg = 10: 0.016475337887357198
# Probando con num_centers = 100 y sigma = 2...
# MSE en conjunto de prueba con num_centers = 100 y sigma = 2 y lambda_reg = 100: 0.01703597585502639
# Probando con num_centers = 100 y sigma = 4...
# MSE en conjunto de prueba con num_centers = 100 y sigma = 4 y lambda_reg = 0.01: 0.01655299733343101
# Probando con num_centers = 100 y sigma = 4...
# MSE en conjunto de prueba con num_centers = 100 y sigma = 4 y lambda_reg = 1: 0.015851467329464495
# Probando con num_centers = 100 y sigma = 4...
# MSE en conjunto de prueba con num_centers = 100 y sigma = 4 y lambda_reg = 10: 0.01642445433232981
# Probando con num_centers = 100 y sigma = 4...
# MSE en conjunto de prueba con num_centers = 100 y sigma = 4 y lambda_reg = 100: 0.016526597767830362
# Probando con num_centers = 100 y sigma = 8...
# MSE en conjunto de prueba con num_centers = 100 y sigma = 8 y lambda_reg = 0.01: 0.0159970814841206
# Probando con num_centers = 100 y sigma = 8...
# MSE en conjunto de prueba con num_centers = 100 y sigma = 8 y lambda_reg = 1: 0.015929515352233012
# Probando con num_centers = 100 y sigma = 8...
# MSE en conjunto de prueba con num_centers = 100 y sigma = 8 y lambda_reg = 10: 0.016090066993796576
# Probando con num_centers = 100 y sigma = 8...
# MSE en conjunto de prueba con num_centers = 100 y sigma = 8 y lambda_reg = 100: 0.016175924948380653
# Probando con num_centers = 100 y sigma = 16...
# MSE en conjunto de prueba con num_centers = 100 y sigma = 16 y lambda_reg = 0.01: 0.016108552340900396
# Probando con num_centers = 100 y sigma = 16...
# MSE en conjunto de prueba con num_centers = 100 y sigma = 16 y lambda_reg = 1: 0.016272484965364774
# Probando con num_centers = 100 y sigma = 16...
# MSE en conjunto de prueba con num_centers = 100 y sigma = 16 y lambda_reg = 10: 0.016310588074339754
# Probando con num_centers = 100 y sigma = 16...
# MSE en conjunto de prueba con num_centers = 100 y sigma = 16 y lambda_reg = 100: 0.016446717183759726
# Probando con num_centers = 100 y sigma = 32...
# MSE en conjunto de prueba con num_centers = 100 y sigma = 32 y lambda_reg = 0.01: 0.016438968154324135
# Probando con num_centers = 100 y sigma = 32...
# MSE en conjunto de prueba con num_centers = 100 y sigma = 32 y lambda_reg = 1: 0.016489913894732224
# Probando con num_centers = 100 y sigma = 32...
# MSE en conjunto de prueba con num_centers = 100 y sigma = 32 y lambda_reg = 10: 0.016520227159821387
# Probando con num_centers = 100 y sigma = 32...
# MSE en conjunto de prueba con num_centers = 100 y sigma = 32 y lambda_reg = 100: 0.01659935693843729
# Probando con num_centers = 1000 y sigma = 1...
# MSE en conjunto de prueba con num_centers = 1000 y sigma = 1 y lambda_reg = 0.01: 0.017156110902052685
# Probando con num_centers = 1000 y sigma = 1...
# MSE en conjunto de prueba con num_centers = 1000 y sigma = 1 y lambda_reg = 1: 0.016186401821441525
# Probando con num_centers = 1000 y sigma = 1...
# MSE en conjunto de prueba con num_centers = 1000 y sigma = 1 y lambda_reg = 10: 0.016697548190750717
# Probando con num_centers = 1000 y sigma = 1...
# MSE en conjunto de prueba con num_centers = 1000 y sigma = 1 y lambda_reg = 100: 0.017074078249387198
# Probando con num_centers = 1000 y sigma = 2...
# MSE en conjunto de prueba con num_centers = 1000 y sigma = 2 y lambda_reg = 0.01: 0.016805085227640147
# Probando con num_centers = 1000 y sigma = 2...
# MSE en conjunto de prueba con num_centers = 1000 y sigma = 2 y lambda_reg = 1: 0.015898152230589494
# Probando con num_centers = 1000 y sigma = 2...
# MSE en conjunto de prueba con num_centers = 1000 y sigma = 2 y lambda_reg = 10: 0.015351993375510789
# Probando con num_centers = 1000 y sigma = 2...
# MSE en conjunto de prueba con num_centers = 1000 y sigma = 2 y lambda_reg = 100: 0.016427044876815813
# Probando con num_centers = 1000 y sigma = 4...
# MSE en conjunto de prueba con num_centers = 1000 y sigma = 4 y lambda_reg = 0.01: 0.015906564646706017
# Probando con num_centers = 1000 y sigma = 4...
# MSE en conjunto de prueba con num_centers = 1000 y sigma = 4 y lambda_reg = 1: 0.015513277600763
# Probando con num_centers = 1000 y sigma = 4...
# MSE en conjunto de prueba con num_centers = 1000 y sigma = 4 y lambda_reg = 10: 0.015419493118604995
# Probando con num_centers = 1000 y sigma = 4...
# MSE en conjunto de prueba con num_centers = 1000 y sigma = 4 y lambda_reg = 100: 0.01579358258113911
# Probando con num_centers = 1000 y sigma = 8...
# MSE en conjunto de prueba con num_centers = 1000 y sigma = 8 y lambda_reg = 0.01: 0.015394828380671783
# Probando con num_centers = 1000 y sigma = 8...
# MSE en conjunto de prueba con num_centers = 1000 y sigma = 8 y lambda_reg = 1: 0.015610465305562399
# Probando con num_centers = 1000 y sigma = 8...
# MSE en conjunto de prueba con num_centers = 1000 y sigma = 8 y lambda_reg = 10: 0.015780196196503893
# Probando con num_centers = 1000 y sigma = 8...
# MSE en conjunto de prueba con num_centers = 1000 y sigma = 8 y lambda_reg = 100: 0.015946069266600853
# Probando con num_centers = 1000 y sigma = 16...
# MSE en conjunto de prueba con num_centers = 1000 y sigma = 16 y lambda_reg = 0.01: 0.015919765001077855
# Probando con num_centers = 1000 y sigma = 16...
# MSE en conjunto de prueba con num_centers = 1000 y sigma = 16 y lambda_reg = 1: 0.016146050581252812
# Probando con num_centers = 1000 y sigma = 16...
# MSE en conjunto de prueba con num_centers = 1000 y sigma = 16 y lambda_reg = 10: 0.01625128672633771
# Probando con num_centers = 1000 y sigma = 16...
# MSE en conjunto de prueba con num_centers = 1000 y sigma = 16 y lambda_reg = 100: 0.016311588432016407
# Probando con num_centers = 1000 y sigma = 32...
# MSE en conjunto de prueba con num_centers = 1000 y sigma = 32 y lambda_reg = 0.01: 0.016443108528257935
# Probando con num_centers = 1000 y sigma = 32...
# MSE en conjunto de prueba con num_centers = 1000 y sigma = 32 y lambda_reg = 1: 0.016461318733196912
# Probando con num_centers = 1000 y sigma = 32...
# MSE en conjunto de prueba con num_centers = 1000 y sigma = 32 y lambda_reg = 10: 0.016486888956340186
# Probando con num_centers = 1000 y sigma = 32...
# MSE en conjunto de prueba con num_centers = 1000 y sigma = 32 y lambda_reg = 100: 0.016525088164092556
# Probando con num_centers = 3000 y sigma = 1...
# MSE en conjunto de prueba con num_centers = 3000 y sigma = 1 y lambda_reg = 0.01: 0.02150389699174295
# Probando con num_centers = 3000 y sigma = 1...
# MSE en conjunto de prueba con num_centers = 3000 y sigma = 1 y lambda_reg = 1: 0.01660075696064837
# Probando con num_centers = 3000 y sigma = 1...
# MSE en conjunto de prueba con num_centers = 3000 y sigma = 1 y lambda_reg = 10: 0.01609040064022367
# Probando con num_centers = 3000 y sigma = 1...
# MSE en conjunto de prueba con num_centers = 3000 y sigma = 1 y lambda_reg = 100: 0.01688318597643875
# Probando con num_centers = 3000 y sigma = 2...
# MSE en conjunto de prueba con num_centers = 3000 y sigma = 2 y lambda_reg = 0.01: 0.020287837453554777
# Probando con num_centers = 3000 y sigma = 2...
# MSE en conjunto de prueba con num_centers = 3000 y sigma = 2 y lambda_reg = 1: 0.016194552443719378
# Probando con num_centers = 3000 y sigma = 2...
# MSE en conjunto de prueba con num_centers = 3000 y sigma = 2 y lambda_reg = 10: 0.015424309684035924
# Probando con num_centers = 3000 y sigma = 2...
# MSE en conjunto de prueba con num_centers = 3000 y sigma = 2 y lambda_reg = 100: 0.015757660644546184
# Probando con num_centers = 3000 y sigma = 4...
# MSE en conjunto de prueba con num_centers = 3000 y sigma = 4 y lambda_reg = 0.01: 0.016009562710107884
# Probando con num_centers = 3000 y sigma = 4...
# MSE en conjunto de prueba con num_centers = 3000 y sigma = 4 y lambda_reg = 1: 0.015657224192949848
# Probando con num_centers = 3000 y sigma = 4...
# MSE en conjunto de prueba con num_centers = 3000 y sigma = 4 y lambda_reg = 10: 0.015379413857644552
# Probando con num_centers = 3000 y sigma = 4...
# MSE en conjunto de prueba con num_centers = 3000 y sigma = 4 y lambda_reg = 100: 0.015468426477998665
# Probando con num_centers = 3000 y sigma = 8...
# MSE en conjunto de prueba con num_centers = 3000 y sigma = 8 y lambda_reg = 0.01: 0.015341418154192689
# Probando con num_centers = 3000 y sigma = 8...
# MSE en conjunto de prueba con num_centers = 3000 y sigma = 8 y lambda_reg = 1: 0.01556769751345924
# Probando con num_centers = 3000 y sigma = 8...
# MSE en conjunto de prueba con num_centers = 3000 y sigma = 8 y lambda_reg = 10: 0.015694723065482606
# Probando con num_centers = 3000 y sigma = 8...
# MSE en conjunto de prueba con num_centers = 3000 y sigma = 8 y lambda_reg = 100: 0.015854999516540163
# Probando con num_centers = 3000 y sigma = 16...
# MSE en conjunto de prueba con num_centers = 3000 y sigma = 16 y lambda_reg = 0.01: 0.015885149186685328
# Probando con num_centers = 3000 y sigma = 16...
# MSE en conjunto de prueba con num_centers = 3000 y sigma = 16 y lambda_reg = 1: 0.016087225853250977
# Probando con num_centers = 3000 y sigma = 16...
# MSE en conjunto de prueba con num_centers = 3000 y sigma = 16 y lambda_reg = 10: 0.016198027148276794
# Probando con num_centers = 3000 y sigma = 16...
# MSE en conjunto de prueba con num_centers = 3000 y sigma = 16 y lambda_reg = 100: 0.016286181881933717
# Probando con num_centers = 3000 y sigma = 32...
# MSE en conjunto de prueba con num_centers = 3000 y sigma = 32 y lambda_reg = 0.01: 0.016433353463270933
# Probando con num_centers = 3000 y sigma = 32...
# MSE en conjunto de prueba con num_centers = 3000 y sigma = 32 y lambda_reg = 1: 0.016449084639769657
# Probando con num_centers = 3000 y sigma = 32...
# MSE en conjunto de prueba con num_centers = 3000 y sigma = 32 y lambda_reg = 10: 0.016474568163362364
# Probando con num_centers = 3000 y sigma = 32...
# MSE en conjunto de prueba con num_centers = 3000 y sigma = 32 y lambda_reg = 100: 0.016503952637827574
# Probando con num_centers = 5508 y sigma = 1...
# MSE en conjunto de prueba con num_centers = 5508 y sigma = 1 y lambda_reg = 0.01: 0.02667551549317741
# Probando con num_centers = 5508 y sigma = 1...
# MSE en conjunto de prueba con num_centers = 5508 y sigma = 1 y lambda_reg = 1: 0.01699514599979522
# Probando con num_centers = 5508 y sigma = 1...
# MSE en conjunto de prueba con num_centers = 5508 y sigma = 1 y lambda_reg = 10: 0.015797747948686307
# Probando con num_centers = 5508 y sigma = 1...
# MSE en conjunto de prueba con num_centers = 5508 y sigma = 1 y lambda_reg = 100: 0.01675530554511544
# Probando con num_centers = 5508 y sigma = 2...
# MSE en conjunto de prueba con num_centers = 5508 y sigma = 2 y lambda_reg = 0.01: 0.021335332412983483
# Probando con num_centers = 5508 y sigma = 2...
# MSE en conjunto de prueba con num_centers = 5508 y sigma = 2 y lambda_reg = 1: 0.016687528350458485
# Probando con num_centers = 5508 y sigma = 2...
# MSE en conjunto de prueba con num_centers = 5508 y sigma = 2 y lambda_reg = 10: 0.015555816570899267
# Probando con num_centers = 5508 y sigma = 2...
# MSE en conjunto de prueba con num_centers = 5508 y sigma = 2 y lambda_reg = 100: 0.015512323059749259
# Probando con num_centers = 5508 y sigma = 4...
# MSE en conjunto de prueba con num_centers = 5508 y sigma = 4 y lambda_reg = 0.01: 0.016087553716588498
# Probando con num_centers = 5508 y sigma = 4...
# MSE en conjunto de prueba con num_centers = 5508 y sigma = 4 y lambda_reg = 1: 0.015702003909251205
# Probando con num_centers = 5508 y sigma = 4...
# MSE en conjunto de prueba con num_centers = 5508 y sigma = 4 y lambda_reg = 10: 0.015411973620375805
# Probando con num_centers = 5508 y sigma = 4...
# MSE en conjunto de prueba con num_centers = 5508 y sigma = 4 y lambda_reg = 100: 0.01537472443035521
# Probando con num_centers = 5508 y sigma = 8...
# MSE en conjunto de prueba con num_centers = 5508 y sigma = 8 y lambda_reg = 0.01: 0.015317605834625252
# Probando con num_centers = 5508 y sigma = 8...
# MSE en conjunto de prueba con num_centers = 5508 y sigma = 8 y lambda_reg = 1: 0.01555180773789245
# Probando con num_centers = 5508 y sigma = 8...
# MSE en conjunto de prueba con num_centers = 5508 y sigma = 8 y lambda_reg = 10: 0.015637929127844397
# Probando con num_centers = 5508 y sigma = 8...
# MSE en conjunto de prueba con num_centers = 5508 y sigma = 8 y lambda_reg = 100: 0.015810356695220622
# Probando con num_centers = 5508 y sigma = 16...
# MSE en conjunto de prueba con num_centers = 5508 y sigma = 16 y lambda_reg = 0.01: 0.015862142248524527
# Probando con num_centers = 5508 y sigma = 16...
# MSE en conjunto de prueba con num_centers = 5508 y sigma = 16 y lambda_reg = 1: 0.016059209787579753
# Probando con num_centers = 5508 y sigma = 16...
# MSE en conjunto de prueba con num_centers = 5508 y sigma = 16 y lambda_reg = 10: 0.016167430015620383
# Probando con num_centers = 5508 y sigma = 16...
# MSE en conjunto de prueba con num_centers = 5508 y sigma = 16 y lambda_reg = 100: 0.016269533012318763
# Probando con num_centers = 5508 y sigma = 32...
# MSE en conjunto de prueba con num_centers = 5508 y sigma = 32 y lambda_reg = 0.01: 0.016420494310445552
# Probando con num_centers = 5508 y sigma = 32...
# MSE en conjunto de prueba con num_centers = 5508 y sigma = 32 y lambda_reg = 1: 0.016443843653885896
# Probando con num_centers = 5508 y sigma = 32...
# MSE en conjunto de prueba con num_centers = 5508 y sigma = 32 y lambda_reg = 10: 0.01646735576815868
# Probando con num_centers = 5508 y sigma = 32...
# MSE en conjunto de prueba con num_centers = 5508 y sigma = 32 y lambda_reg = 100: 0.016495096774455285
# Best alpha:  5508
# Best sigma:  8
# Best lamda_reg:  0.01
# Y_labels:  (9180, 1)
# Datos divididos para la celda (0,1).
# nc1:  550
# alphas:  [1, 10, 100, 1000, 3000, 5508]
# sg:  56.85068161420758
# sigmas:  [1, 2, 4, 8, 16, 32]
# Probando con num_centers = 1 y sigma = 1...
# MSE en conjunto de prueba con num_centers = 1 y sigma = 1 y lambda_reg = 0.01: 0.20915033045956735
# Probando con num_centers = 1 y sigma = 1...
# MSE en conjunto de prueba con num_centers = 1 y sigma = 1 y lambda_reg = 1: 0.2091520180751931
# Probando con num_centers = 1 y sigma = 1...
# MSE en conjunto de prueba con num_centers = 1 y sigma = 1 y lambda_reg = 10: 0.20915032679738563
# Probando con num_centers = 1 y sigma = 1...
# MSE en conjunto de prueba con num_centers = 1 y sigma = 1 y lambda_reg = 100: 0.2091262120890735
# Probando con num_centers = 1 y sigma = 2...
# MSE en conjunto de prueba con num_centers = 1 y sigma = 2 y lambda_reg = 0.01: 0.2072434825548571
# Probando con num_centers = 1 y sigma = 2...
# MSE en conjunto de prueba con num_centers = 1 y sigma = 2 y lambda_reg = 1: 0.20913123464050545
# Probando con num_centers = 1 y sigma = 2...
# MSE en conjunto de prueba con num_centers = 1 y sigma = 2 y lambda_reg = 10: 0.209111475298896
# Probando con num_centers = 1 y sigma = 2...
# MSE en conjunto de prueba con num_centers = 1 y sigma = 2 y lambda_reg = 100: 0.2090763657721284
# Probando con num_centers = 1 y sigma = 4...
# MSE en conjunto de prueba con num_centers = 1 y sigma = 4 y lambda_reg = 0.01: 0.2091515013760474
# Probando con num_centers = 1 y sigma = 4...
# MSE en conjunto de prueba con num_centers = 1 y sigma = 4 y lambda_reg = 1: 0.20904645426663587
# Probando con num_centers = 1 y sigma = 4...
# MSE en conjunto de prueba con num_centers = 1 y sigma = 4 y lambda_reg = 10: 0.2088764350170434
# Probando con num_centers = 1 y sigma = 4...
# MSE en conjunto de prueba con num_centers = 1 y sigma = 4 y lambda_reg = 100: 0.20913146848585346
# Probando con num_centers = 1 y sigma = 8...
# MSE en conjunto de prueba con num_centers = 1 y sigma = 8 y lambda_reg = 0.01: 0.20373850256787032
# Probando con num_centers = 1 y sigma = 8...
# MSE en conjunto de prueba con num_centers = 1 y sigma = 8 y lambda_reg = 1: 0.20814647769248767
# Probando con num_centers = 1 y sigma = 8...
# MSE en conjunto de prueba con num_centers = 1 y sigma = 8 y lambda_reg = 10: 0.20437995780189888
# Probando con num_centers = 1 y sigma = 8...
# MSE en conjunto de prueba con num_centers = 1 y sigma = 8 y lambda_reg = 100: 0.2089997088716402
# Probando con num_centers = 1 y sigma = 16...
# MSE en conjunto de prueba con num_centers = 1 y sigma = 16 y lambda_reg = 0.01: 0.2071264192334775
# Probando con num_centers = 1 y sigma = 16...
# MSE en conjunto de prueba con num_centers = 1 y sigma = 16 y lambda_reg = 1: 0.20790092925880493
# Probando con num_centers = 1 y sigma = 16...
# MSE en conjunto de prueba con num_centers = 1 y sigma = 16 y lambda_reg = 10: 0.19840960314803893
# Probando con num_centers = 1 y sigma = 16...
# MSE en conjunto de prueba con num_centers = 1 y sigma = 16 y lambda_reg = 100: 0.20860697142591608
# Probando con num_centers = 1 y sigma = 32...
# MSE en conjunto de prueba con num_centers = 1 y sigma = 32 y lambda_reg = 0.01: 0.1919385465390018
# Probando con num_centers = 1 y sigma = 32...
# MSE en conjunto de prueba con num_centers = 1 y sigma = 32 y lambda_reg = 1: 0.20046019709698898
# Probando con num_centers = 1 y sigma = 32...
# MSE en conjunto de prueba con num_centers = 1 y sigma = 32 y lambda_reg = 10: 0.19949294877945464
# Probando con num_centers = 1 y sigma = 32...
# MSE en conjunto de prueba con num_centers = 1 y sigma = 32 y lambda_reg = 100: 0.1857568692989878
# Probando con num_centers = 10 y sigma = 1...
# MSE en conjunto de prueba con num_centers = 10 y sigma = 1 y lambda_reg = 0.01: 0.20920301218811524
# Probando con num_centers = 10 y sigma = 1...
# MSE en conjunto de prueba con num_centers = 10 y sigma = 1 y lambda_reg = 1: 0.20788583143659745
# Probando con num_centers = 10 y sigma = 1...
# MSE en conjunto de prueba con num_centers = 10 y sigma = 1 y lambda_reg = 10: 0.2089887972939957
# Probando con num_centers = 10 y sigma = 1...
# MSE en conjunto de prueba con num_centers = 10 y sigma = 1 y lambda_reg = 100: 0.20912020731715322
# Probando con num_centers = 10 y sigma = 2...
# MSE en conjunto de prueba con num_centers = 10 y sigma = 2 y lambda_reg = 0.01: 0.20714144936997772
# Probando con num_centers = 10 y sigma = 2...
# MSE en conjunto de prueba con num_centers = 10 y sigma = 2 y lambda_reg = 1: 0.20598355899838938
# Probando con num_centers = 10 y sigma = 2...
# MSE en conjunto de prueba con num_centers = 10 y sigma = 2 y lambda_reg = 10: 0.20321904328155221
# Probando con num_centers = 10 y sigma = 2...
# MSE en conjunto de prueba con num_centers = 10 y sigma = 2 y lambda_reg = 100: 0.20840627367759135
# Probando con num_centers = 10 y sigma = 4...
# MSE en conjunto de prueba con num_centers = 10 y sigma = 4 y lambda_reg = 0.01: 0.19683606774815102
# Probando con num_centers = 10 y sigma = 4...
# MSE en conjunto de prueba con num_centers = 10 y sigma = 4 y lambda_reg = 1: 0.19786130100823687
# Probando con num_centers = 10 y sigma = 4...
# MSE en conjunto de prueba con num_centers = 10 y sigma = 4 y lambda_reg = 10: 0.20475523455270206
# Probando con num_centers = 10 y sigma = 4...
# MSE en conjunto de prueba con num_centers = 10 y sigma = 4 y lambda_reg = 100: 0.19760941610779104
# Probando con num_centers = 10 y sigma = 8...
# MSE en conjunto de prueba con num_centers = 10 y sigma = 8 y lambda_reg = 0.01: 0.17869046957965737
# Probando con num_centers = 10 y sigma = 8...
# MSE en conjunto de prueba con num_centers = 10 y sigma = 8 y lambda_reg = 1: 0.17626841633032775
# Probando con num_centers = 10 y sigma = 8...
# MSE en conjunto de prueba con num_centers = 10 y sigma = 8 y lambda_reg = 10: 0.19789918802508802
# Probando con num_centers = 10 y sigma = 8...
# MSE en conjunto de prueba con num_centers = 10 y sigma = 8 y lambda_reg = 100: 0.17654683287597311
# Probando con num_centers = 10 y sigma = 16...
# MSE en conjunto de prueba con num_centers = 10 y sigma = 16 y lambda_reg = 0.01: 0.1628743753726939
# Probando con num_centers = 10 y sigma = 16...
# MSE en conjunto de prueba con num_centers = 10 y sigma = 16 y lambda_reg = 1: 0.16420721191101156
# Probando con num_centers = 10 y sigma = 16...
# MSE en conjunto de prueba con num_centers = 10 y sigma = 16 y lambda_reg = 10: 0.16614636555760576
# Probando con num_centers = 10 y sigma = 16...
# MSE en conjunto de prueba con num_centers = 10 y sigma = 16 y lambda_reg = 100: 0.1709935310447233
# Probando con num_centers = 10 y sigma = 32...
# MSE en conjunto de prueba con num_centers = 10 y sigma = 32 y lambda_reg = 0.01: 0.14688769754286832
# Probando con num_centers = 10 y sigma = 32...
# MSE en conjunto de prueba con num_centers = 10 y sigma = 32 y lambda_reg = 1: 0.15937479017121217
# Probando con num_centers = 10 y sigma = 32...
# MSE en conjunto de prueba con num_centers = 10 y sigma = 32 y lambda_reg = 10: 0.1592961467678578
# Probando con num_centers = 10 y sigma = 32...
# MSE en conjunto de prueba con num_centers = 10 y sigma = 32 y lambda_reg = 100: 0.15989091989361295
# Probando con num_centers = 100 y sigma = 1...
# MSE en conjunto de prueba con num_centers = 100 y sigma = 1 y lambda_reg = 0.01: 0.20290240344224197
# Probando con num_centers = 100 y sigma = 1...
# MSE en conjunto de prueba con num_centers = 100 y sigma = 1 y lambda_reg = 1: 0.2031299605783425
# Probando con num_centers = 100 y sigma = 1...
# MSE en conjunto de prueba con num_centers = 100 y sigma = 1 y lambda_reg = 10: 0.20662512814748804
# Probando con num_centers = 100 y sigma = 1...
# MSE en conjunto de prueba con num_centers = 100 y sigma = 1 y lambda_reg = 100: 0.2088397171062821
# Probando con num_centers = 100 y sigma = 2...
# MSE en conjunto de prueba con num_centers = 100 y sigma = 2 y lambda_reg = 0.01: 0.18270141520780867
# Probando con num_centers = 100 y sigma = 2...
# MSE en conjunto de prueba con num_centers = 100 y sigma = 2 y lambda_reg = 1: 0.18118682579319906
# Probando con num_centers = 100 y sigma = 2...
# MSE en conjunto de prueba con num_centers = 100 y sigma = 2 y lambda_reg = 10: 0.1927685623981428
# Probando con num_centers = 100 y sigma = 2...
# MSE en conjunto de prueba con num_centers = 100 y sigma = 2 y lambda_reg = 100: 0.20461803278733073
# Probando con num_centers = 100 y sigma = 4...
# MSE en conjunto de prueba con num_centers = 100 y sigma = 4 y lambda_reg = 0.01: 0.14375021482243244
# Probando con num_centers = 100 y sigma = 4...
# MSE en conjunto de prueba con num_centers = 100 y sigma = 4 y lambda_reg = 1: 0.14507001622770088
# Probando con num_centers = 100 y sigma = 4...
# MSE en conjunto de prueba con num_centers = 100 y sigma = 4 y lambda_reg = 10: 0.16416916619281546
# Probando con num_centers = 100 y sigma = 4...
# MSE en conjunto de prueba con num_centers = 100 y sigma = 4 y lambda_reg = 100: 0.17735877812357823
# Probando con num_centers = 100 y sigma = 8...
# MSE en conjunto de prueba con num_centers = 100 y sigma = 8 y lambda_reg = 0.01: 0.12866416667502714
# Probando con num_centers = 100 y sigma = 8...
# MSE en conjunto de prueba con num_centers = 100 y sigma = 8 y lambda_reg = 1: 0.12926772901573153
# Probando con num_centers = 100 y sigma = 8...
# MSE en conjunto de prueba con num_centers = 100 y sigma = 8 y lambda_reg = 10: 0.12985683435188947
# Probando con num_centers = 100 y sigma = 8...
# MSE en conjunto de prueba con num_centers = 100 y sigma = 8 y lambda_reg = 100: 0.1419881457713199
# Probando con num_centers = 100 y sigma = 16...
# MSE en conjunto de prueba con num_centers = 100 y sigma = 16 y lambda_reg = 0.01: 0.1255433332471014
# Probando con num_centers = 100 y sigma = 16...
# MSE en conjunto de prueba con num_centers = 100 y sigma = 16 y lambda_reg = 1: 0.12628971935014324
# Probando con num_centers = 100 y sigma = 16...
# MSE en conjunto de prueba con num_centers = 100 y sigma = 16 y lambda_reg = 10: 0.12733133485622844
# Probando con num_centers = 100 y sigma = 16...
# MSE en conjunto de prueba con num_centers = 100 y sigma = 16 y lambda_reg = 100: 0.13869685773122506
# Probando con num_centers = 100 y sigma = 32...
# MSE en conjunto de prueba con num_centers = 100 y sigma = 32 y lambda_reg = 0.01: 0.12663259443684402
# Probando con num_centers = 100 y sigma = 32...
# MSE en conjunto de prueba con num_centers = 100 y sigma = 32 y lambda_reg = 1: 0.12873320590962464
# Probando con num_centers = 100 y sigma = 32...
# MSE en conjunto de prueba con num_centers = 100 y sigma = 32 y lambda_reg = 10: 0.1411697328871997
# Probando con num_centers = 100 y sigma = 32...
# MSE en conjunto de prueba con num_centers = 100 y sigma = 32 y lambda_reg = 100: 0.15435999633692826
# Probando con num_centers = 1000 y sigma = 1...
# MSE en conjunto de prueba con num_centers = 1000 y sigma = 1 y lambda_reg = 0.01: 0.17716360867630399
# Probando con num_centers = 1000 y sigma = 1...
# MSE en conjunto de prueba con num_centers = 1000 y sigma = 1 y lambda_reg = 1: 0.16891822267645504
# Probando con num_centers = 1000 y sigma = 1...
# MSE en conjunto de prueba con num_centers = 1000 y sigma = 1 y lambda_reg = 10: 0.19151546447208137
# Probando con num_centers = 1000 y sigma = 1...
# MSE en conjunto de prueba con num_centers = 1000 y sigma = 1 y lambda_reg = 100: 0.206067358755575
# Probando con num_centers = 1000 y sigma = 2...
# MSE en conjunto de prueba con num_centers = 1000 y sigma = 2 y lambda_reg = 0.01: 0.150312890626359
# Probando con num_centers = 1000 y sigma = 2...
# MSE en conjunto de prueba con num_centers = 1000 y sigma = 2 y lambda_reg = 1: 0.13921741038272425
# Probando con num_centers = 1000 y sigma = 2...
# MSE en conjunto de prueba con num_centers = 1000 y sigma = 2 y lambda_reg = 10: 0.14184704092715159
# Probando con num_centers = 1000 y sigma = 2...
# MSE en conjunto de prueba con num_centers = 1000 y sigma = 2 y lambda_reg = 100: 0.17627204339976055
# Probando con num_centers = 1000 y sigma = 4...
# MSE en conjunto de prueba con num_centers = 1000 y sigma = 4 y lambda_reg = 0.01: 0.13524158318752644
# Probando con num_centers = 1000 y sigma = 4...
# MSE en conjunto de prueba con num_centers = 1000 y sigma = 4 y lambda_reg = 1: 0.12911260403147126
# Probando con num_centers = 1000 y sigma = 4...
# MSE en conjunto de prueba con num_centers = 1000 y sigma = 4 y lambda_reg = 10: 0.12768488287853463
# Probando con num_centers = 1000 y sigma = 4...
# MSE en conjunto de prueba con num_centers = 1000 y sigma = 4 y lambda_reg = 100: 0.13378580626822772
# Probando con num_centers = 1000 y sigma = 8...
# MSE en conjunto de prueba con num_centers = 1000 y sigma = 8 y lambda_reg = 0.01: 0.1273489747194484
# Probando con num_centers = 1000 y sigma = 8...
# MSE en conjunto de prueba con num_centers = 1000 y sigma = 8 y lambda_reg = 1: 0.1265616297099248
# Probando con num_centers = 1000 y sigma = 8...
# MSE en conjunto de prueba con num_centers = 1000 y sigma = 8 y lambda_reg = 10: 0.12637191099965522
# Probando con num_centers = 1000 y sigma = 8...
# MSE en conjunto de prueba con num_centers = 1000 y sigma = 8 y lambda_reg = 100: 0.12775447567760873
# Probando con num_centers = 1000 y sigma = 16...
# MSE en conjunto de prueba con num_centers = 1000 y sigma = 16 y lambda_reg = 0.01: 0.12578653505971496
# Probando con num_centers = 1000 y sigma = 16...
# MSE en conjunto de prueba con num_centers = 1000 y sigma = 16 y lambda_reg = 1: 0.12553576704036323
# Probando con num_centers = 1000 y sigma = 16...
# MSE en conjunto de prueba con num_centers = 1000 y sigma = 16 y lambda_reg = 10: 0.1257314464269379
# Probando con num_centers = 1000 y sigma = 16...
# MSE en conjunto de prueba con num_centers = 1000 y sigma = 16 y lambda_reg = 100: 0.1268214197791699
# Probando con num_centers = 1000 y sigma = 32...
# MSE en conjunto de prueba con num_centers = 1000 y sigma = 32 y lambda_reg = 0.01: 0.12618418880940824
# Probando con num_centers = 1000 y sigma = 32...
# MSE en conjunto de prueba con num_centers = 1000 y sigma = 32 y lambda_reg = 1: 0.126770683512158
# Probando con num_centers = 1000 y sigma = 32...
# MSE en conjunto de prueba con num_centers = 1000 y sigma = 32 y lambda_reg = 10: 0.12897011160974847
# Probando con num_centers = 1000 y sigma = 32...
# MSE en conjunto de prueba con num_centers = 1000 y sigma = 32 y lambda_reg = 100: 0.1408345762718232
# Probando con num_centers = 3000 y sigma = 1...
# MSE en conjunto de prueba con num_centers = 3000 y sigma = 1 y lambda_reg = 0.01: 0.18126768048249692
# Probando con num_centers = 3000 y sigma = 1...
# MSE en conjunto de prueba con num_centers = 3000 y sigma = 1 y lambda_reg = 1: 0.15219978238931975
# Probando con num_centers = 3000 y sigma = 1...
# MSE en conjunto de prueba con num_centers = 3000 y sigma = 1 y lambda_reg = 10: 0.16862349482489988
# Probando con num_centers = 3000 y sigma = 1...
# MSE en conjunto de prueba con num_centers = 3000 y sigma = 1 y lambda_reg = 100: 0.20038361366979343
# Probando con num_centers = 3000 y sigma = 2...
# MSE en conjunto de prueba con num_centers = 3000 y sigma = 2 y lambda_reg = 0.01: 0.1622461923223453
# Probando con num_centers = 3000 y sigma = 2...
# MSE en conjunto de prueba con num_centers = 3000 y sigma = 2 y lambda_reg = 1: 0.1395053627823516
# Probando con num_centers = 3000 y sigma = 2...
# MSE en conjunto de prueba con num_centers = 3000 y sigma = 2 y lambda_reg = 10: 0.13375307042849538
# Probando con num_centers = 3000 y sigma = 2...
# MSE en conjunto de prueba con num_centers = 3000 y sigma = 2 y lambda_reg = 100: 0.15305793928366268
# Probando con num_centers = 3000 y sigma = 4...
# MSE en conjunto de prueba con num_centers = 3000 y sigma = 4 y lambda_reg = 0.01: 0.1371376961914385
# Probando con num_centers = 3000 y sigma = 4...
# MSE en conjunto de prueba con num_centers = 3000 y sigma = 4 y lambda_reg = 1: 0.13000019749627312
# Probando con num_centers = 3000 y sigma = 4...
# MSE en conjunto de prueba con num_centers = 3000 y sigma = 4 y lambda_reg = 10: 0.12829022147760316
# Probando con num_centers = 3000 y sigma = 4...
# MSE en conjunto de prueba con num_centers = 3000 y sigma = 4 y lambda_reg = 100: 0.12895643933447434
# Probando con num_centers = 3000 y sigma = 8...
# MSE en conjunto de prueba con num_centers = 3000 y sigma = 8 y lambda_reg = 0.01: 0.12746671905436024
# Probando con num_centers = 3000 y sigma = 8...
# MSE en conjunto de prueba con num_centers = 3000 y sigma = 8 y lambda_reg = 1: 0.1267966739639101
# Probando con num_centers = 3000 y sigma = 8...
# MSE en conjunto de prueba con num_centers = 3000 y sigma = 8 y lambda_reg = 10: 0.12635678670792982
# Probando con num_centers = 3000 y sigma = 8...
# MSE en conjunto de prueba con num_centers = 3000 y sigma = 8 y lambda_reg = 100: 0.12674317925197123
# Probando con num_centers = 3000 y sigma = 16...
# MSE en conjunto de prueba con num_centers = 3000 y sigma = 16 y lambda_reg = 0.01: 0.12585266676902698
# Probando con num_centers = 3000 y sigma = 16...
# MSE en conjunto de prueba con num_centers = 3000 y sigma = 16 y lambda_reg = 1: 0.12550605736543902
# Probando con num_centers = 3000 y sigma = 16...
# MSE en conjunto de prueba con num_centers = 3000 y sigma = 16 y lambda_reg = 10: 0.12561358588137578
# Probando con num_centers = 3000 y sigma = 16...
# MSE en conjunto de prueba con num_centers = 3000 y sigma = 16 y lambda_reg = 100: 0.1261199810074675
# Probando con num_centers = 3000 y sigma = 32...
# MSE en conjunto de prueba con num_centers = 3000 y sigma = 32 y lambda_reg = 0.01: 0.12604967036014847
# Probando con num_centers = 3000 y sigma = 32...
# MSE en conjunto de prueba con num_centers = 3000 y sigma = 32 y lambda_reg = 1: 0.12660198509248183
# Probando con num_centers = 3000 y sigma = 32...
# MSE en conjunto de prueba con num_centers = 3000 y sigma = 32 y lambda_reg = 10: 0.12735482910912516
# Probando con num_centers = 3000 y sigma = 32...
# MSE en conjunto de prueba con num_centers = 3000 y sigma = 32 y lambda_reg = 100: 0.1333220424955544
# Probando con num_centers = 5508 y sigma = 1...
# MSE en conjunto de prueba con num_centers = 5508 y sigma = 1 y lambda_reg = 0.01: 0.2163698293572978
# Probando con num_centers = 5508 y sigma = 1...
# MSE en conjunto de prueba con num_centers = 5508 y sigma = 1 y lambda_reg = 1: 0.14995812187313134
# Probando con num_centers = 5508 y sigma = 1...
# MSE en conjunto de prueba con num_centers = 5508 y sigma = 1 y lambda_reg = 10: 0.15589516663460828
# Probando con num_centers = 5508 y sigma = 1...
# MSE en conjunto de prueba con num_centers = 5508 y sigma = 1 y lambda_reg = 100: 0.1943082569820411
# Probando con num_centers = 5508 y sigma = 2...
# MSE en conjunto de prueba con num_centers = 5508 y sigma = 2 y lambda_reg = 0.01: 0.16989027165040008
# Probando con num_centers = 5508 y sigma = 2...
# MSE en conjunto de prueba con num_centers = 5508 y sigma = 2 y lambda_reg = 1: 0.14248179746212683
# Probando con num_centers = 5508 y sigma = 2...
# MSE en conjunto de prueba con num_centers = 5508 y sigma = 2 y lambda_reg = 10: 0.13363313363828794
# Probando con num_centers = 5508 y sigma = 2...
# MSE en conjunto de prueba con num_centers = 5508 y sigma = 2 y lambda_reg = 100: 0.14226748844374723
# Probando con num_centers = 5508 y sigma = 4...
# MSE en conjunto de prueba con num_centers = 5508 y sigma = 4 y lambda_reg = 0.01: 0.13814703063295683
# Probando con num_centers = 5508 y sigma = 4...
# MSE en conjunto de prueba con num_centers = 5508 y sigma = 4 y lambda_reg = 1: 0.13084660143051818
# Probando con num_centers = 5508 y sigma = 4...
# MSE en conjunto de prueba con num_centers = 5508 y sigma = 4 y lambda_reg = 10: 0.12850684698866596
# Probando con num_centers = 5508 y sigma = 4...
# MSE en conjunto de prueba con num_centers = 5508 y sigma = 4 y lambda_reg = 100: 0.1280197964895855
# Probando con num_centers = 5508 y sigma = 8...
# MSE en conjunto de prueba con num_centers = 5508 y sigma = 8 y lambda_reg = 0.01: 0.1274746505682594
# Probando con num_centers = 5508 y sigma = 8...
# MSE en conjunto de prueba con num_centers = 5508 y sigma = 8 y lambda_reg = 1: 0.12696447862909568
# Probando con num_centers = 5508 y sigma = 8...
# MSE en conjunto de prueba con num_centers = 5508 y sigma = 8 y lambda_reg = 10: 0.12638333524629747
# Probando con num_centers = 5508 y sigma = 8...
# MSE en conjunto de prueba con num_centers = 5508 y sigma = 8 y lambda_reg = 100: 0.12645436601636675
# Probando con num_centers = 5508 y sigma = 16...
# MSE en conjunto de prueba con num_centers = 5508 y sigma = 16 y lambda_reg = 0.01: 0.12597071929364959
# Probando con num_centers = 5508 y sigma = 16...
# MSE en conjunto de prueba con num_centers = 5508 y sigma = 16 y lambda_reg = 1: 0.12550610514731164
# Probando con num_centers = 5508 y sigma = 16...
# MSE en conjunto de prueba con num_centers = 5508 y sigma = 16 y lambda_reg = 10: 0.12555299264364492
# Probando con num_centers = 5508 y sigma = 16...
# MSE en conjunto de prueba con num_centers = 5508 y sigma = 16 y lambda_reg = 100: 0.12589244731859675
# Probando con num_centers = 5508 y sigma = 32...
# MSE en conjunto de prueba con num_centers = 5508 y sigma = 32 y lambda_reg = 0.01: 0.12597884539784704
# Probando con num_centers = 5508 y sigma = 32...
# MSE en conjunto de prueba con num_centers = 5508 y sigma = 32 y lambda_reg = 1: 0.12653450020919338
# Probando con num_centers = 5508 y sigma = 32...
# MSE en conjunto de prueba con num_centers = 5508 y sigma = 32 y lambda_reg = 10: 0.12699286277295765
# Probando con num_centers = 5508 y sigma = 32...
# MSE en conjunto de prueba con num_centers = 5508 y sigma = 32 y lambda_reg = 100: 0.13057681684079459
# Best alpha:  3000
# Best sigma:  16
# Best lamda_reg:  1
# Y_labels:  (9180, 1)
# Datos divididos para la celda (0,2).
# nc1:  550
# alphas:  [1, 10, 100, 1000, 3000, 5508]
# sg:  56.85068161420758
# sigmas:  [1, 2, 4, 8, 16, 32]
# Probando con num_centers = 1 y sigma = 1...
# MSE en conjunto de prueba con num_centers = 1 y sigma = 1 y lambda_reg = 0.01: 0.35087799546013304
# Probando con num_centers = 1 y sigma = 1...
# MSE en conjunto de prueba con num_centers = 1 y sigma = 1 y lambda_reg = 1: 0.3510348427247221
# Probando con num_centers = 1 y sigma = 1...
# MSE en conjunto de prueba con num_centers = 1 y sigma = 1 y lambda_reg = 10: 0.3510292697081607
# Probando con num_centers = 1 y sigma = 1...
# MSE en conjunto de prueba con num_centers = 1 y sigma = 1 y lambda_reg = 100: 0.3510348510455294
# Probando con num_centers = 1 y sigma = 2...
# MSE en conjunto de prueba con num_centers = 1 y sigma = 2 y lambda_reg = 0.01: 0.3507726074205846
# Probando con num_centers = 1 y sigma = 2...
# MSE en conjunto de prueba con num_centers = 1 y sigma = 2 y lambda_reg = 1: 0.3510348583877996
# Probando con num_centers = 1 y sigma = 2...
# MSE en conjunto de prueba con num_centers = 1 y sigma = 2 y lambda_reg = 10: 0.348145050524477
# Probando con num_centers = 1 y sigma = 2...
# MSE en conjunto de prueba con num_centers = 1 y sigma = 2 y lambda_reg = 100: 0.35103483820670783
# Probando con num_centers = 1 y sigma = 4...
# MSE en conjunto de prueba con num_centers = 1 y sigma = 4 y lambda_reg = 0.01: 0.3461471773535538
# Probando con num_centers = 1 y sigma = 4...
# MSE en conjunto de prueba con num_centers = 1 y sigma = 4 y lambda_reg = 1: 0.34348833526626793
# Probando con num_centers = 1 y sigma = 4...
# MSE en conjunto de prueba con num_centers = 1 y sigma = 4 y lambda_reg = 10: 0.34737985744885197
# Probando con num_centers = 1 y sigma = 4...
# MSE en conjunto de prueba con num_centers = 1 y sigma = 4 y lambda_reg = 100: 0.3510347878533063
# Probando con num_centers = 1 y sigma = 8...
# MSE en conjunto de prueba con num_centers = 1 y sigma = 8 y lambda_reg = 0.01: 0.3507531728423008
# Probando con num_centers = 1 y sigma = 8...
# MSE en conjunto de prueba con num_centers = 1 y sigma = 8 y lambda_reg = 1: 0.34047311792289725
# Probando con num_centers = 1 y sigma = 8...
# MSE en conjunto de prueba con num_centers = 1 y sigma = 8 y lambda_reg = 10: 0.3497209465585551
# Probando con num_centers = 1 y sigma = 8...
# MSE en conjunto de prueba con num_centers = 1 y sigma = 8 y lambda_reg = 100: 0.34925365802698183
# Probando con num_centers = 1 y sigma = 16...
# MSE en conjunto de prueba con num_centers = 1 y sigma = 16 y lambda_reg = 0.01: 0.34896626112442747
# Probando con num_centers = 1 y sigma = 16...
# MSE en conjunto de prueba con num_centers = 1 y sigma = 16 y lambda_reg = 1: 0.3121189374137495
# Probando con num_centers = 1 y sigma = 16...
# MSE en conjunto de prueba con num_centers = 1 y sigma = 16 y lambda_reg = 10: 0.3490018892427574
# Probando con num_centers = 1 y sigma = 16...
# MSE en conjunto de prueba con num_centers = 1 y sigma = 16 y lambda_reg = 100: 0.33797126039351044
# Probando con num_centers = 1 y sigma = 32...
# MSE en conjunto de prueba con num_centers = 1 y sigma = 32 y lambda_reg = 0.01: 0.27923424421991033
# Probando con num_centers = 1 y sigma = 32...
# MSE en conjunto de prueba con num_centers = 1 y sigma = 32 y lambda_reg = 1: 0.3240274622791503
# Probando con num_centers = 1 y sigma = 32...
# MSE en conjunto de prueba con num_centers = 1 y sigma = 32 y lambda_reg = 10: 0.2919299030661289
# Probando con num_centers = 1 y sigma = 32...
# MSE en conjunto de prueba con num_centers = 1 y sigma = 32 y lambda_reg = 100: 0.2775287401724528
# Probando con num_centers = 10 y sigma = 1...
# MSE en conjunto de prueba con num_centers = 10 y sigma = 1 y lambda_reg = 0.01: 0.3458699602274784
# Probando con num_centers = 10 y sigma = 1...
# MSE en conjunto de prueba con num_centers = 10 y sigma = 1 y lambda_reg = 1: 0.3491332922954427
# Probando con num_centers = 10 y sigma = 1...
# MSE en conjunto de prueba con num_centers = 10 y sigma = 1 y lambda_reg = 10: 0.34977742102252596
# Probando con num_centers = 10 y sigma = 1...
# MSE en conjunto de prueba con num_centers = 10 y sigma = 1 y lambda_reg = 100: 0.3509575684047949
# Probando con num_centers = 10 y sigma = 2...
# MSE en conjunto de prueba con num_centers = 10 y sigma = 2 y lambda_reg = 0.01: 0.3434683533933057
# Probando con num_centers = 10 y sigma = 2...
# MSE en conjunto de prueba con num_centers = 10 y sigma = 2 y lambda_reg = 1: 0.3442637968643249
# Probando con num_centers = 10 y sigma = 2...
# MSE en conjunto de prueba con num_centers = 10 y sigma = 2 y lambda_reg = 10: 0.34118635807153397
# Probando con num_centers = 10 y sigma = 2...
# MSE en conjunto de prueba con num_centers = 10 y sigma = 2 y lambda_reg = 100: 0.3501627821907265
# Probando con num_centers = 10 y sigma = 4...
# MSE en conjunto de prueba con num_centers = 10 y sigma = 4 y lambda_reg = 0.01: 0.3143910335736689
# Probando con num_centers = 10 y sigma = 4...
# MSE en conjunto de prueba con num_centers = 10 y sigma = 4 y lambda_reg = 1: 0.3236919430500244
# Probando con num_centers = 10 y sigma = 4...
# MSE en conjunto de prueba con num_centers = 10 y sigma = 4 y lambda_reg = 10: 0.30167268806396286
# Probando con num_centers = 10 y sigma = 4...
# MSE en conjunto de prueba con num_centers = 10 y sigma = 4 y lambda_reg = 100: 0.3349871811115198
# Probando con num_centers = 10 y sigma = 8...
# ...
# Probando con num_centers = 10 y sigma = 8...
# MSE en conjunto de prueba con num_centers = 10 y sigma = 8 y lambda_reg = 0.01: 0.35345984074247694
# Probando con num_centers = 10 y sigma = 8...
# MSE en conjunto de prueba con num_centers = 10 y sigma = 8 y lambda_reg = 1: 0.36640080996925517
# Probando con num_centers = 10 y sigma = 8...
# MSE en conjunto de prueba con num_centers = 10 y sigma = 8 y lambda_reg = 10: 0.35565046678066137
# Probando con num_centers = 10 y sigma = 8...
# MSE en conjunto de prueba con num_centers = 10 y sigma = 8 y lambda_reg = 100: 0.36034137998101706
# Probando con num_centers = 10 y sigma = 16...
# MSE en conjunto de prueba con num_centers = 10 y sigma = 16 y lambda_reg = 0.01: 0.27451907206069176
# Probando con num_centers = 10 y sigma = 16...
# MSE en conjunto de prueba con num_centers = 10 y sigma = 16 y lambda_reg = 1: 0.29568719213666794
# Probando con num_centers = 10 y sigma = 16...
# MSE en conjunto de prueba con num_centers = 10 y sigma = 16 y lambda_reg = 10: 0.27620447138019605
# Probando con num_centers = 10 y sigma = 16...
# MSE en conjunto de prueba con num_centers = 10 y sigma = 16 y lambda_reg = 100: 0.29454706513760653
# Probando con num_centers = 10 y sigma = 32...
# MSE en conjunto de prueba con num_centers = 10 y sigma = 32 y lambda_reg = 0.01: 0.24735858468568825
# Probando con num_centers = 10 y sigma = 32...
# MSE en conjunto de prueba con num_centers = 10 y sigma = 32 y lambda_reg = 1: 0.25573572761089053
# Probando con num_centers = 10 y sigma = 32...
# MSE en conjunto de prueba con num_centers = 10 y sigma = 32 y lambda_reg = 10: 0.25394280151070436
# Probando con num_centers = 10 y sigma = 32...
# MSE en conjunto de prueba con num_centers = 10 y sigma = 32 y lambda_reg = 100: 0.2593921241516446
# Probando con num_centers = 100 y sigma = 1...
# MSE en conjunto de prueba con num_centers = 100 y sigma = 1 y lambda_reg = 0.01: 0.4160073958481312
# Probando con num_centers = 100 y sigma = 1...
# MSE en conjunto de prueba con num_centers = 100 y sigma = 1 y lambda_reg = 1: 0.4167633379539805
# Probando con num_centers = 100 y sigma = 1...
# MSE en conjunto de prueba con num_centers = 100 y sigma = 1 y lambda_reg = 10: 0.4358704534845056
# Probando con num_centers = 100 y sigma = 1...
# MSE en conjunto de prueba con num_centers = 100 y sigma = 1 y lambda_reg = 100: 0.4426461773699966
# Probando con num_centers = 100 y sigma = 2...
# MSE en conjunto de prueba con num_centers = 100 y sigma = 2 y lambda_reg = 0.01: 0.364759351117395
# Probando con num_centers = 100 y sigma = 2...
# MSE en conjunto de prueba con num_centers = 100 y sigma = 2 y lambda_reg = 1: 0.3584781516514974
# Probando con num_centers = 100 y sigma = 2...
# MSE en conjunto de prueba con num_centers = 100 y sigma = 2 y lambda_reg = 10: 0.38965235440660106
# Probando con num_centers = 100 y sigma = 2...
# MSE en conjunto de prueba con num_centers = 100 y sigma = 2 y lambda_reg = 100: 0.42835422249931004
# Probando con num_centers = 100 y sigma = 4...
# MSE en conjunto de prueba con num_centers = 100 y sigma = 4 y lambda_reg = 0.01: 0.27002875770921475
# Probando con num_centers = 100 y sigma = 4...
# MSE en conjunto de prueba con num_centers = 100 y sigma = 4 y lambda_reg = 1: 0.27633507207770514
# Probando con num_centers = 100 y sigma = 4...
# MSE en conjunto de prueba con num_centers = 100 y sigma = 4 y lambda_reg = 10: 0.26728653263706176
# Probando con num_centers = 100 y sigma = 4...
# MSE en conjunto de prueba con num_centers = 100 y sigma = 4 y lambda_reg = 100: 0.337681679127925
# Probando con num_centers = 100 y sigma = 8...
# MSE en conjunto de prueba con num_centers = 100 y sigma = 8 y lambda_reg = 0.01: 0.23019687796619367
# Probando con num_centers = 100 y sigma = 8...
# MSE en conjunto de prueba con num_centers = 100 y sigma = 8 y lambda_reg = 1: 0.23282313469266425
# Probando con num_centers = 100 y sigma = 8...
# MSE en conjunto de prueba con num_centers = 100 y sigma = 8 y lambda_reg = 10: 0.23745124243481355
# Probando con num_centers = 100 y sigma = 8...
# MSE en conjunto de prueba con num_centers = 100 y sigma = 8 y lambda_reg = 100: 0.24961498277466726
# Probando con num_centers = 100 y sigma = 16...
# MSE en conjunto de prueba con num_centers = 100 y sigma = 16 y lambda_reg = 0.01: 0.23315409986244937
# Probando con num_centers = 100 y sigma = 16...
# MSE en conjunto de prueba con num_centers = 100 y sigma = 16 y lambda_reg = 1: 0.2369593193581777
# Probando con num_centers = 100 y sigma = 16...
# MSE en conjunto de prueba con num_centers = 100 y sigma = 16 y lambda_reg = 10: 0.23968066357490808
# Probando con num_centers = 100 y sigma = 16...
# MSE en conjunto de prueba con num_centers = 100 y sigma = 16 y lambda_reg = 100: 0.2440744932209723
# Probando con num_centers = 100 y sigma = 32...
# MSE en conjunto de prueba con num_centers = 100 y sigma = 32 y lambda_reg = 0.01: 0.24163570087423142
# Probando con num_centers = 100 y sigma = 32...
# MSE en conjunto de prueba con num_centers = 100 y sigma = 32 y lambda_reg = 1: 0.24184305690002558
# Probando con num_centers = 100 y sigma = 32...
# MSE en conjunto de prueba con num_centers = 100 y sigma = 32 y lambda_reg = 10: 0.24423626931208614
# Probando con num_centers = 100 y sigma = 32...
# MSE en conjunto de prueba con num_centers = 100 y sigma = 32 y lambda_reg = 100: 0.25058887722071405
# Probando con num_centers = 1000 y sigma = 1...
# MSE en conjunto de prueba con num_centers = 1000 y sigma = 1 y lambda_reg = 0.01: 0.2769840803796441
# Probando con num_centers = 1000 y sigma = 1...
# MSE en conjunto de prueba con num_centers = 1000 y sigma = 1 y lambda_reg = 1: 0.2849063088672434
# Probando con num_centers = 1000 y sigma = 1...
# MSE en conjunto de prueba con num_centers = 1000 y sigma = 1 y lambda_reg = 10: 0.3753750150235676
# Probando con num_centers = 1000 y sigma = 1...
# MSE en conjunto de prueba con num_centers = 1000 y sigma = 1 y lambda_reg = 100: 0.4324241431347201
# Probando con num_centers = 1000 y sigma = 2...
# MSE en conjunto de prueba con num_centers = 1000 y sigma = 2 y lambda_reg = 0.01: 0.17304912619528112
# Probando con num_centers = 1000 y sigma = 2...
# MSE en conjunto de prueba con num_centers = 1000 y sigma = 2 y lambda_reg = 1: 0.17983861927137332
# Probando con num_centers = 1000 y sigma = 2...
# MSE en conjunto de prueba con num_centers = 1000 y sigma = 2 y lambda_reg = 10: 0.2190912646738616
# Probando con num_centers = 1000 y sigma = 2...
# MSE en conjunto de prueba con num_centers = 1000 y sigma = 2 y lambda_reg = 100: 0.33643082986956246
# Probando con num_centers = 1000 y sigma = 4...
# MSE en conjunto de prueba con num_centers = 1000 y sigma = 4 y lambda_reg = 0.01: 0.17943330047024922
# Probando con num_centers = 1000 y sigma = 4...
# MSE en conjunto de prueba con num_centers = 1000 y sigma = 4 y lambda_reg = 1: 0.19297579041343024
# Probando con num_centers = 1000 y sigma = 4...
# MSE en conjunto de prueba con num_centers = 1000 y sigma = 4 y lambda_reg = 10: 0.20476842523230476
# Probando con num_centers = 1000 y sigma = 4...
# MSE en conjunto de prueba con num_centers = 1000 y sigma = 4 y lambda_reg = 100: 0.2267425376736877
# Probando con num_centers = 1000 y sigma = 8...
# MSE en conjunto de prueba con num_centers = 1000 y sigma = 8 y lambda_reg = 0.01: 0.21017956186891423
# Probando con num_centers = 1000 y sigma = 8...
# MSE en conjunto de prueba con num_centers = 1000 y sigma = 8 y lambda_reg = 1: 0.22173203396904742
# Probando con num_centers = 1000 y sigma = 8...
# MSE en conjunto de prueba con num_centers = 1000 y sigma = 8 y lambda_reg = 10: 0.2270272783081623
# Probando con num_centers = 1000 y sigma = 8...
# MSE en conjunto de prueba con num_centers = 1000 y sigma = 8 y lambda_reg = 100: 0.2314270106448772
# Probando con num_centers = 1000 y sigma = 16...
# MSE en conjunto de prueba con num_centers = 1000 y sigma = 16 y lambda_reg = 0.01: 0.23242693639505632
# Probando con num_centers = 1000 y sigma = 16...
# MSE en conjunto de prueba con num_centers = 1000 y sigma = 16 y lambda_reg = 1: 0.23355732582078167
# Probando con num_centers = 1000 y sigma = 16...
# MSE en conjunto de prueba con num_centers = 1000 y sigma = 16 y lambda_reg = 10: 0.23618013720246878
# Probando con num_centers = 1000 y sigma = 16...
# MSE en conjunto de prueba con num_centers = 1000 y sigma = 16 y lambda_reg = 100: 0.23860936365143892
# Probando con num_centers = 1000 y sigma = 32...
# MSE en conjunto de prueba con num_centers = 1000 y sigma = 32 y lambda_reg = 0.01: 0.24125263362517152
# Probando con num_centers = 1000 y sigma = 32...
# MSE en conjunto de prueba con num_centers = 1000 y sigma = 32 y lambda_reg = 1: 0.24157712699804076
# Probando con num_centers = 1000 y sigma = 32...
# MSE en conjunto de prueba con num_centers = 1000 y sigma = 32 y lambda_reg = 10: 0.2418431426905952
# Probando con num_centers = 1000 y sigma = 32...
# MSE en conjunto de prueba con num_centers = 1000 y sigma = 32 y lambda_reg = 100: 0.24440905496947699
# Probando con num_centers = 3000 y sigma = 1...
# MSE en conjunto de prueba con num_centers = 3000 y sigma = 1 y lambda_reg = 0.01: 0.21431341642129367
# Probando con num_centers = 3000 y sigma = 1...
# MSE en conjunto de prueba con num_centers = 3000 y sigma = 1 y lambda_reg = 1: 0.19470803615981017
# Probando con num_centers = 3000 y sigma = 1...
# MSE en conjunto de prueba con num_centers = 3000 y sigma = 1 y lambda_reg = 10: 0.2868575598584518
# Probando con num_centers = 3000 y sigma = 1...
# MSE en conjunto de prueba con num_centers = 3000 y sigma = 1 y lambda_reg = 100: 0.4119228170528418
# Probando con num_centers = 3000 y sigma = 2...
# MSE en conjunto de prueba con num_centers = 3000 y sigma = 2 y lambda_reg = 0.01: 0.173105278086364
# Probando con num_centers = 3000 y sigma = 2...
# MSE en conjunto de prueba con num_centers = 3000 y sigma = 2 y lambda_reg = 1: 0.15621426794154714
# Probando con num_centers = 3000 y sigma = 2...
# MSE en conjunto de prueba con num_centers = 3000 y sigma = 2 y lambda_reg = 10: 0.17689682481101868
# Probando con num_centers = 3000 y sigma = 2...
# MSE en conjunto de prueba con num_centers = 3000 y sigma = 2 y lambda_reg = 100: 0.2593576576218661
# Probando con num_centers = 3000 y sigma = 4...
# MSE en conjunto de prueba con num_centers = 3000 y sigma = 4 y lambda_reg = 0.01: 0.1746504333043061
# Probando con num_centers = 3000 y sigma = 4...
# MSE en conjunto de prueba con num_centers = 3000 y sigma = 4 y lambda_reg = 1: 0.1858167213602372
# Probando con num_centers = 3000 y sigma = 4...
# MSE en conjunto de prueba con num_centers = 3000 y sigma = 4 y lambda_reg = 10: 0.19621051413122917
# Probando con num_centers = 3000 y sigma = 4...
# MSE en conjunto de prueba con num_centers = 3000 y sigma = 4 y lambda_reg = 100: 0.2110632951759982
# Probando con num_centers = 3000 y sigma = 8...
# MSE en conjunto de prueba con num_centers = 3000 y sigma = 8 y lambda_reg = 0.01: 0.20720885378877546
# Probando con num_centers = 3000 y sigma = 8...
# MSE en conjunto de prueba con num_centers = 3000 y sigma = 8 y lambda_reg = 1: 0.21865075735476955
# Probando con num_centers = 3000 y sigma = 8...
# MSE en conjunto de prueba con num_centers = 3000 y sigma = 8 y lambda_reg = 10: 0.22361783274823976
# Probando con num_centers = 3000 y sigma = 8...
# MSE en conjunto de prueba con num_centers = 3000 y sigma = 8 y lambda_reg = 100: 0.22938851181808195
# Probando con num_centers = 3000 y sigma = 16...
# MSE en conjunto de prueba con num_centers = 3000 y sigma = 16 y lambda_reg = 0.01: 0.23208279285904845
# Probando con num_centers = 3000 y sigma = 16...
# MSE en conjunto de prueba con num_centers = 3000 y sigma = 16 y lambda_reg = 1: 0.23316492201692277
# Probando con num_centers = 3000 y sigma = 16...
# MSE en conjunto de prueba con num_centers = 3000 y sigma = 16 y lambda_reg = 10: 0.23455993428622895
# Probando con num_centers = 3000 y sigma = 16...
# MSE en conjunto de prueba con num_centers = 3000 y sigma = 16 y lambda_reg = 100: 0.23753373421582982
# Probando con num_centers = 3000 y sigma = 32...
# MSE en conjunto de prueba con num_centers = 3000 y sigma = 32 y lambda_reg = 0.01: 0.24046883923646653
# Probando con num_centers = 3000 y sigma = 32...
# MSE en conjunto de prueba con num_centers = 3000 y sigma = 32 y lambda_reg = 1: 0.24162930743837605
# Probando con num_centers = 3000 y sigma = 32...
# MSE en conjunto de prueba con num_centers = 3000 y sigma = 32 y lambda_reg = 10: 0.24160941771312663
# Probando con num_centers = 3000 y sigma = 32...
# MSE en conjunto de prueba con num_centers = 3000 y sigma = 32 y lambda_reg = 100: 0.24260617996077327
# Probando con num_centers = 5508 y sigma = 1...
# MSE en conjunto de prueba con num_centers = 5508 y sigma = 1 y lambda_reg = 0.01: 0.23745641839534165
# Probando con num_centers = 5508 y sigma = 1...
# MSE en conjunto de prueba con num_centers = 5508 y sigma = 1 y lambda_reg = 1: 0.1743804927313065
# Probando con num_centers = 5508 y sigma = 1...
# MSE en conjunto de prueba con num_centers = 5508 y sigma = 1 y lambda_reg = 10: 0.24141861047376903
# Probando con num_centers = 5508 y sigma = 1...
# MSE en conjunto de prueba con num_centers = 5508 y sigma = 1 y lambda_reg = 100: 0.3898532536722255
# Probando con num_centers = 5508 y sigma = 2...
# MSE en conjunto de prueba con num_centers = 5508 y sigma = 2 y lambda_reg = 0.01: 0.18155073169496566
# Probando con num_centers = 5508 y sigma = 2...
# MSE en conjunto de prueba con num_centers = 5508 y sigma = 2 y lambda_reg = 1: 0.15472352789734314
# Probando con num_centers = 5508 y sigma = 2...
# MSE en conjunto de prueba con num_centers = 5508 y sigma = 2 y lambda_reg = 10: 0.16607289493659222
# Probando con num_centers = 5508 y sigma = 2...
# MSE en conjunto de prueba con num_centers = 5508 y sigma = 2 y lambda_reg = 100: 0.2218733682616741
# Probando con num_centers = 5508 y sigma = 4...
# MSE en conjunto de prueba con num_centers = 5508 y sigma = 4 y lambda_reg = 0.01: 0.1731201302203296
# Probando con num_centers = 5508 y sigma = 4...
# MSE en conjunto de prueba con num_centers = 5508 y sigma = 4 y lambda_reg = 1: 0.18272332578321293
# Probando con num_centers = 5508 y sigma = 4...
# MSE en conjunto de prueba con num_centers = 5508 y sigma = 4 y lambda_reg = 10: 0.19278650986027754
# Probando con num_centers = 5508 y sigma = 4...
# MSE en conjunto de prueba con num_centers = 5508 y sigma = 4 y lambda_reg = 100: 0.2059957932278965
# Probando con num_centers = 5508 y sigma = 8...
# MSE en conjunto de prueba con num_centers = 5508 y sigma = 8 y lambda_reg = 0.01: 0.2059663728574514
# Probando con num_centers = 5508 y sigma = 8...
# MSE en conjunto de prueba con num_centers = 5508 y sigma = 8 y lambda_reg = 1: 0.21720915453523088
# Probando con num_centers = 5508 y sigma = 8...
# MSE en conjunto de prueba con num_centers = 5508 y sigma = 8 y lambda_reg = 10: 0.22213620574888884
# Probando con num_centers = 5508 y sigma = 8...
# MSE en conjunto de prueba con num_centers = 5508 y sigma = 8 y lambda_reg = 100: 0.22812442787959913
# Probando con num_centers = 5508 y sigma = 16...
# MSE en conjunto de prueba con num_centers = 5508 y sigma = 16 y lambda_reg = 0.01: 0.23186126905786988
# Probando con num_centers = 5508 y sigma = 16...
# MSE en conjunto de prueba con num_centers = 5508 y sigma = 16 y lambda_reg = 1: 0.23303115851765172
# Probando con num_centers = 5508 y sigma = 16...
# MSE en conjunto de prueba con num_centers = 5508 y sigma = 16 y lambda_reg = 10: 0.23394642403030189
# Probando con num_centers = 5508 y sigma = 16...
# MSE en conjunto de prueba con num_centers = 5508 y sigma = 16 y lambda_reg = 100: 0.23683684244884082
# Probando con num_centers = 5508 y sigma = 32...
# MSE en conjunto de prueba con num_centers = 5508 y sigma = 32 y lambda_reg = 0.01: 0.23973941184236633
# Probando con num_centers = 5508 y sigma = 32...
# MSE en conjunto de prueba con num_centers = 5508 y sigma = 32 y lambda_reg = 1: 0.24165609366672067
# Probando con num_centers = 5508 y sigma = 32...
# MSE en conjunto de prueba con num_centers = 5508 y sigma = 32 y lambda_reg = 10: 0.24157333238616946
# Probando con num_centers = 5508 y sigma = 32...
# MSE en conjunto de prueba con num_centers = 5508 y sigma = 32 y lambda_reg = 100: 0.24211381121586045
# Best alpha:  5508
# Best sigma:  2
# Best lamda_reg:  1

# %% [markdown]
# Guardar datos

# %%
# Display results
print("Resultados de las métricas para la celda (0,0):")
print(f"Celda (0,0): MSE={mse_metrics[0, 0]}, MAE={mae_metrics[0, 0]}, R2={r2_metrics[0, 0]}")

# Display results
print("Resultados de las métricas para la celda (0,1):")
print(f"Celda (0,1): MSE={mse_metrics[0, 1]}, MAE={mae_metrics[0, 1]}, R2={r2_metrics[0, 1]}")

# Display results
print("Resultados de las métricas para la celda (0,2):")
print(f"Celda (0,2): MSE={mse_metrics[0, 2]}, MAE={mae_metrics[0, 2]}, R2={r2_metrics[0, 2]}")

print(f"mse_metrics: ", mse_metrics)
print(f"mae_metrics: ", mae_metrics)
print(f"r2_metrics: ", r2_metrics)

print(f"predictions: ", predicciones_100_RBFs)
# Out:
# Resultados de las métricas para la celda (0,0):
# Celda (0,0): MSE=0.015317605834625303, MAE=0.039307966759179344, R2=0.09161740731917833
# Resultados de las métricas para la celda (0,1):
# Celda (0,1): MSE=0.12550143726923624, MAE=0.2576747080495453, R2=0.24125435303833898
# Resultados de las métricas para la celda (0,2):
# Celda (0,2): MSE=0.12338909193650854, MAE=0.2535864420136543, R2=0.4583669541168628
# mse_metrics:  [[0.01531761 0.12550144 0.12338909 0.14063117 0.13305908 0.13958979
#   0.1467954  0.14775038 0.1469687  0.15034796]
#  [0.12611238 0.13576589 0.13236251 0.13939128 0.13943457 0.14769773
#   0.14336008 0.14611586 0.15311694 0.15776621]
#  [0.12527776 0.13098247 0.13879626 0.1333973  0.14104529 0.14632168
#   0.14842866 0.14286125 0.1455527  0.15192578]
#  [0.14164601 0.13517801 0.13922426 0.14827555 0.14232394 0.14384388
#   0.14559873 0.14501184 0.15461306 0.15918009]
#  [0.13978435 0.14432741 0.13656241 0.14436078 0.14480712 0.13992788
#   0.14501051 0.14666238 0.15257631 0.15228246]
#  [0.14213515 0.14441243 0.1368906  0.14333267 0.14367648 0.14755535
#   0.14717053 0.14648448 0.15212417 0.16166554]
#  [0.14032778 0.1372117  0.14161806 0.14701863 0.14240602 0.14691823
#   0.14861554 0.15625035 0.14962614 0.15877811]
#  [0.14786331 0.14663448 0.14435661 0.15198902 0.14834092 0.15426929
#   0.15453551 0.15521676 0.1564197  0.16087403]
#  [0.13774538 0.14628796 0.1429698  0.15051612 0.1486544  0.15567376
#   0.15726415 0.16055176 0.1502255  0.15859011]
#  [0.14890437 0.15203107 0.15445778 0.15443345 0.14932136 0.1513488
#   0.15542134 0.16358336 0.15953808 0.15472353]]
# mae_metrics:  [[0.03930797 0.25767471 0.25358644 0.28178208 0.26996937 0.29001746
#   0.29821139 0.29435926 0.30147805 0.3013653 ]
#  [0.25925615 0.27576484 0.26797115 0.28842039 0.28530032 0.29405085
#   0.29970297 0.29654286 0.30808036 0.30966856]
#  [0.25614463 0.26944396 0.27393816 0.26753442 0.28514275 0.29203979
#   0.2990868  0.2914711  0.30372672 0.309376  ]
#  [0.28951475 0.27325988 0.27291428 0.29597728 0.2901694  0.29563278
#   0.29335081 0.30213896 0.30413648 0.30956111]
#  [0.27989956 0.28860664 0.2830445  0.28563637 0.29112972 0.28866977
#   0.29441303 0.30333378 0.30172202 0.30626587]
#  [0.28665663 0.28889057 0.28236238 0.29082622 0.28988005 0.29926286
#   0.29887839 0.29762731 0.30120571 0.30455999]
#  [0.2864767  0.28570928 0.29171653 0.29383162 0.28927426 0.30278828
#   0.30323572 0.3071977  0.3014186  0.30664056]
#  [0.2974075  0.29622156 0.28963931 0.30449367 0.3013538  0.30504469
#   0.31403126 0.31348083 0.30574912 0.31208687]
#  [0.28445644 0.29790833 0.29289049 0.29894141 0.29905767 0.30950983
#   0.31323588 0.30798097 0.30031075 0.31250855]
#  [0.29153857 0.2951497  0.31551135 0.32116555 0.29986827 0.30692752
#   0.30595    0.31279242 0.31350396 0.3106821 ]]
# r2_metrics:  [[0.09161741 0.24125435 0.45836695 0.40434505 0.42871659 0.42704908
#   0.40362138 0.39810492 0.39697652 0.38850464]
#  [0.20741603 0.29781482 0.43982321 0.40543642 0.41036906 0.39673611
#   0.41946263 0.4008973  0.37389132 0.35860537]
#  [0.44523032 0.44742861 0.42708323 0.44213454 0.41286772 0.4075417
#   0.3953418  0.40971576 0.40749535 0.38837609]
#  [0.40473631 0.43206038 0.42185197 0.38207289 0.4194167  0.41462188
#   0.40363563 0.39972888 0.37492392 0.35939352]
#  [0.40002515 0.38648707 0.42537373 0.40649895 0.40796806 0.43022525
#   0.40349653 0.40077253 0.38055646 0.38541345]
#  [0.41575644 0.40306576 0.43987129 0.41839426 0.41722805 0.40053398
#   0.40675605 0.40651807 0.38136834 0.34247379]
#  [0.430053   0.44247985 0.42256297 0.40117507 0.42021974 0.40858726
#   0.40397548 0.3674931  0.38953403 0.35288945]
#  [0.3937324  0.39624994 0.41028824 0.37703295 0.39391442 0.37795966
#   0.3783969  0.37204942 0.36512245 0.34780823]
#  [0.43016028 0.40343033 0.41817897 0.38746891 0.39183751 0.36920905
#   0.36463119 0.34919752 0.3925237  0.35778857]
#  [0.3927605  0.38112373 0.37325151 0.368508   0.39115332 0.38478144
#   0.36900592 0.33812358 0.35652391 0.37321534]]
# predictions:  [[[ 0.01058809  0.00555184 -0.00824387 ...  0.          0.
#     0.        ]
#   [ 0.36003782  0.24731838  0.12642635 ...  0.          0.
#     0.        ]
#   [ 0.71902854  0.79529527  0.21978312 ...  0.          0.
#     0.        ]
#   ...
#   [ 0.2977986   0.00972344  0.99934968 ...  0.          0.
#     0.        ]
#   [ 0.63169748  0.23212387  0.9749084  ...  0.          0.
#     0.        ]
#   [ 0.90309295  0.75094028  0.7929315  ...  0.          0.
#     0.        ]]
#
#  [[ 0.00621419  0.09892368  0.38291412 ...  0.          0.
#     0.        ]
#   [ 0.31181148  0.43440642  0.50211689 ...  0.          0.
#     0.        ]
#   [ 0.63640718  0.8303002   0.63967101 ...  0.          0.
#     0.        ]
#   ...
#   [ 0.29613045 -0.06835413  0.73093267 ...  0.          0.
#     0.        ]
#   [ 0.64207873  0.28948603  0.67444156 ...  0.          0.
#     0.        ]
#   [ 0.85725191  0.96796088  0.34074272 ...  0.          0.
#     0.        ]]
#
#  [[-0.01781984  0.15980884  0.77963741 ...  0.          0.
#     0.        ]
#   [ 0.30700984  0.61802322  0.88485947 ...  0.          0.
#     0.        ]
#   [ 0.69157963  0.9004242   0.93120646 ...  0.          0.
#     0.        ]
#   ...
#   [ 0.23672133  0.20000847  0.15275711 ...  0.          0.
#     0.        ]
#   [ 0.69279936  0.62611754  0.1503707  ...  0.          0.
#     0.        ]
#   [ 0.6936706   0.94205901  0.1414029  ...  0.          0.
#     0.        ]]
#
#  ...
#
#  [[-0.0078315   0.90487989  0.71191791 ...  0.          0.
#     0.        ]
#   [ 0.15816491  1.02408035  0.68829484 ...  0.          0.
#     0.        ]
#   [ 0.77212243  0.48734133  0.83794956 ...  0.          0.
#     0.        ]
#   ...
#   [ 0.14119102  1.07643305  0.28623954 ...  0.          0.
#     0.        ]
#   [ 0.83022908  0.68278606  0.39204936 ...  0.          0.
#     0.        ]
#   [ 1.11612662  0.58722867  0.28494526 ...  0.          0.
#     0.        ]]
#
#  [[-0.0115591   1.01249082  0.85097778 ...  0.          0.
#     0.        ]
#   [ 0.15597368  0.94180367  0.86155755 ...  0.          0.
#     0.        ]
#   [ 0.75503809  0.40119777  0.50098035 ...  0.          0.
#     0.        ]
#   ...
#   [ 0.20369244  1.01634193  0.24441572 ...  0.          0.
#     0.        ]
#   [ 0.83945663  0.67665677  0.3986446  ...  0.          0.
#     0.        ]
#   [ 1.11598523  0.38559714  0.55270871 ...  0.          0.
#     0.        ]]
#
#  [[-0.02445418  1.09612612  0.28527594 ...  0.          0.
#     0.        ]
#   [ 0.1517539   0.64954719  0.18458277 ...  0.          0.
#     0.        ]
#   [ 0.75707663  0.29223442  0.34005942 ...  0.          0.
#     0.        ]
#   ...
#   [ 0.15316522  0.9517447   0.63693614 ...  0.          0.
#     0.        ]
#   [ 0.84370108  0.63470005  0.68464799 ...  0.          0.
#     0.        ]
#   [ 1.11171751  0.29457163  0.61581771 ...  0.          0.
#     0.        ]]]

# %% [markdown]
# Guardar datos (all)

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import xlsxwriter
from matplotlib.backends.backend_pdf import PdfPages
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

def plot_metric_vs_hyperparam(metric_values, hyperparam_values, hyperparam_name, metric_name):
    plt.figure()
    plt.scatter(hyperparam_values, metric_values)
    plt.xlabel(hyperparam_name)
    plt.ylabel(metric_name)
    plt.title(f'{metric_name} vs {hyperparam_name}')
    plt.grid(True)
    return plt.gcf()

def plot_boxplot_metric_vs_hyperparam(metric_values, hyperparam_values, hyperparam_name, metric_name):
    plt.figure()
    df = pd.DataFrame({hyperparam_name: hyperparam_values, metric_name: metric_values})
    df.boxplot(column=metric_name, by=hyperparam_name)
    plt.title(f'{metric_name} vs {hyperparam_name} (Boxplot)')
    plt.suptitle("")  # Elimina el título redundante generado por boxplot
    plt.xlabel(hyperparam_name)
    plt.ylabel(metric_name)
    plt.grid(True)
    return plt.gcf()

def plot_boxplot_mse_vs_hyperparam(fixed_param1, fixed_param2, hyperparam_values, mse_values, hyperparam_name, metric_name, pdf):

    # Crear un DataFrame para el boxplot
    df = pd.DataFrame({hyperparam_name: hyperparam_values, metric_name: mse_values})

    plt.figure(figsize=(10, 6))
    df.boxplot(column=metric_name, by=hyperparam_name)
    plt.title(f'{metric_name} vs {hyperparam_name}\n(Fijos: {fixed_param1}, {fixed_param2})')
    plt.suptitle("")  # Eliminar título redundante generado por boxplot
    plt.xlabel(hyperparam_name)
    plt.ylabel(metric_name)
    plt.grid(True)

    # Guardar en el PDF
    pdf.savefig()
    plt.close()

import seaborn as sns

##ALPHAS
def plot_boxplot_mean_mse_vs_hyperparam(fixed_param1, fixed_param2, hyperparam_values, mse_values, alphas, sigmas, lambda_regs, hyperparam_name, metric_name, pdf):
    # Crear un diccionario para almacenar los MSE por alpha
    mse_dict = {}

    for i in range(10):  # Primer bucle para las filas
            for j in range(10):  # Segundo bucle para las columnas
                for k in range(len(alphas)):  # Tercer bucle para los valores de alphas
                    # Asegúrate de que los índices estén correctamente definidos
                    mse_val = mse_values[i, j, :, sigmas.index(sigmas_up[i*10 + j]), lambda_regs.index(lambda_up[i*10 + j])]

                    # Almacena el MSE en el diccionario usando una tupla como clave
                    mse_dict[(i * 10 + j, alphas[k])] = mse_val[k]

    # Calcular la media de MSE para cada alpha
    mean_mse_dict = {}
    
    # Nuevo diccionario para almacenar todos los arrays por alpha
    alpha_values_dict = {}
    value1, value2, value3, value4, value5, value6 = [], [], [], [], [], []


    for (celda, alpha), valores in mse_dict.items():
        print(f"Celda: {celda}, Alpha: {alpha}, Valores: {valores}")
        if alpha == alphas[0]:
            value1.append(valores)  # Usa append para un solo valor
        elif alpha == alphas[1]:
            value2.append(valores)
        elif alpha == alphas[2]:
            value3.append(valores)
        elif alpha == alphas[3]:
            value4.append(valores)
        elif alpha == alphas[4]:
            value5.append(valores)
        elif alpha == alphas[5]:
            value6.append(valores)

    print("Valores: ", value1, value2, value3, value4, value5, value6)
    
    # Calcular la media de la lista
    mean_value1 = sum(value1) / len(value1)
    mean_value2 = sum(value2) / len(value2)
    mean_value3 = sum(value3) / len(value3)
    mean_value4 = sum(value4) / len(value4)
    mean_value5 = sum(value5) / len(value5)
    mean_value6 = sum(value6) / len(value6)

    mse_total = [mean_value1, mean_value2, mean_value3, mean_value4, mean_value5, mean_value6]
    mse_every_point = [value1, value2, value3, value4, value5, value6]
    print("MSE_EVERY_POINT: ", mse_every_point)

    if(metric_name == 'MSE'):
    # Crear la gráfica
        plt.figure(figsize=(10, 5))
        plt.plot(alphas, mse_total, marker='o', linestyle='-')
        plt.title('MSE Total vs Alphas')
        plt.xlabel('Alphas')
        plt.ylabel('MSE Total')
        plt.grid()
        pdf.savefig()
        plt.close()

        
    elif(metric_name == 'MAE'):
        plt.figure(figsize=(10, 5))
        plt.plot(alphas, mse_total, marker='o', linestyle='-')
        plt.title('MAE Total vs Alphas')
        plt.xlabel('Alphas')
        plt.ylabel('MAE Total')
        plt.grid()
        pdf.savefig()
        plt.close()

    elif(metric_name == 'R2'):
        plt.figure(figsize=(10, 5))
        plt.plot(alphas, mse_total, marker='o', linestyle='-')
        plt.title('R2 Total vs Alphas')
        plt.xlabel('Alphas')
        plt.ylabel('R2 Total')
        plt.grid()
        pdf.savefig()
        plt.close()
        
    elif(metric_name == 'MSEbp'):
        # Crear la gráfica
        plt.figure(figsize=(10, 5))
        plt.boxplot(mse_every_point, patch_artist=True, showmeans=True)
        plt.xticks(ticks=range(1, len(alphas) + 1), labels=alphas)
        plt.title('Distribución del MSE para diferentes valores de Alpha')
        plt.xlabel('Alpha')
        plt.ylabel('MSE')
        plt.grid(True)
        pdf.savefig()
        plt.close()
        
    elif(metric_name == 'MAEbp'):
        # Crear la gráfica
        plt.figure(figsize=(10, 5))
        plt.boxplot(mse_every_point, patch_artist=True, showmeans=True)
        plt.xticks(ticks=range(1, len(alphas) + 1), labels=alphas)
        plt.title('Distribución del MAE para diferentes valores de Alpha')
        plt.xlabel('Alpha')
        plt.ylabel('MAE')
        plt.grid(True)
        pdf.savefig()
        plt.close()

    elif(metric_name == 'R2bp'):
        # Crear la gráfica
        plt.figure(figsize=(10, 5))
        plt.boxplot(mse_every_point, patch_artist=True, showmeans=True)
        plt.xticks(ticks=range(1, len(alphas) + 1), labels=alphas)
        plt.title('Distribución del R2 para diferentes valores de Alpha')
        plt.xlabel('Alpha')
        plt.ylabel('R2')
        plt.grid(True)
        pdf.savefig()
        plt.close()

##SIGMAS
def plot_boxplot_mean_mse_vs_hyperparam_sigmas(fixed_param1, fixed_param2, hyperparam_values, mse_values, alphas, sigmas, lambda_regs, hyperparam_name, metric_name, pdf):
    # Crear un diccionario para almacenar los MSE por alpha
    mse_dict = {}

    for i in range(10):  # Primer bucle para las filas
            for j in range(10):  # Segundo bucle para las columnas
                for k in range(len(sigmas)):  # Tercer bucle para los valores de alphas
                    # Asegúrate de que los índices estén correctamente definidos
                    mse_val = mse_values[i, j, alphas.index(alphas_up[i*10 + j]), :, lambda_regs.index(lambda_up[i*10 + j])]

                    # Almacena el MSE en el diccionario usando una tupla como clave
                    mse_dict[(i * 10 + j, sigmas[k])] = mse_val[k]

    mean_mse_dict = {}
    
    sigmas_values_dict = {}
    value1, value2, value3, value4, value5, value6 = [], [], [], [], [], []


    for (celda, sigma), valores in mse_dict.items():
        print(f"Celda: {celda}, Sigma: {sigma}, Valores: {valores}")
        if sigma == sigmas[0]:
            value1.append(valores)  # Usa append para un solo valor
        elif sigma == sigmas[1]:
            value2.append(valores)
        elif sigma == sigmas[2]:
            value3.append(valores)
        elif sigma == sigmas[3]:
            value4.append(valores)
        elif sigma == sigmas[4]:
            value5.append(valores)
        elif sigma == sigmas[5]:
            value6.append(valores)

    print("Valores: ", value1, value2, value3, value4, value5, value6)
    
    # Calcular la media de la lista
    mean_value1 = sum(value1) / len(value1)
    mean_value2 = sum(value2) / len(value2)
    mean_value3 = sum(value3) / len(value3)
    mean_value4 = sum(value3) / len(value4)
    mean_value5 = sum(value3) / len(value5)
    mean_value6 = sum(value3) / len(value6)

    mse_total = [mean_value1, mean_value2, mean_value3, mean_value4, mean_value5, mean_value6]
    mse_every_point = [value1, value2, value3, value4, value5, value6]

    if(metric_name == 'MSE'):
    # Crear la gráfica
        plt.figure(figsize=(10, 5))
        plt.plot(sigmas, mse_total, marker='o', linestyle='-')
        plt.title('MSE Total vs Sigmas')
        plt.xlabel('Sigmas')
        plt.ylabel('MSE Total')
        plt.grid()
        pdf.savefig()
        plt.close()

        
    elif(metric_name == 'MAE'):
        plt.figure(figsize=(10, 5))
        plt.plot(sigmas, mse_total, marker='o', linestyle='-')
        plt.title('MAE Total vs Sigmas')
        plt.xlabel('Sigmas')
        plt.ylabel('MAE Total')
        plt.grid()
        pdf.savefig()
        plt.close()

    elif(metric_name == 'R2'):
        plt.figure(figsize=(10, 5))
        plt.plot(sigmas, mse_total, marker='o', linestyle='-')
        plt.title('R2 Total vs Sigmas')
        plt.xlabel('Sigmas')
        plt.ylabel('R2 Total')
        plt.grid()
        pdf.savefig()
        plt.close()

    elif(metric_name == 'MSEbp'):
        # Crear la gráfica
        plt.figure(figsize=(10, 5))
        plt.boxplot(mse_every_point, patch_artist=True, showmeans=True)
        plt.xticks(ticks=range(1, len(sigmas) + 1), labels=sigmas)
        plt.title('Distribución del MSE para diferentes valores de Sigma')
        plt.xlabel('Sigma')
        plt.ylabel('MSE')
        plt.grid(True)
        pdf.savefig()
        plt.close()
        
    elif(metric_name == 'MAEbp'):
        # Crear la gráfica
        plt.figure(figsize=(10, 5))
        plt.boxplot(mse_every_point, patch_artist=True, showmeans=True)
        plt.xticks(ticks=range(1, len(sigmas) + 1), labels=sigmas)
        plt.title('Distribución del MAE para diferentes valores de Sigma')
        plt.xlabel('Sigma')
        plt.ylabel('MAE')
        plt.grid(True)
        pdf.savefig()
        plt.close()

    elif(metric_name == 'R2bp'):
        # Crear la gráfica
        plt.figure(figsize=(10, 5))
        plt.boxplot(mse_every_point, patch_artist=True, showmeans=True)
        plt.xticks(ticks=range(1, len(sigmas) + 1), labels=sigmas)
        plt.title('Distribución del R2 para diferentes valores de Sigma')
        plt.xlabel('Sigma')
        plt.ylabel('R2')
        plt.grid(True)
        pdf.savefig()
        plt.close()
##LAMBDA
def plot_boxplot_mean_mse_vs_hyperparam_lambda(fixed_param1, fixed_param2, hyperparam_values, mse_values, alphas, sigmas, lambda_regs, hyperparam_name, metric_name, pdf):
    mse_dict = {}

    for i in range(10):  # Primer bucle para las filas
            for j in range(10):  # Segundo bucle para las columnas
                for k in range(len(lambda_regs)):  # Tercer bucle para los valores de alphas
                    # Asegúrate de que los índices estén correctamente definidos
                    mse_val = mse_values[i, j, alphas.index(alphas_up[i*10 + j]), sigmas.index(sigmas_up[i*10 + j]), :]

                    # Almacena el MSE en el diccionario usando una tupla como clave
                    mse_dict[(i * 10 + j, lambda_regs[k])] = mse_val[k]

    # Calcular la media de MSE para cada alpha
    mean_mse_dict = {}
    
    # Nuevo diccionario para almacenar todos los arrays por alpha
    alpha_values_dict = {}
    value1, value2, value3, value4 = [], [], [], []


    for (celda, lambda_r), valores in mse_dict.items():
        print(f"Celda: {celda}, Lambda: {lambda_r}, Valores: {valores}")
        if lambda_r == lambda_regs[0]:
            value1.append(valores)  # Usa append para un solo valor
        elif lambda_r == lambda_regs[1]:
            value2.append(valores)
        elif lambda_r == lambda_regs[2]:
            value3.append(valores)
        elif lambda_r == lambda_regs[3]:
            value4.append(valores)

    print("Valores: ", value1, value2, value3, value4)
    
    # Calcular la media de la lista
    mean_value1 = sum(value1) / len(value1)
    mean_value2 = sum(value2) / len(value2)
    mean_value3 = sum(value3) / len(value3)
    mean_value4 = sum(value4) / len(value4)

    mse_total = [mean_value1, mean_value2, mean_value3, mean_value4]
    mse_every_point = [value1, value2, value3, value4]

    if(metric_name == 'MSE'):
    # Crear la gráfica
        plt.figure(figsize=(10, 5))
        plt.plot(lambda_regs, mse_total, marker='o', linestyle='-')
        plt.title('MSE Total vs Lambda')
        plt.xlabel('Lambda')
        plt.ylabel('MSE Total')
        plt.grid()
        pdf.savefig()
        plt.close()

        
    elif(metric_name == 'MAE'):
        plt.figure(figsize=(10, 5))
        plt.plot(lambda_regs, mse_total, marker='o', linestyle='-')
        plt.title('MAE Total vs Lambda')
        plt.xlabel('Lambda')
        plt.ylabel('MAE Total')
        plt.grid()
        pdf.savefig()
        plt.close()

    elif(metric_name == 'R2'):
        plt.figure(figsize=(10, 5))
        plt.plot(lambda_regs, mse_total, marker='o', linestyle='-')
        plt.title('R2 Total vs Lambda')
        plt.xlabel('Lambda')
        plt.ylabel('R2 Total')
        plt.grid()
        pdf.savefig()
        plt.close()

    elif(metric_name == 'MSEbp'):
        # Crear la gráfica
        plt.figure(figsize=(10, 5))
        plt.boxplot(mse_every_point, patch_artist=True, showmeans=True)
        plt.xticks(ticks=range(1, len(lambda_regs) + 1), labels=lambda_regs)
        plt.title('Distribución del MSE para diferentes valores de Lambda')
        plt.xlabel('Lambda')
        plt.ylabel('MSE')
        plt.grid(True)
        pdf.savefig()
        plt.close()
        
    elif(metric_name == 'MAEbp'):
        # Crear la gráfica
        plt.figure(figsize=(10, 5))
        plt.boxplot(mse_every_point, patch_artist=True, showmeans=True)
        plt.xticks(ticks=range(1, len(lambda_regs) + 1), labels=lambda_regs)
        plt.title('Distribución del MAE para diferentes valores de Lambda')
        plt.xlabel('Lambda')
        plt.ylabel('MAE')
        plt.grid(True)
        pdf.savefig()
        plt.close()

    elif(metric_name == 'R2bp'):
        # Crear la gráfica
        plt.figure(figsize=(10, 5))
        plt.boxplot(mse_every_point, patch_artist=True, showmeans=True)
        plt.xticks(ticks=range(1, len(lambda_regs) + 1), labels=lambda_regs)
        plt.title('Distribución del R2 para diferentes valores de Lambda')
        plt.xlabel('Lambda')
        plt.ylabel('R2')
        plt.grid(True)
        pdf.savefig()
        plt.close()

def create_pointplot(metric_matrix, hyperparam_values, hyperparam_name, metric_name, fixed_params, fixed_indices, pdf):
    fig, ax = plt.subplots()
    pointplot_data = []
    print("Matriz: ", metric_matrix)

    # Extraer los datos correspondientes a cada valor del hiperparámetro
    for idx in range(len(hyperparam_values)):
        if hyperparam_name == 'Alpha':
            pointplot_data.append(metric_matrix[idx, fixed_indices[0], fixed_indices[1]])
        elif hyperparam_name == 'Sigma':
            pointplot_data.append(metric_matrix[fixed_indices[0], idx, fixed_indices[1]])
        elif hyperparam_name == 'Lambda':
            pointplot_data.append(metric_matrix[fixed_indices[0], fixed_indices[1], idx])

    # Crear el gráfico de puntos
    ax.scatter(hyperparam_values, pointplot_data)

    # Configurar las etiquetas y el título
    ax.set_xticks(range(len(hyperparam_values)))
    ax.set_xticklabels([str(val) for val in hyperparam_values])

    ax.set_xlabel(hyperparam_name)
    ax.set_ylabel(metric_name)
    ax.set_title(f'{metric_name} vs {hyperparam_name} (Fixed: {", ".join(fixed_params)})')
    plt.grid(True)

    # Guardar en el PDF
    pdf.savefig()
    plt.close()

# Crear directorio 'img' si no existe
if not os.path.exists('img'):
    os.makedirs('img')

# Guardar resultados en un archivo Excel
workbook = xlsxwriter.Workbook('resultados_rbf4.xlsx')
worksheet = workbook.add_worksheet()

worksheet.write(0, 0, 'Celda')
worksheet.write(0, 1, 'MSE')
worksheet.write(0, 2, 'MAE')
worksheet.write(0, 3, 'R2')

for i in range(10):
    for j in range(10):
        worksheet.write(i * 10 + j + 1, 0, f'({i},{j})')
        worksheet.write(i * 10 + j + 1, 1, mse_metrics[i, j])
        worksheet.write(i * 10 + j + 1, 2, mae_metrics[i, j])
        worksheet.write(i * 10 + j + 1, 3, r2_metrics[i, j])

workbook.close()

# Graficar superficies 3D para MSE, MAE y R2
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
X, Y = np.meshgrid(range(10), range(10))
ax.plot_surface(X, Y, mse_metrics, cmap='viridis')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('MSE')
plt.title('Superficie de MSE por celda')
plt.savefig('img/mse_surface.png')
plt.close(fig)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, mae_metrics, cmap='plasma')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('MAE')
plt.title('Superficie de MAE por celda')
plt.savefig('img/mae_surface.png')
plt.close(fig)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, r2_metrics, cmap='inferno')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('R2')
plt.title('Superficie de R2 por celda')
plt.savefig('img/r2_surface.png')
plt.close(fig)

# Mostrar resultados
print("Resultados de las métricas:")
for i in range(10):
    for j in range(10):
        print(f"Celda ({i},{j}): MSE={mse_metrics[i, j]}, MAE={mae_metrics[i, j]}, R2={r2_metrics[i, j]}")

# Inicializar listas para almacenar los resultados de las métricas por hiperparámetro
alpha_mse = []
alpha_mae = []
alpha_r2 = []
sigma_mse = []
sigma_mae = []
sigma_r2 = []
lambda_mse = []
lambda_mae = []
lambda_r2 = []

sigmas_up = [float(value) for value in sigmas_up]

print(f"Alphas_up: ", alphas_up)
print(f"Sigmas_up: ", sigmas_up)
print(f"Lambda_up: ", lambda_up)

for i in range(10):
    for j in range(10):
        if mse_metrics[i, j] != 0:
            alpha_mse.append(mse_metrics[i, j])
            alpha_mae.append(mae_metrics[i, j])
            alpha_r2.append(r2_metrics[i, j])
            sigma_mse.append(mse_metrics[i, j])
            sigma_mae.append(mae_metrics[i, j])
            sigma_r2.append(r2_metrics[i, j])
            lambda_mse.append(mse_metrics[i, j])
            lambda_mae.append(mae_metrics[i, j])
            lambda_r2.append(r2_metrics[i, j])

alpha_mse = [float(value) for value in alpha_mse]
alpha_mae = [float(value) for value in alpha_mae]
alpha_r2 = [float(value) for value in alpha_r2]

sigma_mse = [float(value) for value in sigma_mse]
sigma_mae = [float(value) for value in sigma_mae]
sigma_r2 = [float(value) for value in sigma_r2]

lambda_mse = [float(value) for value in lambda_mse]
lambda_mae = [float(value) for value in lambda_mae]
lambda_r2 = [float(value) for value in lambda_r2]

print(f"Alphas_mse ", alpha_mse)
print(f"Alphas_mae ", alpha_mae)
print(f"Alphas_r2 ", alpha_r2)

print(f"Sigmas_mse: ", sigma_mse)
print(f"Sigmas_mae: ", sigma_mae)
print(f"Sigmas_r2: ", sigma_r2)

print(f"Lambda_mse: ", lambda_mse)
print(f"Lambda_mae: ", lambda_mae)
print(f"Lambda_r2: ", lambda_r2)

# Graficar optimización de hiperparámetros
with PdfPages('hyperparam_optimization_results.pdf') as pdf:
    pdf.savefig(plot_metric_vs_hyperparam(alpha_mse, alphas_up, 'Alpha', 'MSE'))
    pdf.savefig(plot_metric_vs_hyperparam(alpha_mae, alphas_up, 'Alpha', 'MAE'))
    pdf.savefig(plot_metric_vs_hyperparam(alpha_r2, alphas_up, 'Alpha', 'R2'))
    
    pdf.savefig(plot_metric_vs_hyperparam(sigma_mse, sigmas_up, 'Sigma', 'MSE'))
    pdf.savefig(plot_metric_vs_hyperparam(sigma_mae, sigmas_up, 'Sigma', 'MAE'))
    pdf.savefig(plot_metric_vs_hyperparam(sigma_r2, sigmas_up, 'Sigma', 'R2'))
    
    pdf.savefig(plot_metric_vs_hyperparam(lambda_mse, lambda_up, 'Lambda', 'MSE'))
    pdf.savefig(plot_metric_vs_hyperparam(lambda_mae, lambda_up, 'Lambda', 'MAE'))
    pdf.savefig(plot_metric_vs_hyperparam(lambda_r2, lambda_up, 'Lambda', 'R2'))

print("Gráficos guardados en hyperparam_optimization_results.pdf")

# Graficar optimización de hiperparámetros BOXPLOT
with PdfPages('hyperparam_optimization_results_boxplot.pdf') as pdf:
    pdf.savefig(plot_boxplot_metric_vs_hyperparam(alpha_mse, alphas_up, 'Alpha', 'MSE'))
    pdf.savefig(plot_boxplot_metric_vs_hyperparam(alpha_mae, alphas_up, 'Alpha', 'MAE'))
    pdf.savefig(plot_boxplot_metric_vs_hyperparam(alpha_r2, alphas_up, 'Alpha', 'R2'))
    
    pdf.savefig(plot_boxplot_metric_vs_hyperparam(sigma_mse, sigmas_up, 'Sigma', 'MSE'))
    pdf.savefig(plot_boxplot_metric_vs_hyperparam(sigma_mae, sigmas_up, 'Sigma', 'MAE'))
    pdf.savefig(plot_boxplot_metric_vs_hyperparam(sigma_r2, sigmas_up, 'Sigma', 'R2'))
    
    pdf.savefig(plot_boxplot_metric_vs_hyperparam(lambda_mse, lambda_up, 'Lambda', 'MSE'))
    pdf.savefig(plot_boxplot_metric_vs_hyperparam(lambda_mae, lambda_up, 'Lambda', 'MAE'))
    pdf.savefig(plot_boxplot_metric_vs_hyperparam(lambda_r2, lambda_up, 'Lambda', 'R2'))

print("Gráficos guardados en hyperparam_optimization_results_boxplot.pdf")

# Graficar y guardar en PDF
with PdfPages('MEAN_MSE_BOXPLOT_100_CELDAS_NV_ALPHAS.pdf') as pdf:
    plot_boxplot_mean_mse_vs_hyperparam(
                sigmas_up,            # Cambia i por el valor del primer bucle
                lambda_up,            # Cambia j por el valor del segundo bucle
                alphas,                  # Mantén alphas igual
                mse_metrics_matrix_all,  # Cambia los índices según los bucles
                alphas,
                sigmas,
                lambda_regs,
                'Alphas',                # Nombre del hiperparámetro
                'MSE',                   # Nombre de la métrica
                pdf                      # Objeto PdfPages para guardar
            )
    plot_boxplot_mean_mse_vs_hyperparam(
                sigmas_up,            # Cambia i por el valor del primer bucle
                lambda_up,            # Cambia j por el valor del segundo bucle
                alphas,                  # Mantén alphas igual
                mae_metrics_matrix_all,  # Cambia los índices según los bucles
                alphas,
                sigmas,
                lambda_regs,
                'Alphas',                # Nombre del hiperparámetro
                'MAE',                   # Nombre de la métrica
                pdf                      # Objeto PdfPages para guardar
            )
    plot_boxplot_mean_mse_vs_hyperparam(
                sigmas_up,            # Cambia i por el valor del primer bucle
                lambda_up,            # Cambia j por el valor del segundo bucle
                alphas,                  # Mantén alphas igual
                r2_metrics_matrix_all,  # Cambia los índices según los bucles
                alphas,
                sigmas,
                lambda_regs,
                'Alphas',                # Nombre del hiperparámetro
                'R2',                   # Nombre de la métrica
                pdf                      # Objeto PdfPages para guardar
            )
    plot_boxplot_mean_mse_vs_hyperparam(
                sigmas_up,            # Cambia i por el valor del primer bucle
                lambda_up,            # Cambia j por el valor del segundo bucle
                alphas,                  # Mantén alphas igual
                mse_metrics_matrix_all,  # Cambia los índices según los bucles
                alphas,
                sigmas,
                lambda_regs,
                'Alphas',                # Nombre del hiperparámetro
                'MSEbp',                   # Nombre de la métrica
                pdf                      # Objeto PdfPages para guardar
            )
    plot_boxplot_mean_mse_vs_hyperparam(
                sigmas_up,            # Cambia i por el valor del primer bucle
                lambda_up,            # Cambia j por el valor del segundo bucle
                alphas,                  # Mantén alphas igual
                mae_metrics_matrix_all,  # Cambia los índices según los bucles
                alphas,
                sigmas,
                lambda_regs,
                'Alphas',                # Nombre del hiperparámetro
                'MAEbp',                   # Nombre de la métrica
                pdf                      # Objeto PdfPages para guardar
            )
    plot_boxplot_mean_mse_vs_hyperparam(
                sigmas_up,            # Cambia i por el valor del primer bucle
                lambda_up,            # Cambia j por el valor del segundo bucle
                alphas,                  # Mantén alphas igual
                r2_metrics_matrix_all,  # Cambia los índices según los bucles
                alphas,
                sigmas,
                lambda_regs,
                'Alphas',                # Nombre del hiperparámetro
                'R2bp',                   # Nombre de la métrica
                pdf                      # Objeto PdfPages para guardar
            )
    
# Graficar y guardar en PDF
with PdfPages('MEAN_MSE_BOXPLOT_100_CELDAS_NV_SIGMAS.pdf') as pdf:
    plot_boxplot_mean_mse_vs_hyperparam_sigmas(
                sigmas_up,            # Cambia i por el valor del primer bucle
                lambda_up,            # Cambia j por el valor del segundo bucle
                alphas,                  # Mantén alphas igual
                mse_metrics_matrix_all,  # Cambia los índices según los bucles
                alphas,
                sigmas,
                lambda_regs,
                'Sigmas',                # Nombre del hiperparámetro
                'MSE',                   # Nombre de la métrica
                pdf                      # Objeto PdfPages para guardar
            )
    plot_boxplot_mean_mse_vs_hyperparam_sigmas(
                sigmas_up,            # Cambia i por el valor del primer bucle
                lambda_up,            # Cambia j por el valor del segundo bucle
                alphas,                  # Mantén alphas igual
                mae_metrics_matrix_all,  # Cambia los índices según los bucles
                alphas,
                sigmas,
                lambda_regs,
                'Sigmas',                # Nombre del hiperparámetro
                'MAE',                   # Nombre de la métrica
                pdf                      # Objeto PdfPages para guardar
            )
    
    plot_boxplot_mean_mse_vs_hyperparam_sigmas(
                sigmas_up,            # Cambia i por el valor del primer bucle
                lambda_up,            # Cambia j por el valor del segundo bucle
                alphas,                  # Mantén alphas igual
                r2_metrics_matrix_all,  # Cambia los índices según los bucles
                alphas,
                sigmas,
                lambda_regs,
                'Sigmas',                # Nombre del hiperparámetro
                'R2',                   # Nombre de la métrica
                pdf                      # Objeto PdfPages para guardar
            )
    plot_boxplot_mean_mse_vs_hyperparam_sigmas(
                sigmas_up,            # Cambia i por el valor del primer bucle
                lambda_up,            # Cambia j por el valor del segundo bucle
                alphas,                  # Mantén alphas igual
                mse_metrics_matrix_all,  # Cambia los índices según los bucles
                alphas,
                sigmas,
                lambda_regs,
                'Alphas',                # Nombre del hiperparámetro
                'MSEbp',                   # Nombre de la métrica
                pdf                      # Objeto PdfPages para guardar
            )
    plot_boxplot_mean_mse_vs_hyperparam_sigmas(
                sigmas_up,            # Cambia i por el valor del primer bucle
                lambda_up,            # Cambia j por el valor del segundo bucle
                alphas,                  # Mantén alphas igual
                mae_metrics_matrix_all,  # Cambia los índices según los bucles
                alphas,
                sigmas,
                lambda_regs,
                'Alphas',                # Nombre del hiperparámetro
                'MAEbp',                   # Nombre de la métrica
                pdf                      # Objeto PdfPages para guardar
            )
    plot_boxplot_mean_mse_vs_hyperparam_sigmas(
                sigmas_up,            # Cambia i por el valor del primer bucle
                lambda_up,            # Cambia j por el valor del segundo bucle
                alphas,                  # Mantén alphas igual
                r2_metrics_matrix_all,  # Cambia los índices según los bucles
                alphas,
                sigmas,
                lambda_regs,
                'Alphas',                # Nombre del hiperparámetro
                'R2bp',                   # Nombre de la métrica
                pdf                      # Objeto PdfPages para guardar
            )
    
# Graficar y guardar en PDF
with PdfPages('MEAN_MSE_BOXPLOT_100_CELDAS_NV_LAMBDA.pdf') as pdf:
    plot_boxplot_mean_mse_vs_hyperparam_lambda(
                sigmas_up,            # Cambia i por el valor del primer bucle
                lambda_up,            # Cambia j por el valor del segundo bucle
                alphas,                  # Mantén alphas igual
                mse_metrics_matrix_all,  # Cambia los índices según los bucles
                alphas,
                sigmas,
                lambda_regs,
                'Lambda',                # Nombre del hiperparámetro
                'MSE',                   # Nombre de la métrica
                pdf                      # Objeto PdfPages para guardar
            ) 
    plot_boxplot_mean_mse_vs_hyperparam_lambda(
                sigmas_up,            # Cambia i por el valor del primer bucle
                lambda_up,            # Cambia j por el valor del segundo bucle
                alphas,                  # Mantén alphas igual
                mae_metrics_matrix_all,  # Cambia los índices según los bucles
                alphas,
                sigmas,
                lambda_regs,
                'Lambda',                # Nombre del hiperparámetro
                'MAE',                   # Nombre de la métrica
                pdf                      # Objeto PdfPages para guardar
            )
    plot_boxplot_mean_mse_vs_hyperparam_lambda(
                sigmas_up,            # Cambia i por el valor del primer bucle
                lambda_up,            # Cambia j por el valor del segundo bucle
                alphas,                  # Mantén alphas igual
                r2_metrics_matrix_all,  # Cambia los índices según los bucles
                alphas,
                sigmas,
                lambda_regs,
                'Lambda',                # Nombre del hiperparámetro
                'R2',                   # Nombre de la métrica
                pdf                      # Objeto PdfPages para guardar
            ) 
    plot_boxplot_mean_mse_vs_hyperparam_lambda(
                sigmas_up,            # Cambia i por el valor del primer bucle
                lambda_up,            # Cambia j por el valor del segundo bucle
                alphas,                  # Mantén alphas igual
                mse_metrics_matrix_all,  # Cambia los índices según los bucles
                alphas,
                sigmas,
                lambda_regs,
                'Alphas',                # Nombre del hiperparámetro
                'MSEbp',                   # Nombre de la métrica
                pdf                      # Objeto PdfPages para guardar
            )
    plot_boxplot_mean_mse_vs_hyperparam_lambda(
                sigmas_up,            # Cambia i por el valor del primer bucle
                lambda_up,            # Cambia j por el valor del segundo bucle
                alphas,                  # Mantén alphas igual
                mae_metrics_matrix_all,  # Cambia los índices según los bucles
                alphas,
                sigmas,
                lambda_regs,
                'Alphas',                # Nombre del hiperparámetro
                'MAEbp',                   # Nombre de la métrica
                pdf                      # Objeto PdfPages para guardar
            )
    plot_boxplot_mean_mse_vs_hyperparam_lambda(
                sigmas_up,            # Cambia i por el valor del primer bucle
                lambda_up,            # Cambia j por el valor del segundo bucle
                alphas,                  # Mantén alphas igual
                r2_metrics_matrix_all,  # Cambia los índices según los bucles
                alphas,
                sigmas,
                lambda_regs,
                'Alphas',                # Nombre del hiperparámetro
                'R2bp',                   # Nombre de la métrica
                pdf                      # Objeto PdfPages para guardar
            )
# Graficar y guardar en PDF
with PdfPages('MSE_BOXPLOT_100_CELDAS_NV_ALPHAS.pdf') as pdf:
    for i in range(10):  # Primer bucle para las filas
        for j in range(10):  # Segundo bucle para las columnas
            # Llamar a la función con los índices de los bucles
            plot_boxplot_mse_vs_hyperparam(
                sigmas_up[i*10+j],            # Cambia i por el valor del primer bucle
                lambda_up[i*10+j],            # Cambia j por el valor del segundo bucle
                alphas,                  # Mantén alphas igual
                mse_metrics_matrix_all[i, j, :, sigmas.index(sigmas_up[i*j]), lambda_regs.index(lambda_up[i*j])],  # Cambia los índices según los bucles
                'Alphas',                # Nombre del hiperparámetro
                'MSE',                   # Nombre de la métrica
                pdf                      # Objeto PdfPages para guardar
            )

# Graficar y guardar en PDF
with PdfPages('MSE_BOXPLOT_100_CELDAS_NV_SIGMAS.pdf') as pdf:
    for i in range(10):  # Primer bucle para las filas
        for j in range(10):  # Segundo bucle para las columnas
            # Llamar a la función con los índices de los bucles
            plot_boxplot_mse_vs_hyperparam(
                alphas_up[i*10+j],            # Cambia i por el valor del primer bucle
                lambda_up[i*10+j],            # Cambia j por el valor del segundo bucle
                sigmas,                  # Mantén alphas igual
                mse_metrics_matrix_all[i, j, alphas.index(alphas_up[i*j]), :, lambda_regs.index(lambda_up[i*j])],  # Cambia los índices según los bucles
                'Sigmas',                # Nombre del hiperparámetro
                'MSE',                   # Nombre de la métrica
                pdf                      # Objeto PdfPages para guardar
            )

# Graficar y guardar en PDF
with PdfPages('MSE_BOXPLOT_100_CELDAS_NV_LAMBDA.pdf') as pdf:
    for i in range(10):  # Primer bucle para las filas
        for j in range(10):  # Segundo bucle para las columnas
            # Llamar a la función con los índices de los bucles
            plot_boxplot_mse_vs_hyperparam(
                alphas_up[i*10+j],            # Cambia i por el valor del primer bucle
                sigmas_up[i*10+j],            # Cambia j por el valor del segundo bucle
                lambda_regs,                  # Mantén alphas igual
                mse_metrics_matrix_all[i, j, alphas.index(alphas_up[i*j]), sigmas.index(sigmas_up[i*j]), :],  # Cambia los índices según los bucles
                'Lambda',                # Nombre del hiperparámetro
                'MSE',                   # Nombre de la métrica
                pdf                      # Objeto PdfPages para guardar
            )

# Graficar y guardar en PDF
with PdfPages('MAE_BOXPLOT_100_CELDAS_ALPHAS.pdf') as pdf:
    for i in range(10):  # Primer bucle para las filas
        for j in range(10):  # Segundo bucle para las columnas
            # Llamar a la función con los índices de los bucles
            plot_boxplot_mse_vs_hyperparam(
                sigmas_up[i*10+j],            # Cambia i por el valor del primer bucle
                lambda_up[i*10+j],            # Cambia j por el valor del segundo bucle
                alphas,                  # Mantén alphas igual
                mae_metrics_matrix_all[i, j, :, sigmas.index(sigmas_up[i*j]), lambda_regs.index(lambda_up[i*j])],  # Cambia los índices según los bucles
                'Alphas',                # Nombre del hiperparámetro
                'MAE',                   # Nombre de la métrica
                pdf                      # Objeto PdfPages para guardar
            )


# Ejemplo de uso con PdfPages:
with PdfPages('hyperparam_pointplot_BEST.pdf') as pdf:

    # Crear boxplots variando Alpha, manteniendo Sigma y Lambda fijos
    create_pointplot(results, alphas, 'Alpha', 'MSE', ['Sigma', 'Lambda'], [best_sigma_index, best_lambda_reg_index], pdf)

    # Crear boxplots variando Sigma, manteniendo Alpha y Lambda fijos
    create_pointplot(results, sigmas, 'Sigma', 'MSE', ['Alpha', 'Lambda'], [best_alpha_index, best_lambda_reg_index], pdf)

    # Crear boxplots variando Lambda, manteniendo Alpha y Sigma fijos
    create_pointplot(results, lambda_regs, 'Lambda', 'MSE', ['Alpha', 'Sigma'], [best_alpha_index, best_sigma_index], pdf)


# Gráfico Real vs Predicted para una celda
fig, ax = plt.subplots()
real_values = y_test1.flatten()
predicted_values = predictions_all.flatten()
ax.scatter(real_values, predicted_values, edgecolors=(0, 0, 0))
ax.plot([real_values.min(), real_values.max()], [real_values.min(), real_values.max()], 'k--', lw=4)
ax.set_xlabel('Valores Reales')
ax.set_ylabel('Valores Predichos')
plt.title('Valores Reales vs Valores Predichos')
plt.savefig('img/real_vs_predicted.png')
plt.close(fig)

# Gráficos de valores reales vs predichos para todas las celdas
for i in range(10):
    for j in range(10):
        real_values = (y_test1 > 0.5).astype(int).flatten()
        predicted_values = (predicciones_100_RBFs[i, j, :len(y_test1)] > 0.5).astype(int).flatten()

        fig, ax = plt.subplots()
        ax.scatter(real_values, predicted_values, edgecolors=(0, 0, 0))
        ax.plot([real_values.min(), real_values.max()], [real_values.min(), real_values.max()], 'k--', lw=4)
        ax.set_xlabel('Valores Reales')
        ax.set_ylabel('Valores Predichos')
        plt.title(f'Valores Reales vs Valores Predichos para la celda ({i},{j})')
        plt.savefig(f'img/real_vs_predicted_{i}_{j}.png')
        plt.close(fig)

        # Crear matriz de confusión para cada celda
        cm = confusion_matrix(real_values, predicted_values)
        disp = ConfusionMatrixDisplay(confusion_matrix=cm)
        disp.plot()
        plt.title(f'Matriz de Confusión para la celda ({i},{j})')
        plt.savefig(f'img/confusion_matrix_{i}_{j}.png')
        plt.close()
# Out:
# Resultados de las métricas:
# Celda (0,0): MSE=0.015317605834625303, MAE=0.039307966759179344, R2=0.09161740731917833
# Celda (0,1): MSE=0.12550143726923624, MAE=0.2576747080495453, R2=0.24125435303833898
# Celda (0,2): MSE=0.12338909193650854, MAE=0.2535864420136543, R2=0.4583669541168628
# Celda (0,3): MSE=0.14063116526725405, MAE=0.2817820755926831, R2=0.4043450523609131
# Celda (0,4): MSE=0.1330590789806866, MAE=0.2699693679118501, R2=0.42871658859023476
# Celda (0,5): MSE=0.1395897939295248, MAE=0.2900174643096292, R2=0.42704907662160163
# Celda (0,6): MSE=0.14679540346403977, MAE=0.2982113892216628, R2=0.4036213815186206
# Celda (0,7): MSE=0.14775038284523723, MAE=0.2943592603012166, R2=0.3981049207643903
# Celda (0,8): MSE=0.14696869950437144, MAE=0.30147804600097744, R2=0.3969765200578933
# Celda (0,9): MSE=0.15034796483275403, MAE=0.30136530374837367, R2=0.38850464133340823
# Celda (1,0): MSE=0.12611238309047143, MAE=0.2592561456881259, R2=0.20741602526627245
# Celda (1,1): MSE=0.1357658912391416, MAE=0.27576483819487735, R2=0.29781482349278887
# Celda (1,2): MSE=0.1323625095002809, MAE=0.26797114508180525, R2=0.4398232090379788
# Celda (1,3): MSE=0.1393912754787683, MAE=0.28842039136513176, R2=0.40543641588357815
# Celda (1,4): MSE=0.13943457188874392, MAE=0.2853003213653076, R2=0.41036905839961413
# Celda (1,5): MSE=0.14769772914083346, MAE=0.29405084633391715, R2=0.3967361149037695
# Celda (1,6): MSE=0.14336008428863964, MAE=0.2997029695173817, R2=0.4194626285434777
# Celda (1,7): MSE=0.14611585502348234, MAE=0.2965428586515331, R2=0.40089729993369494
# Celda (1,8): MSE=0.15311694436864745, MAE=0.3080803563562505, R2=0.37389132491027655
# Celda (1,9): MSE=0.15776620850333106, MAE=0.30966856321908953, R2=0.3586053684635594
# Celda (2,0): MSE=0.12527776219134548, MAE=0.256144633041974, R2=0.4452303213653751
# Celda (2,1): MSE=0.13098247492133047, MAE=0.26944396453739594, R2=0.4474286104972909
# Celda (2,2): MSE=0.13879625922829264, MAE=0.27393816464566445, R2=0.42708322829733514
# Celda (2,3): MSE=0.13339730187538934, MAE=0.2675344210871899, R2=0.4421345387531975
# Celda (2,4): MSE=0.1410452915525376, MAE=0.28514274709767007, R2=0.41286771514265075
# Celda (2,5): MSE=0.14632167961066064, MAE=0.2920397912215594, R2=0.40754169612988767
# Celda (2,6): MSE=0.14842866144117584, MAE=0.2990868002216213, R2=0.3953417973031542
# Celda (2,7): MSE=0.14286124852351173, MAE=0.29147110266470194, R2=0.40971575969087637
# Celda (2,8): MSE=0.1455527038844854, MAE=0.30372672410475565, R2=0.4074953509329424
# Celda (2,9): MSE=0.151925780181739, MAE=0.30937599500629637, R2=0.3883760875535561
# Celda (3,0): MSE=0.1416460051664452, MAE=0.2895147523217528, R2=0.4047363106267229
# Celda (3,1): MSE=0.1351780114359009, MAE=0.27325987960232284, R2=0.43206038211888154
# Celda (3,2): MSE=0.13922426275256108, MAE=0.2729142831596557, R2=0.421851965861872
# Celda (3,3): MSE=0.14827555230381548, MAE=0.2959772777982178, R2=0.3820728893234465
# Celda (3,4): MSE=0.1423239410020697, MAE=0.29016939596011654, R2=0.41941670083971183
# Celda (3,5): MSE=0.14384387591823128, MAE=0.295632776448803, R2=0.41462187989571453
# Celda (3,6): MSE=0.14559873348076416, MAE=0.29335080937615726, R2=0.40363562671149467
# Celda (3,7): MSE=0.1450118390512186, MAE=0.3021389644744257, R2=0.3997288841919815
# Celda (3,8): MSE=0.15461305599591746, MAE=0.30413647781888187, R2=0.3749239161310407
# Celda (3,9): MSE=0.15918008626930583, MAE=0.30956110611519605, R2=0.3593935184351723
# Celda (4,0): MSE=0.13978434652538108, MAE=0.2798995630073602, R2=0.40002515450322107
# Celda (4,1): MSE=0.14432740792325777, MAE=0.28860663766464484, R2=0.3864870748757837
# Celda (4,2): MSE=0.13656241486935544, MAE=0.2830444968738833, R2=0.4253737348354395
# Celda (4,3): MSE=0.14436077549227055, MAE=0.28563636851664004, R2=0.40649895092125377
# Celda (4,4): MSE=0.14480712126743425, MAE=0.2911297151457817, R2=0.40796805593225816
# Celda (4,5): MSE=0.13992787832752077, MAE=0.28866977290845053, R2=0.4302252544661692
# Celda (4,6): MSE=0.14501051327631143, MAE=0.2944130307156647, R2=0.4034965266649422
# Celda (4,7): MSE=0.1466623804819752, MAE=0.3033337763681436, R2=0.4007725348413482
# Celda (4,8): MSE=0.15257630741074243, MAE=0.3017220188439729, R2=0.38055645579322916
# Celda (4,9): MSE=0.15228246316330818, MAE=0.30626587475695133, R2=0.3854134495224374
# Celda (5,0): MSE=0.14213515055403864, MAE=0.28665662559475624, R2=0.41575643597663436
# Celda (5,1): MSE=0.14441242740527813, MAE=0.28889056728865126, R2=0.40306576232375213
# Celda (5,2): MSE=0.13689059961758468, MAE=0.2823623842980058, R2=0.43987128865757286
# Celda (5,3): MSE=0.14333266851448784, MAE=0.2908262159341147, R2=0.41839425813046227
# Celda (5,4): MSE=0.14367647537078423, MAE=0.28988005302464853, R2=0.41722805077674885
# Celda (5,5): MSE=0.1475553509164875, MAE=0.2992628636848375, R2=0.4005339795897159
# Celda (5,6): MSE=0.1471705295190612, MAE=0.29887838811354744, R2=0.4067560453830772
# Celda (5,7): MSE=0.14648447627126654, MAE=0.2976273107102513, R2=0.40651807486503966
# Celda (5,8): MSE=0.15212417211790652, MAE=0.3012057076676499, R2=0.38136834047097856
# Celda (5,9): MSE=0.16166554019591609, MAE=0.3045599851273736, R2=0.34247379007691514
# Celda (6,0): MSE=0.1403277829798359, MAE=0.28647669823273764, R2=0.4300530000595252
# Celda (6,1): MSE=0.13721170383229045, MAE=0.285709276219931, R2=0.4424798484819561
# Celda (6,2): MSE=0.14161805975151356, MAE=0.2917165291092614, R2=0.4225629709825126
# Celda (6,3): MSE=0.14701863267194495, MAE=0.29383162359344334, R2=0.4011750665490629
# Celda (6,4): MSE=0.14240601759898983, MAE=0.2892742581695208, R2=0.42021974432953657
# Celda (6,5): MSE=0.14691822924832265, MAE=0.3027882792482352, R2=0.4085872601338034
# Celda (6,6): MSE=0.14861554479802117, MAE=0.30323571733062593, R2=0.403975484676097
# Celda (6,7): MSE=0.15625034781698824, MAE=0.3071977029646891, R2=0.36749310401178004
# Celda (6,8): MSE=0.14962614012458816, MAE=0.30141860449684726, R2=0.3895340301788086
# Celda (6,9): MSE=0.15877810761638106, MAE=0.3066405610554224, R2=0.3528894511399139
# Celda (7,0): MSE=0.14786330971303052, MAE=0.2974075003404868, R2=0.3937324044979217
# Celda (7,1): MSE=0.14663447640262442, MAE=0.29622156405826955, R2=0.3962499404937577
# Celda (7,2): MSE=0.14435661320051058, MAE=0.289639306413678, R2=0.41028823531803293
# Celda (7,3): MSE=0.15198901516114624, MAE=0.3044936727492649, R2=0.37703294554300726
# Celda (7,4): MSE=0.14834092008888977, MAE=0.30135380452413535, R2=0.39391442282574896
# Celda (7,5): MSE=0.15426928678747145, MAE=0.3050446876270484, R2=0.3779596629727988
# Celda (7,6): MSE=0.15453551128105145, MAE=0.31403126352486427, R2=0.3783968962569124
# Celda (7,7): MSE=0.15521676458399897, MAE=0.31348082877269906, R2=0.3720494182113332
# Celda (7,8): MSE=0.1564196974607615, MAE=0.30574911933044335, R2=0.3651224528291177
# Celda (7,9): MSE=0.16087403234325737, MAE=0.31208687188177603, R2=0.34780822798433997
# Celda (8,0): MSE=0.13774537846349896, MAE=0.28445644033906936, R2=0.4301602836389026
# Celda (8,1): MSE=0.14628796291346244, MAE=0.297908327955303, R2=0.4034303267825975
# Celda (8,2): MSE=0.14296979901981896, MAE=0.2928904873482613, R2=0.41817896905472773
# Celda (8,3): MSE=0.15051612429434783, MAE=0.2989414141188899, R2=0.38746891153785235
# Celda (8,4): MSE=0.14865439978065592, MAE=0.29905766927271143, R2=0.39183751345278117
# Celda (8,5): MSE=0.15567375587384144, MAE=0.3095098261110424, R2=0.36920904597610715
# Celda (8,6): MSE=0.15726414616544246, MAE=0.3132358771085212, R2=0.36463118672369843
# Celda (8,7): MSE=0.16055175660186652, MAE=0.3079809734134631, R2=0.34919752087818656
# Celda (8,8): MSE=0.1502254965648411, MAE=0.30031074695229726, R2=0.3925236954986868
# Celda (8,9): MSE=0.15859010823313477, MAE=0.3125085519365373, R2=0.35778857113879936
# Celda (9,0): MSE=0.1489043673869424, MAE=0.2915385692780526, R2=0.3927604976957584
# Celda (9,1): MSE=0.15203106699446467, MAE=0.29514970083624864, R2=0.3811237332400581
# Celda (9,2): MSE=0.15445778196535673, MAE=0.3155113490120553, R2=0.37325151482542596
# Celda (9,3): MSE=0.15443345364396438, MAE=0.32116555468371644, R2=0.3685080024993521
# Celda (9,4): MSE=0.14932136499547824, MAE=0.299868270033623, R2=0.39115332095980593
# Celda (9,5): MSE=0.1513487989663172, MAE=0.3069275224609296, R2=0.38478144455066077
# Celda (9,6): MSE=0.15542134087176832, MAE=0.305949996547459, R2=0.3690059232079803
# Celda (9,7): MSE=0.16358335724020945, MAE=0.3127924235748005, R2=0.3381235781308899
# Celda (9,8): MSE=0.1595380779877546, MAE=0.313503955640356, R2=0.3565239092390651
# Celda (9,9): MSE=0.15472352789734314, MAE=0.31068210244068956, R2=0.3732153352661082
# Alphas_up:  [5508, 3000, 5508, 3000, 3000, 3000, 5508, 5508, 5508, 3000, 3000, 3000, 5508, 5508, 5508, 5508, 5508, 5508, 5508, 3000, 5508, 1000, 1000, 5508, 3000, 5508, 1000, 5508, 5508, 1000, 3000, 3000, 1000, 5508, 3000, 5508, 5508, 5508, 3000, 3000, 1000, 1000, 3000, 5508, 5508, 3000, 5508, 5508, 3000, 3000, 1000, 1000, 3000, 5508, 3000, 3000, 5508, 3000, 3000, 5508, 5508, 5508, 5508, 3000, 5508, 5508, 1000, 5508, 3000, 5508, 5508, 3000, 5508, 5508, 5508, 1000, 1000, 5508, 5508, 5508, 5508, 5508, 5508, 1000, 3000, 1000, 3000, 5508, 5508, 5508, 3000, 3000, 5508, 5508, 3000, 5508, 5508, 5508, 5508, 5508]
# Sigmas_up:  [8.0, 16.0, 8.0, 4.0, 8.0, 4.0, 4.0, 4.0, 4.0, 4.0, 16.0, 16.0, 8.0, 4.0, 8.0, 4.0, 4.0, 4.0, 4.0, 4.0, 16.0, 16.0, 8.0, 8.0, 8.0, 4.0, 4.0, 4.0, 4.0, 4.0, 8.0, 4.0, 8.0, 8.0, 4.0, 4.0, 4.0, 4.0, 4.0, 2.0, 8.0, 8.0, 8.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 2.0, 8.0, 8.0, 8.0, 8.0, 4.0, 4.0, 4.0, 4.0, 2.0, 2.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 2.0, 2.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 2.0, 2.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 2.0, 2.0, 2.0, 4.0, 4.0, 2.0, 2.0, 2.0, 4.0, 2.0, 2.0, 2.0, 2.0]
# Lambda_up:  [0.01, 1, 1, 10, 0.01, 10, 10, 1, 1, 0.01, 100, 0.01, 10, 100, 0.01, 10, 10, 1, 1, 0.01, 1, 0.01, 0.01, 0.01, 0.01, 10, 1, 1, 1, 0.01, 10, 10, 0.01, 0.01, 10, 10, 1, 1, 0.01, 1, 0.01, 0.01, 0.01, 10, 10, 1, 1, 1, 0.01, 1, 0.01, 0.01, 0.01, 0.01, 1, 1, 1, 0.01, 1, 1, 10, 10, 10, 1, 1, 1, 0.01, 0.01, 1, 1, 1, 1, 1, 1, 1, 0.01, 0.01, 0.01, 1, 1, 1, 1, 1, 0.01, 0.01, 0.01, 0.01, 1, 1, 1, 0.01, 0.01, 10, 10, 1, 0.01, 1, 1, 1, 1]
# Alphas_mse  [0.015317605834625303, 0.12550143726923624, 0.12338909193650854, 0.14063116526725405, 0.1330590789806866, 0.1395897939295248, 0.14679540346403977, 0.14775038284523723, 0.14696869950437144, 0.15034796483275403, 0.12611238309047143, 0.1357658912391416, 0.1323625095002809, 0.1393912754787683, 0.13943457188874392, 0.14769772914083346, 0.14336008428863964, 0.14611585502348234, 0.15311694436864745, 0.15776620850333106, 0.12527776219134548, 0.13098247492133047, 0.13879625922829264, 0.13339730187538934, 0.1410452915525376, 0.14632167961066064, 0.14842866144117584, 0.14286124852351173, 0.1455527038844854, 0.151925780181739, 0.1416460051664452, 0.1351780114359009, 0.13922426275256108, 0.14827555230381548, 0.1423239410020697, 0.14384387591823128, 0.14559873348076416, 0.1450118390512186, 0.15461305599591746, 0.15918008626930583, 0.13978434652538108, 0.14432740792325777, 0.13656241486935544, 0.14436077549227055, 0.14480712126743425, 0.13992787832752077, 0.14501051327631143, 0.1466623804819752, 0.15257630741074243, 0.15228246316330818, 0.14213515055403864, 0.14441242740527813, 0.13689059961758468, 0.14333266851448784, 0.14367647537078423, 0.1475553509164875, 0.1471705295190612, 0.14648447627126654, 0.15212417211790652, 0.16166554019591609, 0.1403277829798359, 0.13721170383229045, 0.14161805975151356, 0.14701863267194495, 0.14240601759898983, 0.14691822924832265, 0.14861554479802117, 0.15625034781698824, 0.14962614012458816, 0.15877810761638106, 0.14786330971303052, 0.14663447640262442, 0.14435661320051058, 0.15198901516114624, 0.14834092008888977, 0.15426928678747145, 0.15453551128105145, 0.15521676458399897, 0.1564196974607615, 0.16087403234325737, 0.13774537846349896, 0.14628796291346244, 0.14296979901981896, 0.15051612429434783, 0.14865439978065592, 0.15567375587384144, 0.15726414616544246, 0.16055175660186652, 0.1502254965648411, 0.15859010823313477, 0.1489043673869424, 0.15203106699446467, 0.15445778196535673, 0.15443345364396438, 0.14932136499547824, 0.1513487989663172, 0.15542134087176832, 0.16358335724020945, 0.1595380779877546, 0.15472352789734314]
# Alphas_mae  [0.039307966759179344, 0.2576747080495453, 0.2535864420136543, 0.2817820755926831, 0.2699693679118501, 0.2900174643096292, 0.2982113892216628, 0.2943592603012166, 0.30147804600097744, 0.30136530374837367, 0.2592561456881259, 0.27576483819487735, 0.26797114508180525, 0.28842039136513176, 0.2853003213653076, 0.29405084633391715, 0.2997029695173817, 0.2965428586515331, 0.3080803563562505, 0.30966856321908953, 0.256144633041974, 0.26944396453739594, 0.27393816464566445, 0.2675344210871899, 0.28514274709767007, 0.2920397912215594, 0.2990868002216213, 0.29147110266470194, 0.30372672410475565, 0.30937599500629637, 0.2895147523217528, 0.27325987960232284, 0.2729142831596557, 0.2959772777982178, 0.29016939596011654, 0.295632776448803, 0.29335080937615726, 0.3021389644744257, 0.30413647781888187, 0.30956110611519605, 0.2798995630073602, 0.28860663766464484, 0.2830444968738833, 0.28563636851664004, 0.2911297151457817, 0.28866977290845053, 0.2944130307156647, 0.3033337763681436, 0.3017220188439729, 0.30626587475695133, 0.28665662559475624, 0.28889056728865126, 0.2823623842980058, 0.2908262159341147, 0.28988005302464853, 0.2992628636848375, 0.29887838811354744, 0.2976273107102513, 0.3012057076676499, 0.3045599851273736, 0.28647669823273764, 0.285709276219931, 0.2917165291092614, 0.29383162359344334, 0.2892742581695208, 0.3027882792482352, 0.30323571733062593, 0.3071977029646891, 0.30141860449684726, 0.3066405610554224, 0.2974075003404868, 0.29622156405826955, 0.289639306413678, 0.3044936727492649, 0.30135380452413535, 0.3050446876270484, 0.31403126352486427, 0.31348082877269906, 0.30574911933044335, 0.31208687188177603, 0.28445644033906936, 0.297908327955303, 0.2928904873482613, 0.2989414141188899, 0.29905766927271143, 0.3095098261110424, 0.3132358771085212, 0.3079809734134631, 0.30031074695229726, 0.3125085519365373, 0.2915385692780526, 0.29514970083624864, 0.3155113490120553, 0.32116555468371644, 0.299868270033623, 0.3069275224609296, 0.305949996547459, 0.3127924235748005, 0.313503955640356, 0.31068210244068956]
# Alphas_r2  [0.09161740731917833, 0.24125435303833898, 0.4583669541168628, 0.4043450523609131, 0.42871658859023476, 0.42704907662160163, 0.4036213815186206, 0.3981049207643903, 0.3969765200578933, 0.38850464133340823, 0.20741602526627245, 0.29781482349278887, 0.4398232090379788, 0.40543641588357815, 0.41036905839961413, 0.3967361149037695, 0.4194626285434777, 0.40089729993369494, 0.37389132491027655, 0.3586053684635594, 0.4452303213653751, 0.4474286104972909, 0.42708322829733514, 0.4421345387531975, 0.41286771514265075, 0.40754169612988767, 0.3953417973031542, 0.40971575969087637, 0.4074953509329424, 0.3883760875535561, 0.4047363106267229, 0.43206038211888154, 0.421851965861872, 0.3820728893234465, 0.41941670083971183, 0.41462187989571453, 0.40363562671149467, 0.3997288841919815, 0.3749239161310407, 0.3593935184351723, 0.40002515450322107, 0.3864870748757837, 0.4253737348354395, 0.40649895092125377, 0.40796805593225816, 0.4302252544661692, 0.4034965266649422, 0.4007725348413482, 0.38055645579322916, 0.3854134495224374, 0.41575643597663436, 0.40306576232375213, 0.43987128865757286, 0.41839425813046227, 0.41722805077674885, 0.4005339795897159, 0.4067560453830772, 0.40651807486503966, 0.38136834047097856, 0.34247379007691514, 0.4300530000595252, 0.4424798484819561, 0.4225629709825126, 0.4011750665490629, 0.42021974432953657, 0.4085872601338034, 0.403975484676097, 0.36749310401178004, 0.3895340301788086, 0.3528894511399139, 0.3937324044979217, 0.3962499404937577, 0.41028823531803293, 0.37703294554300726, 0.39391442282574896, 0.3779596629727988, 0.3783968962569124, 0.3720494182113332, 0.3651224528291177, 0.34780822798433997, 0.4301602836389026, 0.4034303267825975, 0.41817896905472773, 0.38746891153785235, 0.39183751345278117, 0.36920904597610715, 0.36463118672369843, 0.34919752087818656, 0.3925236954986868, 0.35778857113879936, 0.3927604976957584, 0.3811237332400581, 0.37325151482542596, 0.3685080024993521, 0.39115332095980593, 0.38478144455066077, 0.3690059232079803, 0.3381235781308899, 0.3565239092390651, 0.3732153352661082]
# Sigmas_mse:  [0.015317605834625303, 0.12550143726923624, 0.12338909193650854, 0.14063116526725405, 0.1330590789806866, 0.1395897939295248, 0.14679540346403977, 0.14775038284523723, 0.14696869950437144, 0.15034796483275403, 0.12611238309047143, 0.1357658912391416, 0.1323625095002809, 0.1393912754787683, 0.13943457188874392, 0.14769772914083346, 0.14336008428863964, 0.14611585502348234, 0.15311694436864745, 0.15776620850333106, 0.12527776219134548, 0.13098247492133047, 0.13879625922829264, 0.13339730187538934, 0.1410452915525376, 0.14632167961066064, 0.14842866144117584, 0.14286124852351173, 0.1455527038844854, 0.151925780181739, 0.1416460051664452, 0.1351780114359009, 0.13922426275256108, 0.14827555230381548, 0.1423239410020697, 0.14384387591823128, 0.14559873348076416, 0.1450118390512186, 0.15461305599591746, 0.15918008626930583, 0.13978434652538108, 0.14432740792325777, 0.13656241486935544, 0.14436077549227055, 0.14480712126743425, 0.13992787832752077, 0.14501051327631143, 0.1466623804819752, 0.15257630741074243, 0.15228246316330818, 0.14213515055403864, 0.14441242740527813, 0.13689059961758468, 0.14333266851448784, 0.14367647537078423, 0.1475553509164875, 0.1471705295190612, 0.14648447627126654, 0.15212417211790652, 0.16166554019591609, 0.1403277829798359, 0.13721170383229045, 0.14161805975151356, 0.14701863267194495, 0.14240601759898983, 0.14691822924832265, 0.14861554479802117, 0.15625034781698824, 0.14962614012458816, 0.15877810761638106, 0.14786330971303052, 0.14663447640262442, 0.14435661320051058, 0.15198901516114624, 0.14834092008888977, 0.15426928678747145, 0.15453551128105145, 0.15521676458399897, 0.1564196974607615, 0.16087403234325737, 0.13774537846349896, 0.14628796291346244, 0.14296979901981896, 0.15051612429434783, 0.14865439978065592, 0.15567375587384144, 0.15726414616544246, 0.16055175660186652, 0.1502254965648411, 0.15859010823313477, 0.1489043673869424, 0.15203106699446467, 0.15445778196535673, 0.15443345364396438, 0.14932136499547824, 0.1513487989663172, 0.15542134087176832, 0.16358335724020945, 0.1595380779877546, 0.15472352789734314]
# Sigmas_mae:  [0.039307966759179344, 0.2576747080495453, 0.2535864420136543, 0.2817820755926831, 0.2699693679118501, 0.2900174643096292, 0.2982113892216628, 0.2943592603012166, 0.30147804600097744, 0.30136530374837367, 0.2592561456881259, 0.27576483819487735, 0.26797114508180525, 0.28842039136513176, 0.2853003213653076, 0.29405084633391715, 0.2997029695173817, 0.2965428586515331, 0.3080803563562505, 0.30966856321908953, 0.256144633041974, 0.26944396453739594, 0.27393816464566445, 0.2675344210871899, 0.28514274709767007, 0.2920397912215594, 0.2990868002216213, 0.29147110266470194, 0.30372672410475565, 0.30937599500629637, 0.2895147523217528, 0.27325987960232284, 0.2729142831596557, 0.2959772777982178, 0.29016939596011654, 0.295632776448803, 0.29335080937615726, 0.3021389644744257, 0.30413647781888187, 0.30956110611519605, 0.2798995630073602, 0.28860663766464484, 0.2830444968738833, 0.28563636851664004, 0.2911297151457817, 0.28866977290845053, 0.2944130307156647, 0.3033337763681436, 0.3017220188439729, 0.30626587475695133, 0.28665662559475624, 0.28889056728865126, 0.2823623842980058, 0.2908262159341147, 0.28988005302464853, 0.2992628636848375, 0.29887838811354744, 0.2976273107102513, 0.3012057076676499, 0.3045599851273736, 0.28647669823273764, 0.285709276219931, 0.2917165291092614, 0.29383162359344334, 0.2892742581695208, 0.3027882792482352, 0.30323571733062593, 0.3071977029646891, 0.30141860449684726, 0.3066405610554224, 0.2974075003404868, 0.29622156405826955, 0.289639306413678, 0.3044936727492649, 0.30135380452413535, 0.3050446876270484, 0.31403126352486427, 0.31348082877269906, 0.30574911933044335, 0.31208687188177603, 0.28445644033906936, 0.297908327955303, 0.2928904873482613, 0.2989414141188899, 0.29905766927271143, 0.3095098261110424, 0.3132358771085212, 0.3079809734134631, 0.30031074695229726, 0.3125085519365373, 0.2915385692780526, 0.29514970083624864, 0.3155113490120553, 0.32116555468371644, 0.299868270033623, 0.3069275224609296, 0.305949996547459, 0.3127924235748005, 0.313503955640356, 0.31068210244068956]
# Sigmas_r2:  [0.09161740731917833, 0.24125435303833898, 0.4583669541168628, 0.4043450523609131, 0.42871658859023476, 0.42704907662160163, 0.4036213815186206, 0.3981049207643903, 0.3969765200578933, 0.38850464133340823, 0.20741602526627245, 0.29781482349278887, 0.4398232090379788, 0.40543641588357815, 0.41036905839961413, 0.3967361149037695, 0.4194626285434777, 0.40089729993369494, 0.37389132491027655, 0.3586053684635594, 0.4452303213653751, 0.4474286104972909, 0.42708322829733514, 0.4421345387531975, 0.41286771514265075, 0.40754169612988767, 0.3953417973031542, 0.40971575969087637, 0.4074953509329424, 0.3883760875535561, 0.4047363106267229, 0.43206038211888154, 0.421851965861872, 0.3820728893234465, 0.41941670083971183, 0.41462187989571453, 0.40363562671149467, 0.3997288841919815, 0.3749239161310407, 0.3593935184351723, 0.40002515450322107, 0.3864870748757837, 0.4253737348354395, 0.40649895092125377, 0.40796805593225816, 0.4302252544661692, 0.4034965266649422, 0.4007725348413482, 0.38055645579322916, 0.3854134495224374, 0.41575643597663436, 0.40306576232375213, 0.43987128865757286, 0.41839425813046227, 0.41722805077674885, 0.4005339795897159, 0.4067560453830772, 0.40651807486503966, 0.38136834047097856, 0.34247379007691514, 0.4300530000595252, 0.4424798484819561, 0.4225629709825126, 0.4011750665490629, 0.42021974432953657, 0.4085872601338034, 0.403975484676097, 0.36749310401178004, 0.3895340301788086, 0.3528894511399139, 0.3937324044979217, 0.3962499404937577, 0.41028823531803293, 0.37703294554300726, 0.39391442282574896, 0.3779596629727988, 0.3783968962569124, 0.3720494182113332, 0.3651224528291177, 0.34780822798433997, 0.4301602836389026, 0.4034303267825975, 0.41817896905472773, 0.38746891153785235, 0.39183751345278117, 0.36920904597610715, 0.36463118672369843, 0.34919752087818656, 0.3925236954986868, 0.35778857113879936, 0.3927604976957584, 0.3811237332400581, 0.37325151482542596, 0.3685080024993521, 0.39115332095980593, 0.38478144455066077, 0.3690059232079803, 0.3381235781308899, 0.3565239092390651, 0.3732153352661082]
# Lambda_mse:  [0.015317605834625303, 0.12550143726923624, 0.12338909193650854, 0.14063116526725405, 0.1330590789806866, 0.1395897939295248, 0.14679540346403977, 0.14775038284523723, 0.14696869950437144, 0.15034796483275403, 0.12611238309047143, 0.1357658912391416, 0.1323625095002809, 0.1393912754787683, 0.13943457188874392, 0.14769772914083346, 0.14336008428863964, 0.14611585502348234, 0.15311694436864745, 0.15776620850333106, 0.12527776219134548, 0.13098247492133047, 0.13879625922829264, 0.13339730187538934, 0.1410452915525376, 0.14632167961066064, 0.14842866144117584, 0.14286124852351173, 0.1455527038844854, 0.151925780181739, 0.1416460051664452, 0.1351780114359009, 0.13922426275256108, 0.14827555230381548, 0.1423239410020697, 0.14384387591823128, 0.14559873348076416, 0.1450118390512186, 0.15461305599591746, 0.15918008626930583, 0.13978434652538108, 0.14432740792325777, 0.13656241486935544, 0.14436077549227055, 0.14480712126743425, 0.13992787832752077, 0.14501051327631143, 0.1466623804819752, 0.15257630741074243, 0.15228246316330818, 0.14213515055403864, 0.14441242740527813, 0.13689059961758468, 0.14333266851448784, 0.14367647537078423, 0.1475553509164875, 0.1471705295190612, 0.14648447627126654, 0.15212417211790652, 0.16166554019591609, 0.1403277829798359, 0.13721170383229045, 0.14161805975151356, 0.14701863267194495, 0.14240601759898983, 0.14691822924832265, 0.14861554479802117, 0.15625034781698824, 0.14962614012458816, 0.15877810761638106, 0.14786330971303052, 0.14663447640262442, 0.14435661320051058, 0.15198901516114624, 0.14834092008888977, 0.15426928678747145, 0.15453551128105145, 0.15521676458399897, 0.1564196974607615, 0.16087403234325737, 0.13774537846349896, 0.14628796291346244, 0.14296979901981896, 0.15051612429434783, 0.14865439978065592, 0.15567375587384144, 0.15726414616544246, 0.16055175660186652, 0.1502254965648411, 0.15859010823313477, 0.1489043673869424, 0.15203106699446467, 0.15445778196535673, 0.15443345364396438, 0.14932136499547824, 0.1513487989663172, 0.15542134087176832, 0.16358335724020945, 0.1595380779877546, 0.15472352789734314]
# Lambda_mae:  [0.039307966759179344, 0.2576747080495453, 0.2535864420136543, 0.2817820755926831, 0.2699693679118501, 0.2900174643096292, 0.2982113892216628, 0.2943592603012166, 0.30147804600097744, 0.30136530374837367, 0.2592561456881259, 0.27576483819487735, 0.26797114508180525, 0.28842039136513176, 0.2853003213653076, 0.29405084633391715, 0.2997029695173817, 0.2965428586515331, 0.3080803563562505, 0.30966856321908953, 0.256144633041974, 0.26944396453739594, 0.27393816464566445, 0.2675344210871899, 0.28514274709767007, 0.2920397912215594, 0.2990868002216213, 0.29147110266470194, 0.30372672410475565, 0.30937599500629637, 0.2895147523217528, 0.27325987960232284, 0.2729142831596557, 0.2959772777982178, 0.29016939596011654, 0.295632776448803, 0.29335080937615726, 0.3021389644744257, 0.30413647781888187, 0.30956110611519605, 0.2798995630073602, 0.28860663766464484, 0.2830444968738833, 0.28563636851664004, 0.2911297151457817, 0.28866977290845053, 0.2944130307156647, 0.3033337763681436, 0.3017220188439729, 0.30626587475695133, 0.28665662559475624, 0.28889056728865126, 0.2823623842980058, 0.2908262159341147, 0.28988005302464853, 0.2992628636848375, 0.29887838811354744, 0.2976273107102513, 0.3012057076676499, 0.3045599851273736, 0.28647669823273764, 0.285709276219931, 0.2917165291092614, 0.29383162359344334, 0.2892742581695208, 0.3027882792482352, 0.30323571733062593, 0.3071977029646891, 0.30141860449684726, 0.3066405610554224, 0.2974075003404868, 0.29622156405826955, 0.289639306413678, 0.3044936727492649, 0.30135380452413535, 0.3050446876270484, 0.31403126352486427, 0.31348082877269906, 0.30574911933044335, 0.31208687188177603, 0.28445644033906936, 0.297908327955303, 0.2928904873482613, 0.2989414141188899, 0.29905766927271143, 0.3095098261110424, 0.3132358771085212, 0.3079809734134631, 0.30031074695229726, 0.3125085519365373, 0.2915385692780526, 0.29514970083624864, 0.3155113490120553, 0.32116555468371644, 0.299868270033623, 0.3069275224609296, 0.305949996547459, 0.3127924235748005, 0.313503955640356, 0.31068210244068956]
# Lambda_r2:  [0.09161740731917833, 0.24125435303833898, 0.4583669541168628, 0.4043450523609131, 0.42871658859023476, 0.42704907662160163, 0.4036213815186206, 0.3981049207643903, 0.3969765200578933, 0.38850464133340823, 0.20741602526627245, 0.29781482349278887, 0.4398232090379788, 0.40543641588357815, 0.41036905839961413, 0.3967361149037695, 0.4194626285434777, 0.40089729993369494, 0.37389132491027655, 0.3586053684635594, 0.4452303213653751, 0.4474286104972909, 0.42708322829733514, 0.4421345387531975, 0.41286771514265075, 0.40754169612988767, 0.3953417973031542, 0.40971575969087637, 0.4074953509329424, 0.3883760875535561, 0.4047363106267229, 0.43206038211888154, 0.421851965861872, 0.3820728893234465, 0.41941670083971183, 0.41462187989571453, 0.40363562671149467, 0.3997288841919815, 0.3749239161310407, 0.3593935184351723, 0.40002515450322107, 0.3864870748757837, 0.4253737348354395, 0.40649895092125377, 0.40796805593225816, 0.4302252544661692, 0.4034965266649422, 0.4007725348413482, 0.38055645579322916, 0.3854134495224374, 0.41575643597663436, 0.40306576232375213, 0.43987128865757286, 0.41839425813046227, 0.41722805077674885, 0.4005339795897159, 0.4067560453830772, 0.40651807486503966, 0.38136834047097856, 0.34247379007691514, 0.4300530000595252, 0.4424798484819561, 0.4225629709825126, 0.4011750665490629, 0.42021974432953657, 0.4085872601338034, 0.403975484676097, 0.36749310401178004, 0.3895340301788086, 0.3528894511399139, 0.3937324044979217, 0.3962499404937577, 0.41028823531803293, 0.37703294554300726, 0.39391442282574896, 0.3779596629727988, 0.3783968962569124, 0.3720494182113332, 0.3651224528291177, 0.34780822798433997, 0.4301602836389026, 0.4034303267825975, 0.41817896905472773, 0.38746891153785235, 0.39183751345278117, 0.36920904597610715, 0.36463118672369843, 0.34919752087818656, 0.3925236954986868, 0.35778857113879936, 0.3927604976957584, 0.3811237332400581, 0.37325151482542596, 0.3685080024993521, 0.39115332095980593, 0.38478144455066077, 0.3690059232079803, 0.3381235781308899, 0.3565239092390651, 0.3732153352661082]
# Gráficos guardados en hyperparam_optimization_results.pdf
# c:\Users\ismae\OneDrive\Cosas inutiles\Escritorio\master\TFM\cupy-env\Lib\site-packages\pandas\plotting\_matplotlib\tools.py:233: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig = plt.figure(**fig_kw)
# Gráficos guardados en hyperparam_optimization_results_boxplot.pdf
# Celda: 0, Alpha: 1, Valores: 0.017156854013030142
# Celda: 0, Alpha: 10, Valores: 0.01661911608946834
# Celda: 0, Alpha: 100, Valores: 0.0159970814841206
# Celda: 0, Alpha: 1000, Valores: 0.015394828380671783
# Celda: 0, Alpha: 3000, Valores: 0.015341418154192689
# Celda: 0, Alpha: 5508, Valores: 0.015317605834625252
# Celda: 1, Alpha: 1, Valores: 0.20790092925880493
# Celda: 1, Alpha: 10, Valores: 0.16420721191101156
# Celda: 1, Alpha: 100, Valores: 0.12628971935014324
# Celda: 1, Alpha: 1000, Valores: 0.12553576704036323
# Celda: 1, Alpha: 3000, Valores: 0.12550605736543902
# Celda: 1, Alpha: 5508, Valores: 0.12550610514731164
# Celda: 2, Alpha: 1, Valores: 0.34047311792289725
# Celda: 2, Alpha: 10, Valores: 0.3235864603011646
# Celda: 2, Alpha: 100, Valores: 0.12892682604606934
# Celda: 2, Alpha: 1000, Valores: 0.12348982346848619
# Celda: 2, Alpha: 3000, Valores: 0.12343065437389573
# Celda: 2, Alpha: 5508, Valores: 0.12338909193650857
# Celda: 3, Alpha: 1, Valores: 0.3808813695435786
# Celda: 3, Alpha: 10, Valores: 0.36270157766472044
# Celda: 3, Alpha: 100, Valores: 0.19690149294612402
# Celda: 3, Alpha: 1000, Valores: 0.14141207637691716
# Celda: 3, Alpha: 3000, Valores: 0.14054637560851535
# Celda: 3, Alpha: 5508, Valores: 0.1408678094171492
# Celda: 4, Alpha: 1, Valores: 0.36342630725480296
# Celda: 4, Alpha: 10, Valores: 0.2745853483403402
# Celda: 4, Alpha: 100, Valores: 0.15650661529989013
# Celda: 4, Alpha: 1000, Valores: 0.13370178464087937
# Celda: 4, Alpha: 3000, Valores: 0.1330376481795391
# Celda: 4, Alpha: 5508, Valores: 0.1330663574926146
# Celda: 5, Alpha: 1, Valores: 0.4151943370055551
# Celda: 5, Alpha: 10, Valores: 0.3934834800151887
# Celda: 5, Alpha: 100, Valores: 0.2367821302934095
# Celda: 5, Alpha: 1000, Valores: 0.1426654258966946
# Celda: 5, Alpha: 3000, Valores: 0.13971494277712637
# Celda: 5, Alpha: 5508, Valores: 0.13982512351585033
# Celda: 6, Alpha: 1, Valores: 0.4320807549232123
# Celda: 6, Alpha: 10, Valores: 0.41305803629268834
# Celda: 6, Alpha: 100, Valores: 0.2542647966634033
# Celda: 6, Alpha: 1000, Valores: 0.15358570548252
# Celda: 6, Alpha: 3000, Valores: 0.1475264341072801
# Celda: 6, Alpha: 5508, Valores: 0.14679540346403977
# Celda: 7, Alpha: 1, Valores: 0.429102323407295
# Celda: 7, Alpha: 10, Valores: 0.39630245832631045
# Celda: 7, Alpha: 100, Valores: 0.2393119139789607
# Celda: 7, Alpha: 1000, Valores: 0.15265203886548134
# Celda: 7, Alpha: 3000, Valores: 0.14834236536725925
# Celda: 7, Alpha: 5508, Valores: 0.14775038284523723
# Celda: 8, Alpha: 1, Valores: 0.4157192434734434
# Celda: 8, Alpha: 10, Valores: 0.3905367252167042
# Celda: 8, Alpha: 100, Valores: 0.2482147514285683
# Celda: 8, Alpha: 1000, Valores: 0.15567406030805953
# Celda: 8, Alpha: 3000, Valores: 0.14808614999518077
# Celda: 8, Alpha: 5508, Valores: 0.14696869950437141
# Celda: 9, Alpha: 1, Valores: 0.4295566692953543
# Celda: 9, Alpha: 10, Valores: 0.40918397741941015
# Celda: 9, Alpha: 100, Valores: 0.25829926726594515
# Celda: 9, Alpha: 1000, Valores: 0.15114001905512517
# Celda: 9, Alpha: 3000, Valores: 0.15079275458286215
# Celda: 9, Alpha: 5508, Valores: 0.1513241924038251
# Celda: 10, Alpha: 1, Valores: 0.18466747269825193
# Celda: 10, Alpha: 10, Valores: 0.16497127178013482
# Celda: 10, Alpha: 100, Valores: 0.13299859481392598
# Celda: 10, Alpha: 1000, Valores: 0.12623611542387725
# Celda: 10, Alpha: 3000, Valores: 0.12609175670886677
# Celda: 10, Alpha: 5508, Valores: 0.12613461184524127
# Celda: 11, Alpha: 1, Valores: 0.25982478472680204
# Celda: 11, Alpha: 10, Valores: 0.18408217498344093
# Celda: 11, Alpha: 100, Valores: 0.13633772670944566
# Celda: 11, Alpha: 1000, Valores: 0.13587385513021014
# Celda: 11, Alpha: 3000, Valores: 0.13574940604918123
# Celda: 11, Alpha: 5508, Valores: 0.1357526392931937
# Celda: 12, Alpha: 1, Valores: 0.36687963997204387
# Celda: 12, Alpha: 10, Valores: 0.29933285757832323
# Celda: 12, Alpha: 100, Valores: 0.14203982429845494
# Celda: 12, Alpha: 1000, Valores: 0.13295805540202027
# Celda: 12, Alpha: 3000, Valores: 0.1325102594331009
# Celda: 12, Alpha: 5508, Valores: 0.1323625095002809
# Celda: 13, Alpha: 1, Valores: 0.37480582746897223
# Celda: 13, Alpha: 10, Valores: 0.3576768760274196
# Celda: 13, Alpha: 100, Valores: 0.2840737990219462
# Celda: 13, Alpha: 1000, Valores: 0.15246897007007126
# Celda: 13, Alpha: 3000, Valores: 0.14071252916032428
# Celda: 13, Alpha: 5508, Valores: 0.13939127547876828
# Celda: 14, Alpha: 1, Valores: 0.3702508648926444
# Celda: 14, Alpha: 10, Valores: 0.2970161825425963
# Celda: 14, Alpha: 100, Valores: 0.15748237678603388
# Celda: 14, Alpha: 1000, Valores: 0.14009038231113174
# Celda: 14, Alpha: 3000, Valores: 0.13953150677685985
# Celda: 14, Alpha: 5508, Valores: 0.1394345718887455
# Celda: 15, Alpha: 1, Valores: 0.4223994442161836
# Celda: 15, Alpha: 10, Valores: 0.39417038767843
# Celda: 15, Alpha: 100, Valores: 0.24793023453530638
# Celda: 15, Alpha: 1000, Valores: 0.15305741423604452
# Celda: 15, Alpha: 3000, Valores: 0.14772663727552035
# Celda: 15, Alpha: 5508, Valores: 0.14769772914083348
# Celda: 16, Alpha: 1, Valores: 0.43399068027940635
# Celda: 16, Alpha: 10, Valores: 0.4026913097908422
# Celda: 16, Alpha: 100, Valores: 0.2493201623936475
# Celda: 16, Alpha: 1000, Valores: 0.15139136498552822
# Celda: 16, Alpha: 3000, Valores: 0.14458148349255656
# Celda: 16, Alpha: 5508, Valores: 0.1433600842886397
# Celda: 17, Alpha: 1, Valores: 0.4216904729610179
# Celda: 17, Alpha: 10, Valores: 0.39129558393027475
# Celda: 17, Alpha: 100, Valores: 0.23301524634033055
# Celda: 17, Alpha: 1000, Valores: 0.15075190341768993
# Celda: 17, Alpha: 3000, Valores: 0.14681441972919815
# Celda: 17, Alpha: 5508, Valores: 0.14611585502348237
# Celda: 18, Alpha: 1, Valores: 0.42114046407406225
# Celda: 18, Alpha: 10, Valores: 0.38740139893385384
# Celda: 18, Alpha: 100, Valores: 0.2500574117783997
# Celda: 18, Alpha: 1000, Valores: 0.16323087405588763
# Celda: 18, Alpha: 3000, Valores: 0.1538856428599403
# Celda: 18, Alpha: 5508, Valores: 0.15311694436864745
# Celda: 19, Alpha: 1, Valores: 0.4298780218811519
# Celda: 19, Alpha: 10, Valores: 0.4014190199757389
# Celda: 19, Alpha: 100, Valores: 0.2530944372561871
# Celda: 19, Alpha: 1000, Valores: 0.15852191977396554
# Celda: 19, Alpha: 3000, Valores: 0.1579419471116154
# Celda: 19, Alpha: 5508, Valores: 0.15832928208767524
# Celda: 20, Alpha: 1, Valores: 0.3036499799583803
# Celda: 20, Alpha: 10, Valores: 0.253978890107486
# Celda: 20, Alpha: 100, Valores: 0.1280638758701693
# Celda: 20, Alpha: 1000, Valores: 0.12594212590848872
# Celda: 20, Alpha: 3000, Valores: 0.12538015338488465
# Celda: 20, Alpha: 5508, Valores: 0.12527776219134545
# Celda: 21, Alpha: 1, Valores: 0.3379276213756751
# Celda: 21, Alpha: 10, Valores: 0.2682670068368362
# Celda: 21, Alpha: 100, Valores: 0.13152157272793552
# Celda: 21, Alpha: 1000, Valores: 0.1309674760967221
# Celda: 21, Alpha: 3000, Valores: 0.131018009745048
# Celda: 21, Alpha: 5508, Valores: 0.13097485168921336
# Celda: 22, Alpha: 1, Valores: 0.4000149748171702
# Celda: 22, Alpha: 10, Valores: 0.32530596047042937
# Celda: 22, Alpha: 100, Valores: 0.14774116120030503
# Celda: 22, Alpha: 1000, Valores: 0.1388474206004583
# Celda: 22, Alpha: 3000, Valores: 0.1390439934568018
# Celda: 22, Alpha: 5508, Valores: 0.1392907291849285
# Celda: 23, Alpha: 1, Valores: 0.38576704862334166
# Celda: 23, Alpha: 10, Valores: 0.27791673232344954
# Celda: 23, Alpha: 100, Valores: 0.1437710808138438
# Celda: 23, Alpha: 1000, Valores: 0.13418275184934256
# Celda: 23, Alpha: 3000, Valores: 0.1335512746856555
# Celda: 23, Alpha: 5508, Valores: 0.13339730187538937
# Celda: 24, Alpha: 1, Valores: 0.3830909395690391
# Celda: 24, Alpha: 10, Valores: 0.31428601433000547
# Celda: 24, Alpha: 100, Valores: 0.16050322984892784
# Celda: 24, Alpha: 1000, Valores: 0.14148048463825885
# Celda: 24, Alpha: 3000, Valores: 0.14092528328596268
# Celda: 24, Alpha: 5508, Valores: 0.1410402098635275
# Celda: 25, Alpha: 1, Valores: 0.44492229435230424
# Celda: 25, Alpha: 10, Valores: 0.4145826152412955
# Celda: 25, Alpha: 100, Valores: 0.27258367092361735
# Celda: 25, Alpha: 1000, Valores: 0.15018246861423334
# Celda: 25, Alpha: 3000, Valores: 0.1465599509044956
# Celda: 25, Alpha: 5508, Valores: 0.14632167961066064
# Celda: 26, Alpha: 1, Valores: 0.430981354364694
# Celda: 26, Alpha: 10, Valores: 0.3981563336707337
# Celda: 26, Alpha: 100, Valores: 0.2667512595476099
# Celda: 26, Alpha: 1000, Valores: 0.14730016302682006
# Celda: 26, Alpha: 3000, Valores: 0.14860236530597176
# Celda: 26, Alpha: 5508, Valores: 0.14908624234487894
# Celda: 27, Alpha: 1, Valores: 0.40983559542666104
# Celda: 27, Alpha: 10, Valores: 0.3638331067219729
# Celda: 27, Alpha: 100, Valores: 0.25226654180204033
# Celda: 27, Alpha: 1000, Valores: 0.1504921408031034
# Celda: 27, Alpha: 3000, Valores: 0.14379382676778235
# Celda: 27, Alpha: 5508, Valores: 0.14286124852351179
# Celda: 28, Alpha: 1, Valores: 0.4278030290754853
# Celda: 28, Alpha: 10, Valores: 0.39588902033571677
# Celda: 28, Alpha: 100, Valores: 0.2581551558229962
# Celda: 28, Alpha: 1000, Valores: 0.1578807927527788
# Celda: 28, Alpha: 3000, Valores: 0.14669234058856173
# Celda: 28, Alpha: 5508, Valores: 0.1455527038844855
# Celda: 29, Alpha: 1, Valores: 0.45499428498813194
# Celda: 29, Alpha: 10, Valores: 0.43004038168892667
# Celda: 29, Alpha: 100, Valores: 0.2680368075630848
# Celda: 29, Alpha: 1000, Valores: 0.15177812283102252
# Celda: 29, Alpha: 3000, Valores: 0.15294239274181343
# Celda: 29, Alpha: 5508, Valores: 0.1537798116312528
# Celda: 30, Alpha: 1, Valores: 0.3627158134249339
# Celda: 30, Alpha: 10, Valores: 0.27048786053262897
# Celda: 30, Alpha: 100, Valores: 0.15942171527985663
# Celda: 30, Alpha: 1000, Valores: 0.14198969396802028
# Celda: 30, Alpha: 3000, Valores: 0.14175957308694273
# Celda: 30, Alpha: 5508, Valores: 0.1418541396690436
# Celda: 31, Alpha: 1, Valores: 0.38312883096621014
# Celda: 31, Alpha: 10, Valores: 0.36736689771763603
# Celda: 31, Alpha: 100, Valores: 0.2110566538291988
# Celda: 31, Alpha: 1000, Valores: 0.1367641547420428
# Celda: 31, Alpha: 3000, Valores: 0.13515513052314798
# Celda: 31, Alpha: 5508, Valores: 0.13526000141943825
# Celda: 32, Alpha: 1, Valores: 0.39513791003331344
# Celda: 32, Alpha: 10, Valores: 0.33207202574363315
# Celda: 32, Alpha: 100, Valores: 0.14884454608167408
# Celda: 32, Alpha: 1000, Valores: 0.13927008244625508
# Celda: 32, Alpha: 3000, Valores: 0.13943619948328134
# Celda: 32, Alpha: 5508, Valores: 0.13960149384834275
# Celda: 33, Alpha: 1, Valores: 0.396197588057374
# Celda: 33, Alpha: 10, Valores: 0.31673840051743996
# Celda: 33, Alpha: 100, Valores: 0.16377998587167283
# Celda: 33, Alpha: 1000, Valores: 0.14913858876414138
# Celda: 33, Alpha: 3000, Valores: 0.14843402812852918
# Celda: 33, Alpha: 5508, Valores: 0.14827555230381384
# Celda: 34, Alpha: 1, Valores: 0.4242509012307125
# Celda: 34, Alpha: 10, Valores: 0.422165157427103
# Celda: 34, Alpha: 100, Valores: 0.22789981874175447
# Celda: 34, Alpha: 1000, Valores: 0.14598651535491863
# Celda: 34, Alpha: 3000, Valores: 0.14200673705254752
# Celda: 34, Alpha: 5508, Valores: 0.14205097459588825
# Celda: 35, Alpha: 1, Valores: 0.43238364082975783
# Celda: 35, Alpha: 10, Valores: 0.40229258202406626
# Celda: 35, Alpha: 100, Valores: 0.2541240865062805
# Celda: 35, Alpha: 1000, Valores: 0.1510066983515912
# Celda: 35, Alpha: 3000, Valores: 0.14413869342730104
# Celda: 35, Alpha: 5508, Valores: 0.1438438759182313
# Celda: 36, Alpha: 1, Valores: 0.4184621108486469
# Celda: 36, Alpha: 10, Valores: 0.38753149472134346
# Celda: 36, Alpha: 100, Valores: 0.24158158831440527
# Celda: 36, Alpha: 1000, Valores: 0.14637666280800699
# Celda: 36, Alpha: 3000, Valores: 0.14575621036086128
# Celda: 36, Alpha: 5508, Valores: 0.14559873348076413
# Celda: 37, Alpha: 1, Valores: 0.40284119249784495
# Celda: 37, Alpha: 10, Valores: 0.3805951577536027
# Celda: 37, Alpha: 100, Valores: 0.2396566826096994
# Celda: 37, Alpha: 1000, Valores: 0.15299720772144426
# Celda: 37, Alpha: 3000, Valores: 0.1455567479940604
# Celda: 37, Alpha: 5508, Valores: 0.14501183905121862
# Celda: 38, Alpha: 1, Valores: 0.44336005911626636
# Celda: 38, Alpha: 10, Valores: 0.4200613568707055
# Celda: 38, Alpha: 100, Valores: 0.2597989475501469
# Celda: 38, Alpha: 1000, Valores: 0.15581737053170455
# Celda: 38, Alpha: 3000, Valores: 0.15471486337546866
# Celda: 38, Alpha: 5508, Valores: 0.15524344031812598
# Celda: 39, Alpha: 1, Valores: 0.4607296687233086
# Celda: 39, Alpha: 10, Valores: 0.44749530680489874
# Celda: 39, Alpha: 100, Valores: 0.371520404944365
# Celda: 39, Alpha: 1000, Valores: 0.1743790975864125
# Celda: 39, Alpha: 3000, Valores: 0.1588961620286557
# Celda: 39, Alpha: 5508, Valores: 0.15942302518412002
# Celda: 40, Alpha: 1, Valores: 0.369111899356957
# Celda: 40, Alpha: 10, Valores: 0.3096631551227171
# Celda: 40, Alpha: 100, Valores: 0.15181210849292284
# Celda: 40, Alpha: 1000, Valores: 0.139797472113584
# Celda: 40, Alpha: 3000, Valores: 0.1398936243761889
# Celda: 40, Alpha: 5508, Valores: 0.1399641773335369
# Celda: 41, Alpha: 1, Valores: 0.366991694408879
# Celda: 41, Alpha: 10, Valores: 0.3026661253107144
# Celda: 41, Alpha: 100, Valores: 0.16265777189269545
# Celda: 41, Alpha: 1000, Valores: 0.14416242981917607
# Celda: 41, Alpha: 3000, Valores: 0.1443900244834545
# Celda: 41, Alpha: 5508, Valores: 0.14447848526574933
# Celda: 42, Alpha: 1, Valores: 0.384183704983061
# Celda: 42, Alpha: 10, Valores: 0.3158388768626521
# Celda: 42, Alpha: 100, Valores: 0.15807887145666763
# Celda: 42, Alpha: 1000, Valores: 0.1366601348493184
# Celda: 42, Alpha: 3000, Valores: 0.13654546730513145
# Celda: 42, Alpha: 5508, Valores: 0.13674336968707537
# Celda: 43, Alpha: 1, Valores: 0.4154924801226485
# Celda: 43, Alpha: 10, Valores: 0.3959144817414602
# Celda: 43, Alpha: 100, Valores: 0.23088108640836452
# Celda: 43, Alpha: 1000, Valores: 0.15062339635128175
# Celda: 43, Alpha: 3000, Valores: 0.14467522878002886
# Celda: 43, Alpha: 5508, Valores: 0.14436077549227055
# Celda: 44, Alpha: 1, Valores: 0.4246773998769114
# Celda: 44, Alpha: 10, Valores: 0.3907510130921094
# Celda: 44, Alpha: 100, Valores: 0.24260114475587563
# Celda: 44, Alpha: 1000, Valores: 0.1500540435508095
# Celda: 44, Alpha: 3000, Valores: 0.14557627159548944
# Celda: 44, Alpha: 5508, Valores: 0.14480712126743425
# Celda: 45, Alpha: 1, Valores: 0.4314359653296135
# Celda: 45, Alpha: 10, Valores: 0.38874453972016443
# Celda: 45, Alpha: 100, Valores: 0.24615968838546645
# Celda: 45, Alpha: 1000, Valores: 0.14108299826314813
# Celda: 45, Alpha: 3000, Valores: 0.13988326515029761
# Celda: 45, Alpha: 5508, Valores: 0.14024667549184858
# Celda: 46, Alpha: 1, Valores: 0.41369840183729595
# Celda: 46, Alpha: 10, Valores: 0.3788270276559008
# Celda: 46, Alpha: 100, Valores: 0.25031831238477853
# Celda: 46, Alpha: 1000, Valores: 0.14800252735334105
# Celda: 46, Alpha: 3000, Valores: 0.14560345663383847
# Celda: 46, Alpha: 5508, Valores: 0.14501051327631137
# Celda: 47, Alpha: 1, Valores: 0.425092302462807
# Celda: 47, Alpha: 10, Valores: 0.3914975983777578
# Celda: 47, Alpha: 100, Valores: 0.24711948809345824
# Celda: 47, Alpha: 1000, Valores: 0.15643961232759784
# Celda: 47, Alpha: 3000, Valores: 0.14795645198715934
# Celda: 47, Alpha: 5508, Valores: 0.14666238048197522
# Celda: 48, Alpha: 1, Valores: 0.43605319599401254
# Celda: 48, Alpha: 10, Valores: 0.39906733866568894
# Celda: 48, Alpha: 100, Valores: 0.25596908230940957
# Celda: 48, Alpha: 1000, Valores: 0.15339001850207046
# Celda: 48, Alpha: 3000, Valores: 0.15272222174834635
# Celda: 48, Alpha: 5508, Valores: 0.15305228490545508
# Celda: 49, Alpha: 1, Valores: 0.452886931275948
# Celda: 49, Alpha: 10, Valores: 0.43800408550176273
# Celda: 49, Alpha: 100, Valores: 0.3574012046931265
# Celda: 49, Alpha: 1000, Valores: 0.17150704933238797
# Celda: 49, Alpha: 3000, Valores: 0.15264026234935318
# Celda: 49, Alpha: 5508, Valores: 0.15305673477312806
# Celda: 50, Alpha: 1, Valores: 0.40364423415217676
# Celda: 50, Alpha: 10, Valores: 0.29965735597088333
# Celda: 50, Alpha: 100, Valores: 0.17961324699122597
# Celda: 50, Alpha: 1000, Valores: 0.14204026469188485
# Celda: 50, Alpha: 3000, Valores: 0.14218650043452846
# Celda: 50, Alpha: 5508, Valores: 0.14231637649782328
# Celda: 51, Alpha: 1, Valores: 0.40499017843564755
# Celda: 51, Alpha: 10, Valores: 0.3225671816888372
# Celda: 51, Alpha: 100, Valores: 0.17286063620614378
# Celda: 51, Alpha: 1000, Valores: 0.14404313671796054
# Celda: 51, Alpha: 3000, Valores: 0.14430439942438913
# Celda: 51, Alpha: 5508, Valores: 0.14460910747375785
# Celda: 52, Alpha: 1, Valores: 0.4128850680467628
# Celda: 52, Alpha: 10, Valores: 0.35676501408288236
# Celda: 52, Alpha: 100, Valores: 0.1720094228528406
# Celda: 52, Alpha: 1000, Valores: 0.13770156174005627
# Celda: 52, Alpha: 3000, Valores: 0.13685213659976483
# Celda: 52, Alpha: 5508, Valores: 0.1370676931531297
# Celda: 53, Alpha: 1, Valores: 0.4211990255402583
# Celda: 53, Alpha: 10, Valores: 0.32980956835944636
# Celda: 53, Alpha: 100, Valores: 0.18888375652801584
# Celda: 53, Alpha: 1000, Valores: 0.14572306254643033
# Celda: 53, Alpha: 3000, Valores: 0.14347819887028251
# Celda: 53, Alpha: 5508, Valores: 0.14333266851447896
# Celda: 54, Alpha: 1, Valores: 0.4353009671943056
# Celda: 54, Alpha: 10, Valores: 0.40968975867593915
# Celda: 54, Alpha: 100, Valores: 0.25633245712102903
# Celda: 54, Alpha: 1000, Valores: 0.14442644738162985
# Celda: 54, Alpha: 3000, Valores: 0.14370788699505266
# Celda: 54, Alpha: 5508, Valores: 0.14395175384964162
# Celda: 55, Alpha: 1, Valores: 0.4377019305004675
# Celda: 55, Alpha: 10, Valores: 0.3989656715785148
# Celda: 55, Alpha: 100, Valores: 0.2510082017455073
# Celda: 55, Alpha: 1000, Valores: 0.15015793026615032
# Celda: 55, Alpha: 3000, Valores: 0.14729945132472186
# Celda: 55, Alpha: 5508, Valores: 0.14736781325505383
# Celda: 56, Alpha: 1, Valores: 0.4558953772878722
# Celda: 56, Alpha: 10, Valores: 0.4107062823658162
# Celda: 56, Alpha: 100, Valores: 0.2499380812137806
# Celda: 56, Alpha: 1000, Valores: 0.1553753777784534
# Celda: 56, Alpha: 3000, Valores: 0.14796204733368296
# Celda: 56, Alpha: 5508, Valores: 0.14717052951906118
# Celda: 57, Alpha: 1, Valores: 0.43995665975680076
# Celda: 57, Alpha: 10, Valores: 0.40670432175809784
# Celda: 57, Alpha: 100, Valores: 0.25538817725493457
# Celda: 57, Alpha: 1000, Valores: 0.1469762603905288
# Celda: 57, Alpha: 3000, Valores: 0.14639487810972954
# Celda: 57, Alpha: 5508, Valores: 0.14681439617740732
# Celda: 58, Alpha: 1, Valores: 0.4350855351236785
# Celda: 58, Alpha: 10, Valores: 0.42789314134151213
# Celda: 58, Alpha: 100, Valores: 0.3604604798047217
# Celda: 58, Alpha: 1000, Valores: 0.1733240299238402
# Celda: 58, Alpha: 3000, Valores: 0.1526780903180132
# Celda: 58, Alpha: 5508, Valores: 0.15308911191290783
# Celda: 59, Alpha: 1, Valores: 0.4346327926849421
# Celda: 59, Alpha: 10, Valores: 0.42583074611141575
# Celda: 59, Alpha: 100, Valores: 0.3401518745540867
# Celda: 59, Alpha: 1000, Valores: 0.17685249961959132
# Celda: 59, Alpha: 3000, Valores: 0.1620160108922038
# Celda: 59, Alpha: 5508, Valores: 0.1616655401959161
# Celda: 60, Alpha: 1, Valores: 0.4321680235963706
# Celda: 60, Alpha: 10, Valores: 0.40198850154993493
# Celda: 60, Alpha: 100, Valores: 0.2442376462880932
# Celda: 60, Alpha: 1000, Valores: 0.14650109277787907
# ...
# Celda: 67, Lambda: 100, Valores: 0.21899252441683736
# Celda: 68, Lambda: 0.01, Valores: 0.29691159130069156
# Celda: 68, Lambda: 1, Valores: 0.38899477999535903
# Celda: 68, Lambda: 10, Valores: 0.34652794087967564
# Celda: 68, Lambda: 100, Valores: 0.015300807820969764
# Celda: 69, Lambda: 0.01, Valores: 0.24330360710417687
# Celda: 69, Lambda: 1, Valores: 0.3528894511399139
# Celda: 69, Lambda: 10, Valores: 0.33566804168868614
# Celda: 69, Lambda: 100, Valores: 0.12459983784307738
# Celda: 70, Lambda: 0.01, Valores: 0.37405243019518464
# Celda: 70, Lambda: 1, Valores: 0.3937324044979217
# Celda: 70, Lambda: 10, Valores: 0.3880922112915114
# Celda: 70, Lambda: 100, Valores: 0.3269427184929674
# Celda: 71, Lambda: 0.01, Valores: 0.375743242976312
# Celda: 71, Lambda: 1, Valores: 0.39645004243946347
# Celda: 71, Lambda: 10, Valores: 0.3772438782528059
# Celda: 71, Lambda: 100, Valores: 0.28519796334146996
# Celda: 72, Lambda: 0.01, Valores: 0.3877515042597266
# Celda: 72, Lambda: 1, Valores: 0.41028823531803293
# Celda: 72, Lambda: 10, Valores: 0.3935061333379878
# Celda: 72, Lambda: 100, Valores: 0.31635657467948375
# Celda: 73, Lambda: 0.01, Valores: 0.35760446374917776
# Celda: 73, Lambda: 1, Valores: 0.37703294554300726
# Celda: 73, Lambda: 10, Valores: 0.35700555949275226
# Celda: 73, Lambda: 100, Valores: 0.27078833486948983
# Celda: 74, Lambda: 0.01, Valores: 0.3906203572215252
# Celda: 74, Lambda: 1, Valores: 0.39391442282574907
# Celda: 74, Lambda: 10, Valores: 0.35211629751723017
# Celda: 74, Lambda: 100, Valores: 0.24605432728747645
# Celda: 75, Lambda: 0.01, Valores: 0.37905119351037353
# Celda: 75, Lambda: 1, Valores: 0.34182064722443095
# Celda: 75, Lambda: 10, Valores: 0.25725029726411996
# Celda: 75, Lambda: 100, Valores: 0.1154060536334317
# Celda: 76, Lambda: 0.01, Valores: 0.3809049556220139
# Celda: 76, Lambda: 1, Valores: 0.3108909329589181
# Celda: 76, Lambda: 10, Valores: 0.24217204714257434
# Celda: 76, Lambda: 100, Valores: 0.09463992353954709
# Celda: 77, Lambda: 0.01, Valores: 0.37204941821133475
# Celda: 77, Lambda: 1, Valores: 0.3389958425295876
# Celda: 77, Lambda: 10, Valores: 0.27605190546462455
# Celda: 77, Lambda: 100, Valores: 0.20249176135632063
# Celda: 78, Lambda: 0.01, Valores: 0.2489775824501258
# Celda: 78, Lambda: 1, Valores: 0.3651224528291177
# Celda: 78, Lambda: 10, Valores: 0.3398653862192925
# Celda: 78, Lambda: 100, Valores: 0.11624866593163807
# Celda: 79, Lambda: 0.01, Valores: 0.2369932604090541
# Celda: 79, Lambda: 1, Valores: 0.34780822798433997
# Celda: 79, Lambda: 10, Valores: 0.31342165748392015
# Celda: 79, Lambda: 100, Valores: 0.09774798293591425
# Celda: 80, Lambda: 0.01, Valores: 0.4166729265018414
# Celda: 80, Lambda: 1, Valores: 0.4301602836389026
# Celda: 80, Lambda: 10, Valores: 0.38471136902215286
# Celda: 80, Lambda: 100, Valores: 0.273985417279913
# Celda: 81, Lambda: 0.01, Valores: 0.3859858777259316
# Celda: 81, Lambda: 1, Valores: 0.4034303267825974
# Celda: 81, Lambda: 10, Valores: 0.36200897286259204
# Celda: 81, Lambda: 100, Valores: 0.2553068068384724
# Celda: 82, Lambda: 0.01, Valores: 0.4125961068946007
# Celda: 82, Lambda: 1, Valores: 0.41817896905472807
# Celda: 82, Lambda: 10, Valores: 0.3722171722596094
# Celda: 82, Lambda: 100, Valores: 0.26254790701479114
# Celda: 83, Lambda: 0.01, Valores: 0.3890256805276504
# Celda: 83, Lambda: 1, Valores: 0.3465369397293451
# Celda: 83, Lambda: 10, Valores: 0.25616012617795114
# Celda: 83, Lambda: 100, Valores: 0.1440731335127735
# Celda: 84, Lambda: 0.01, Valores: 0.39065446350921207
# Celda: 84, Lambda: 1, Valores: 0.36718869295795253
# Celda: 84, Lambda: 10, Valores: 0.29431248817752687
# Celda: 84, Lambda: 100, Valores: 0.20658481080268642
# Celda: 85, Lambda: 0.01, Valores: 0.36705132688573694
# Celda: 85, Lambda: 1, Valores: 0.29971993183071377
# Celda: 85, Lambda: 10, Valores: 0.2211255841333043
# Celda: 85, Lambda: 100, Valores: 0.10912040807828882
# Celda: 86, Lambda: 0.01, Valores: 0.3651573834972881
# Celda: 86, Lambda: 1, Valores: 0.316483981108572
# Celda: 86, Lambda: 10, Valores: 0.2564160677508942
# Celda: 86, Lambda: 100, Valores: 0.1727681185261536
# Celda: 87, Lambda: 0.01, Valores: 0.24313617924670317
# Celda: 87, Lambda: 1, Valores: 0.3491975208781867
# Celda: 87, Lambda: 10, Valores: 0.3298106023917142
# Celda: 87, Lambda: 100, Valores: 0.09969759024692437
# Celda: 88, Lambda: 0.01, Valores: 0.27932303889772314
# Celda: 88, Lambda: 1, Valores: 0.3925236954986866
# Celda: 88, Lambda: 10, Valores: 0.35096164513451156
# Celda: 88, Lambda: 100, Valores: 0.099725431101925
# Celda: 89, Lambda: 0.01, Valores: 0.25146433824893266
# Celda: 89, Lambda: 1, Valores: 0.35778857113879936
# Celda: 89, Lambda: 10, Valores: 0.32429778290532185
# Celda: 89, Lambda: 100, Valores: 0.0921396842551051
# Celda: 90, Lambda: 0.01, Valores: 0.3929312640200976
# Celda: 90, Lambda: 1, Valores: 0.3643587066402457
# Celda: 90, Lambda: 10, Valores: 0.29542638872823235
# Celda: 90, Lambda: 100, Valores: 0.21637423611062545
# Celda: 91, Lambda: 0.01, Valores: 0.3812653140389938
# Celda: 91, Lambda: 1, Valores: 0.3422181145279982
# Celda: 91, Lambda: 10, Valores: 0.2747165109010399
# Celda: 91, Lambda: 100, Valores: 0.19260887273768157
# Celda: 92, Lambda: 0.01, Valores: 0.24684690692067723
# Celda: 92, Lambda: 1, Valores: 0.35860619311553954
# Celda: 92, Lambda: 10, Valores: 0.37325151482542596
# Celda: 92, Lambda: 100, Valores: 0.16605103076984729
# Celda: 93, Lambda: 0.01, Valores: 0.21529093165943103
# Celda: 93, Lambda: 1, Valores: 0.3606438847286587
# Celda: 93, Lambda: 10, Valores: 0.3685080024993521
# Celda: 93, Lambda: 100, Valores: 0.17445175849100147
# Celda: 94, Lambda: 0.01, Valores: 0.3079305883391644
# Celda: 94, Lambda: 1, Valores: 0.3888437212980699
# Celda: 94, Lambda: 10, Valores: 0.33700290255934895
# Celda: 94, Lambda: 100, Valores: 0.006379462768396071
# Celda: 95, Lambda: 0.01, Valores: 0.3847814445506571
# Celda: 95, Lambda: 1, Valores: 0.3187327482798822
# Celda: 95, Lambda: 10, Valores: 0.26232115821316615
# Celda: 95, Lambda: 100, Valores: 0.19885148966439614
# Celda: 96, Lambda: 0.01, Valores: 0.2636056286555627
# Celda: 96, Lambda: 1, Valores: 0.36900592320798054
# Celda: 96, Lambda: 10, Valores: 0.34249183331676636
# Celda: 96, Lambda: 100, Valores: 0.10694634545643256
# Celda: 97, Lambda: 0.01, Valores: 0.23512395756010418
# Celda: 97, Lambda: 1, Valores: 0.3381235781308898
# Celda: 97, Lambda: 10, Valores: 0.31034224106619224
# Celda: 97, Lambda: 100, Valores: 0.08556700488795799
# Celda: 98, Lambda: 0.01, Valores: 0.24887811222640965
# Celda: 98, Lambda: 1, Valores: 0.3565239092390651
# Celda: 98, Lambda: 10, Valores: 0.31498747181093656
# Celda: 98, Lambda: 100, Valores: 0.07933861051250624
# Celda: 99, Lambda: 0.01, Valores: 0.2645383928091275
# Celda: 99, Lambda: 1, Valores: 0.3732153352661082
# Celda: 99, Lambda: 10, Valores: 0.32723907482718273
# Celda: 99, Lambda: 100, Valores: 0.10119148245157938
# Valores:  [np.float64(0.09161740731918133), np.float64(0.23913092035223316), np.float64(0.4572516456743544), np.float64(0.37361108141639365), np.float64(0.42880860080978844), np.float64(0.39266479364074336), np.float64(0.3746480320887964), np.float64(0.37948312034323783), np.float64(0.38373655660175454), np.float64(0.3866955921183015), np.float64(0.202080640750402), np.float64(0.2979000853793822), np.float64(0.4336799173561816), np.float64(0.3577646442003205), np.float64(0.41036905839960747), np.float64(0.3606403562760545), np.float64(0.3893266011941341), np.float64(0.3871866583479958), np.float64(0.3546426896697148), np.float64(0.3578909074837552), np.float64(0.4436055643418956), np.float64(0.44749188553740393), np.float64(0.42687204675440305), np.float64(0.4421345387531973), np.float64(0.41336727614876667), np.float64(0.37477259771281446), np.float64(0.3846280032134839), np.float64(0.39774901212770686), np.float64(0.3886125382435742), np.float64(0.388970527591571), np.float64(0.4006113692504175), np.float64(0.40157636544026853), np.float64(0.4216616932376164), np.float64(0.3820728893234533), np.float64(0.3961672946016809), np.float64(0.38357261776811347), np.float64(0.38807763508466586), np.float64(0.3857898247441188), np.float64(0.37451232502892506), np.float64(0.29448434120099254), np.float64(0.399968817560281), np.float64(0.3871883706357022), np.float64(0.4254450466641222), np.float64(0.38432237606588404), np.float64(0.382470576072245), np.float64(0.41313882804536217), np.float64(0.38565563925206403), np.float64(0.38656109082990653), np.float64(0.37996405913630504), np.float64(0.29699803640884115), np.float64(0.4161464623287652), np.float64(0.40459223936506816), np.float64(0.44002867156528136), np.float64(0.41839425813049835), np.float64(0.39926272740255075), np.float64(0.3785380210506488), np.float64(0.3922094106352795), np.float64(0.4068810818590304), np.float64(0.3025778553783611), np.float64(0.22775674930475986), np.float64(0.39908444708588586), np.float64(0.41586966978649775), np.float64(0.3835910667971396), np.float64(0.3788307977905544), np.float64(0.4052181018223472), np.float64(0.39111965472559773), np.float64(0.4053995806358802), np.float64(0.3674931040117807), np.float64(0.29691159130069156), np.float64(0.24330360710417687), np.float64(0.37405243019518464), np.float64(0.375743242976312), np.float64(0.3877515042597266), np.float64(0.35760446374917776), np.float64(0.3906203572215252), np.float64(0.37905119351037353), np.float64(0.3809049556220139), np.float64(0.37204941821133475), np.float64(0.2489775824501258), np.float64(0.2369932604090541), np.float64(0.4166729265018414), np.float64(0.3859858777259316), np.float64(0.4125961068946007), np.float64(0.3890256805276504), np.float64(0.39065446350921207), np.float64(0.36705132688573694), np.float64(0.3651573834972881), np.float64(0.24313617924670317), np.float64(0.27932303889772314), np.float64(0.25146433824893266), np.float64(0.3929312640200976), np.float64(0.3812653140389938), np.float64(0.24684690692067723), np.float64(0.21529093165943103), np.float64(0.3079305883391644), np.float64(0.3847814445506571), np.float64(0.2636056286555627), np.float64(0.23512395756010418), np.float64(0.24887811222640965), np.float64(0.2645383928091275)] [np.float64(0.07772849188438602), np.float64(0.24122642126354266), np.float64(0.4583669541168627), np.float64(0.39735869988364936), np.float64(0.41804456436350557), np.float64(0.41927572495184384), np.float64(0.39666509728666366), np.float64(0.3981049207643903), np.float64(0.3969765200578934), np.float64(0.3529066520585379), np.float64(0.2050010454329776), np.float64(0.2952918238409109), np.float64(0.43812395418469374), np.float64(0.38737013591279146), np.float64(0.4010539154423276), np.float64(0.38724388261127374), np.float64(0.4148593038682159), np.float64(0.40089729993369483), np.float64(0.37389132491027655), np.float64(0.32228781881681234), np.float64(0.4452303213653752), np.float64(0.4425233606944321), np.float64(0.4244478331758106) ...
# Matriz:  [[[0.44351458 0.44378554 0.44361567 0.44387747]
#   [0.44301611 0.44204477 0.44317767 0.44381765]
#   [0.44156897 0.44050909 0.44172739 0.44149465]
#   [0.43036604 0.43029658 0.42945357 0.43035874]
#   [0.39906216 0.40545515 0.39031094 0.40649723]
#   [0.37390884 0.32848805 0.35346021 0.33950764]]
#
#  [[0.4409674  0.44089659 0.44336916 0.44382848]
#   [0.4329377  0.43690545 0.4346963  0.4419802 ]
#   [0.41387467 0.4069865  0.41011873 0.42628993]
#   [0.35345984 0.36640081 0.35565047 0.36034138]
#   [0.27451907 0.29568719 0.27620447 0.29454707]
#   [0.24735858 0.25573573 0.2539428  0.25939212]]
#
#  [[0.4160074  0.41676334 0.43587045 0.44264618]
#   [0.36475935 0.35847815 0.38965235 0.42835422]
#   [0.27002876 0.27633507 0.26728653 0.33768168]
#   [0.23019688 0.23282313 0.23745124 0.24961498]
#   [0.2331541  0.23695932 0.23968066 0.24407449]
#   [0.2416357  0.24184306 0.24423627 0.25058888]]
#
#  [[0.27698408 0.28490631 0.37537502 0.43242414]
#   [0.17304913 0.17983862 0.21909126 0.33643083]
#   [0.1794333  0.19297579 0.20476843 0.22674254]
#   [0.21017956 0.22173203 0.22702728 0.23142701]
#   [0.23242694 0.23355733 0.23618014 0.23860936]
#   [0.24125263 0.24157713 0.24184314 0.24440905]]
#
#  [[0.21431342 0.19470804 0.28685756 0.41192282]
#   [0.17310528 0.15621427 0.17689682 0.25935766]
#   [0.17465043 0.18581672 0.19621051 0.2110633 ]
#   [0.20720885 0.21865076 0.22361783 0.22938851]
#   [0.23208279 0.23316492 0.23455993 0.23753373]
#   [0.24046884 0.24162931 0.24160942 0.24260618]]
#
#  [[0.23745642 0.17438049 0.24141861 0.38985325]
#   [0.18155073 0.15472353 0.16607289 0.22187337]
#   [0.17312013 0.18272333 0.19278651 0.20599579]
#   [0.20596637 0.21720915 0.22213621 0.22812443]
#   [0.23186127 0.23303116 0.23394642 0.23683684]
#   [0.23973941 0.24165609 0.24157333 0.24211381]]]
# Matriz:  [[[0.44351458 0.44378554 0.44361567 0.44387747]
#   [0.44301611 0.44204477 0.44317767 0.44381765]
#   [0.44156897 0.44050909 0.44172739 0.44149465]
#   [0.43036604 0.43029658 0.42945357 0.43035874]
#   [0.39906216 0.40545515 0.39031094 0.40649723]
#   [0.37390884 0.32848805 0.35346021 0.33950764]]
#
#  [[0.4409674  0.44089659 0.44336916 0.44382848]
#   [0.4329377  0.43690545 0.4346963  0.4419802 ]
#   [0.41387467 0.4069865  0.41011873 0.42628993]
#   [0.35345984 0.36640081 0.35565047 0.36034138]
#   [0.27451907 0.29568719 0.27620447 0.29454707]
#   [0.24735858 0.25573573 0.2539428  0.25939212]]
#
#  [[0.4160074  0.41676334 0.43587045 0.44264618]
#   [0.36475935 0.35847815 0.38965235 0.42835422]
#   [0.27002876 0.27633507 0.26728653 0.33768168]
#   [0.23019688 0.23282313 0.23745124 0.24961498]
#   [0.2331541  0.23695932 0.23968066 0.24407449]
#   [0.2416357  0.24184306 0.24423627 0.25058888]]
#
#  [[0.27698408 0.28490631 0.37537502 0.43242414]
#   [0.17304913 0.17983862 0.21909126 0.33643083]
#   [0.1794333  0.19297579 0.20476843 0.22674254]
#   [0.21017956 0.22173203 0.22702728 0.23142701]
#   [0.23242694 0.23355733 0.23618014 0.23860936]
#   [0.24125263 0.24157713 0.24184314 0.24440905]]
#
#  [[0.21431342 0.19470804 0.28685756 0.41192282]
#   [0.17310528 0.15621427 0.17689682 0.25935766]
#   [0.17465043 0.18581672 0.19621051 0.2110633 ]
#   [0.20720885 0.21865076 0.22361783 0.22938851]
#   [0.23208279 0.23316492 0.23455993 0.23753373]
#   [0.24046884 0.24162931 0.24160942 0.24260618]]
#
#  [[0.23745642 0.17438049 0.24141861 0.38985325]
#   [0.18155073 0.15472353 0.16607289 0.22187337]
#   [0.17312013 0.18272333 0.19278651 0.20599579]
#   [0.20596637 0.21720915 0.22213621 0.22812443]
#   [0.23186127 0.23303116 0.23394642 0.23683684]
#   [0.23973941 0.24165609 0.24157333 0.24211381]]]
# Matriz:  [[[0.44351458 0.44378554 0.44361567 0.44387747]
#   [0.44301611 0.44204477 0.44317767 0.44381765]
#   [0.44156897 0.44050909 0.44172739 0.44149465]
#   [0.43036604 0.43029658 0.42945357 0.43035874]
#   [0.39906216 0.40545515 0.39031094 0.40649723]
#   [0.37390884 0.32848805 0.35346021 0.33950764]]
#
#  [[0.4409674  0.44089659 0.44336916 0.44382848]
#   [0.4329377  0.43690545 0.4346963  0.4419802 ]
#   [0.41387467 0.4069865  0.41011873 0.42628993]
#   [0.35345984 0.36640081 0.35565047 0.36034138]
#   [0.27451907 0.29568719 0.27620447 0.29454707]
#   [0.24735858 0.25573573 0.2539428  0.25939212]]
#
#  [[0.4160074  0.41676334 0.43587045 0.44264618]
#   [0.36475935 0.35847815 0.38965235 0.42835422]
#   [0.27002876 0.27633507 0.26728653 0.33768168]
#   [0.23019688 0.23282313 0.23745124 0.24961498]
#   [0.2331541  0.23695932 0.23968066 0.24407449]
#   [0.2416357  0.24184306 0.24423627 0.25058888]]
#
#  [[0.27698408 0.28490631 0.37537502 0.43242414]
#   [0.17304913 0.17983862 0.21909126 0.33643083]
#   [0.1794333  0.19297579 0.20476843 0.22674254]
#   [0.21017956 0.22173203 0.22702728 0.23142701]
#   [0.23242694 0.23355733 0.23618014 0.23860936]
#   [0.24125263 0.24157713 0.24184314 0.24440905]]
#
#  [[0.21431342 0.19470804 0.28685756 0.41192282]
#   [0.17310528 0.15621427 0.17689682 0.25935766]
#   [0.17465043 0.18581672 0.19621051 0.2110633 ]
#   [0.20720885 0.21865076 0.22361783 0.22938851]
#   [0.23208279 0.23316492 0.23455993 0.23753373]
#   [0.24046884 0.24162931 0.24160942 0.24260618]]
#
#  [[0.23745642 0.17438049 0.24141861 0.38985325]
#   [0.18155073 0.15472353 0.16607289 0.22187337]
#   [0.17312013 0.18272333 0.19278651 0.20599579]
#   [0.20596637 0.21720915 0.22213621 0.22812443]
#   [0.23186127 0.23303116 0.23394642 0.23683684]
#   [0.23973941 0.24165609 0.24157333 0.24211381]]]
